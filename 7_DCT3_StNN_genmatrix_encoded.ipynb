# %% [markdown]
# ### 3-layer DCT-III StNN - Generator matrix encoded data

# %%
# %reset -f
import gc
gc.collect()
# Out:
# 0

# %%
global w0
global z0

w0 = 4
z0 = 3

n = 27
q = 7
num_samples = 1000

num_unseen_samples = 20

# %%
import numpy as np
import tensorflow as tf
import math

np.random.seed(42)

# %%
def next_power_of_two(x):
    return 2 ** math.ceil(math.log2(x))

n_padded = next_power_of_two(n)

x_original = np.random.randint(0, q, size=(num_samples, n))

padding = n_padded - n
dataset = np.pad(x_original, ((0, 0), (0, padding)), mode='constant', constant_values=0)

print(f"Original n: {n}, Padded to: {n_padded}")
# Out:
# Original n: 27, Padded to: 32

# %%
x_original.shape
# Out:
# (1000, 27)

# %%
dataset.shape
# Out:
# (1000, 32)

# %% [markdown]
# Encode using generator matrix
# $$
# \tilde{M}_{kj} = \left[ \left( \frac{w_0}{z_0} \right)^j \zeta^{kj} \right]_{k,j=0}^{n-1}
# $$

# %%
def padded_generator_matrix(N, w0, z0):
    n = np.arange(N)
    k = n.reshape((N, 1))
    zeta = np.exp(-2j * np.pi / N)
    M_tilde = ((w0 / z0) ** n) * (zeta ** (k * n))
    return M_tilde

# %%
M_tilde = padded_generator_matrix(n_padded, w0, z0)
print(M_tilde.shape)
# Out:
# (32, 32)

# %%
encoded_dataset = np.array([np.dot(M_tilde, x) for x in dataset])
encoded_dataset[np.abs(encoded_dataset) < 1e-10] = 0
encoded_dataset = np.round(encoded_dataset, decimals=10)
encoded_dataset.shape
# Out:
# (1000, 32)

# %%
print(f"x_original[0]:", x_original[0])
print(f"\nAfter encoding:\n", encoded_dataset[0])
# Out:
# x_original[0]: [6 3 4 6 2 4 4 6 1 2 6 2 2 4 3 2 5 4 1 3 5 5 1 3 4 0 3]
#
# After encoding:
#  [18563.60052945    +0.j         -3175.07412411+14542.65392496j
#  -9480.13851167 -1549.89213738j  -850.18419129 -5788.51248279j
#   2813.63372348 -2457.36436449j  3312.0476391   +337.88077825j
#   1059.2907911  +3489.68169028j -2366.82367016  +909.74502726j
#   -210.29906943  +357.85181443j -3878.07651347  +373.95548592j
#    -49.25036994 -6370.32567308j  6901.71964373 -1088.5938127j
#   2896.76301761 +7252.43377368j -6714.83312544 +4427.90575271j
#  -5496.28870703 -5330.43278044j  2828.24226801 -6162.17891893j
#   6446.94186958    -0.j          2828.24226801 +6162.17891893j
#  -5496.28870703 +5330.43278044j -6714.83312544 -4427.90575271j
#   2896.76301761 -7252.43377368j  6901.71964373 +1088.5938127j
#    -49.25036994 +6370.32567308j -3878.07651347  -373.95548592j
#   -210.29906943  -357.85181443j -2366.82367016  -909.74502726j
#   1059.2907911  -3489.68169028j  3312.0476391   -337.88077825j
#   2813.63372348 +2457.36436449j  -850.18419129 +5788.51248279j
#  -9480.13851167 +1549.89213738j -3175.07412411-14542.65392496j]

# %% [markdown]
# Pre-processing

# %%
N = encoded_dataset.shape[1]

k = np.arange(N)
shift = np.exp(-1j * np.pi * k / (2 * N))
alpha_k = np.where(k == 0, np.sqrt(1/N), np.sqrt(2/N))

dct2_dataset = np.array([np.real(alpha_k * shift * y) for y in encoded_dataset])
dct2_dataset[np.abs(dct2_dataset) < 1e-10] = 0
dct2_dataset = np.round(dct2_dataset, decimals=10) # Round for numerical stability

# %%
"""
The part below is for testing purposes only
"""

from scipy.fftpack import dct

dct3_dataset = np.array([dct(x, type=3, norm='ortho') for x in dct2_dataset])

X_perm = np.hstack((dct3_dataset[:, ::2], dct3_dataset[:, 1::2][:, ::-1]))

D_hat_n = np.array([(z0 / w0) ** k for k in range(N)])
decoded_dataset = X_perm * D_hat_n

# Print verification (for one sample)
sample_idx = 78
print("Original x:", dataset[sample_idx])
print("\nEncoded y:", encoded_dataset[sample_idx])
print("\nDCT Coefficients:", np.round(dct2_dataset[sample_idx], 4))
print("\nReconstructed Signal:", np.round(dct3_dataset[sample_idx], 4))
print("\nAfter Permutation:", np.round(X_perm[sample_idx], 4))
print("\nAfter Scaling:", np.round(decoded_dataset[sample_idx], 4))
# Out:
# Original x: [4 3 6 4 2 0 5 6 6 2 2 1 6 1 1 5 1 4 3 0 2 4 0 6 6 6 4 0 0 0 0 0]
#
# Encoded y: [ 29916.11588021    +0.j            328.95686704+26422.4846445j
#  -21936.20111033 +3988.95593508j  -7301.38988823-17810.36382931j
#   13577.84642585 -8953.74117052j   9354.9421295  +8727.48732799j
#   -4221.49645678 +8798.15590637j  -7861.90722461  -861.73832776j
#    -779.76795929 -5322.56486315j   2168.22506293 -1740.90057156j
#    1615.33333537 -1441.8771791j    5127.91361716 +2018.69510167j
#   -2943.81135295 +6208.60576073j  -5262.87924206 -2070.18847016j
#     798.8487054  -4460.7613612j    2679.94226354  +633.97975698j
#    -477.22622529    -0.j           2679.94226354  -633.97975698j
#     798.8487054  +4460.7613612j   -5262.87924206 +2070.18847016j
#   -2943.81135295 -6208.60576073j   5127.91361716 -2018.69510167j
#    1615.33333537 +1441.8771791j    2168.22506293 +1740.90057156j
#    -779.76795929 +5322.56486315j  -7861.90722461  +861.73832776j
#   -4221.49645678 -8798.15590637j   9354.9421295  -8727.48732799j
#   13577.84642585 +8953.74117052j  -7301.38988823+17810.36382931j
#  -21936.20111033 -3988.95593508j    328.95686704-26422.4846445j ]
#
# DCT Coefficients: [ 5288.4721   406.2626 -5359.8966 -2458.9216  2892.5409  2798.7982
#   -371.4376 -1923.1607  -689.3173   303.9303   186.2252  1359.0437
#    250.4067 -1365.0985  -553.0897   602.8653   -84.3625   332.4978
#    988.7499  -368.0756 -1699.4402   226.1955   508.2713   625.1978
#   1154.7511  -459.308  -2411.1865 -1548.2175  2857.651   4136.5643
#  -1529.9679 -6593.6291]
#
# Reconstructed Signal: [ 4.0000000e+00  0.0000000e+00  4.0000000e+00  0.0000000e+00
#   1.0666700e+01 -0.0000000e+00  9.4815000e+00  0.0000000e+00
#   6.3210000e+00  0.0000000e+00  0.0000000e+00  7.0870769e+03
#   2.8093300e+01  7.9729615e+03  4.4949200e+01  5.9797211e+03
#   5.9932300e+01  4.4847908e+03  2.6636600e+01 -0.0000000e+00
#   3.5515500e+01  1.6817966e+03  2.3677000e+01  6.3067370e+02
#   1.8941580e+02  0.0000000e+00  4.2092400e+01  5.3213090e+02
#   5.6123200e+01  5.3213090e+02  3.7415460e+02  9.9774600e+01]
#
# After Permutation: [ 4.0000000e+00  4.0000000e+00  1.0666700e+01  9.4815000e+00
#   6.3210000e+00  0.0000000e+00  2.8093300e+01  4.4949200e+01
#   5.9932300e+01  2.6636600e+01  3.5515500e+01  2.3677000e+01
#   1.8941580e+02  4.2092400e+01  5.6123200e+01  3.7415460e+02
#   9.9774600e+01  5.3213090e+02  5.3213090e+02  0.0000000e+00
#   6.3067370e+02  1.6817966e+03 -0.0000000e+00  4.4847908e+03
#   5.9797211e+03  7.9729615e+03  7.0870769e+03  0.0000000e+00
#   0.0000000e+00 -0.0000000e+00  0.0000000e+00  0.0000000e+00]
#
# After Scaling: [ 4.  3.  6.  4.  2.  0.  5.  6.  6.  2.  2.  1.  6.  1.  1.  5.  1.  4.
#   3.  0.  2.  4. -0.  6.  6.  6.  4.  0.  0. -0.  0.  0.]

# %%
y = dataset.astype(np.float32)
y_normalized = y / (q - 1)  # Scale to [0, 1]

# labels = y
labels = y_normalized

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    dct2_dataset, labels, test_size=0.2, random_state=42
)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (800, 32) (800, 32)
# (200, 32) (200, 32)

# %%
X_train = (X_train - X_train.mean()) / X_train.std()
X_test = (X_test - X_test.mean()) / X_test.std()

# %% [markdown]
# DCT-3 imposed StNN

# %%
class FirstLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, **kwargs):
        super(FirstLayer, self).__init__(**kwargs)
        self.n = units
        self.n1 = units // 2
        self.trainable = trainable

        init_diag = tf.ones(self.n1, dtype=tf.float32)
        init_diag = tf.tensor_scatter_nd_update(init_diag, [[0]], [tf.sqrt(2.0)])

        self.B_1 = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_diag),
                trainable=self.trainable,
                name='B_1'
            )
        self.B_2 = self.add_weight(
                shape=(self.n1,),
                initializer='ones',
                trainable=self.trainable,
                name='B_2'
            )
        self.bias = self.add_weight(
            shape=(self.n,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

    def call(self, x):
        even = x[:, ::2]
        odd = x[:, 1::2]

        d1 = tf.multiply(odd, self.B_1) # diagonal
        d2 = tf.multiply(tf.concat([tf.zeros_like(odd[:, :1]), odd[:, :-1]], axis=1), self.B_2) # off-diagonal
        B_n = tf.add(d1, d2)

        u = tf.concat([even, B_n], axis=1)

        return u + self.bias

# %%
class DCTIII(tf.keras.layers.Layer):
    def __init__(self, n, trainable=True, **kwargs):
        super(DCTIII, self).__init__(**kwargs)
        self.n = n
        self.n1 = n // 2 if n > 2 else 1
        self.trainable = trainable

        if n == 2:
            # Base case: trainable 2x2 matrix
            self.C_2 = self.add_weight(
                shape=(2, 2),
                initializer=tf.keras.initializers.Constant((1 / np.sqrt(2)) * np.array([[1., 1.], [1., -1.]])),
                trainable=self.trainable,
                name='C_2'
            )
        else:
            init_diag = tf.ones(self.n1, dtype=tf.float32)
            init_diag = tf.tensor_scatter_nd_update(init_diag, [[0]], [tf.sqrt(2.0)])

            # Weights for B^T_{n/2}
            self.B_1 = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_diag),
                trainable=self.trainable,
                name='B_1'
            )
            self.B_2 = self.add_weight(
                shape=(self.n1,),
                initializer='ones',
                trainable=self.trainable,
                name='B_2'
            )

            k = tf.cast(tf.range(1, self.n1 + 1), tf.float32)
            pi = tf.constant(np.pi, dtype=tf.float32)
            init_W_c = 1 / (2 * tf.cos((2 * k - 1) * (pi / (2 * self.n))))

            # Weight for W_c
            self.w_c = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_W_c),
                trainable=self.trainable,
                name='W_c'
            )

            # Recursive DCTIII for n/2
            self.dctiii_layer1 = DCTIII(self.n1,trainable=self.trainable)
            self.dctiii_layer2 = DCTIII(self.n1,trainable=self.trainable)

    def call(self, x):
        if self.n == 2:
            y = tf.matmul(self.C_2, x, transpose_b=True)
            return tf.transpose(y)
        else:
            # Permutation
            even = x[:, ::2]
            odd = x[:, 1::2]

            # B^T
            d1 = tf.multiply(odd, self.B_1)
            d2 = tf.multiply(tf.concat([tf.zeros_like(odd[:, :1]), odd[:, :-1]], axis=1), self.B_2)
            B_n = tf.add(d1, d2)
            u = tf.concat([even, B_n], axis=1)

            # Recursive DCTIII
            z1 = self.dctiii_layer1(u[:, :self.n1])
            z2 = self.dctiii_layer2(u[:, self.n1:])
            recurs_out = tf.concat([z1, z2], axis=1)

            # W_c
            W_n = tf.multiply(recurs_out[:, self.n1:], self.w_c)
            v = tf.concat([recurs_out[:, :self.n1], W_n], axis=1)

            # H_n
            out1 = v[:, :self.n1]
            out2 = v[:, self.n1:]
            y = (1 / tf.sqrt(tf.constant(2.0, dtype=tf.float32))) * tf.concat(
                [(out1 + out2), tf.reverse((out1 - out2), axis=[1])],
                axis=1
            )

            return y

# %%
class SecondLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, **kwargs):
        super(SecondLayer, self).__init__(**kwargs)
        self.n = units
        self.n1 = units // 2
        self.trainable = trainable

        self.bias = self.add_weight(
            shape=(self.n,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

        # Recursive DCTIII for n/2
        self.dctiii1 = DCTIII(self.n1, trainable=self.trainable)
        self.dctiii2 = DCTIII(self.n1,trainable=self.trainable)

    def call(self, x):
        z1 = self.dctiii1(x[:, :self.n1])
        z2 = self.dctiii2(x[:, self.n1:])
        out = tf.concat([z1, z2], axis=1)
        return out + self.bias

# %%
class ThirdLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, **kwargs):
        super(ThirdLayer, self).__init__(**kwargs)
        self.n = units
        self.n1 = units // 2
        self.trainable = trainable

        k = tf.cast(tf.range(1, self.n1 + 1), tf.float32)
        pi = tf.constant(np.pi, dtype=tf.float32)
        init_W_c = 1 / (2 * tf.cos((2 * k - 1) * (pi / (2 * self.n))))

        self.w_c = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_W_c),
                trainable=self.trainable,
                name='W_c'
            )

        self.bias = self.add_weight(
            shape=(self.n,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

    def call(self, x):
        input1 = x[:, :self.n1]
        input2 = x[:, self.n1:]

        # W_{N/2}
        W_n = tf.multiply(input2, self.w_c)
        v = tf.concat([input1, W_n], axis=1)

        # H_n^T
        out1 = v[:, :self.n1]
        out2 = v[:, self.n1:]

        y = (1 / tf.sqrt(tf.constant(2.0, dtype=tf.float32))) * tf.concat([(out1 + out2), tf.reverse((out1 - out2), axis=[1])], axis=1)

        return y + self.bias

# %%
class DiagonalLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, kernel_initializer='he_normal', bias_initializer='zeros', **kwargs):
        super(DiagonalLayer, self).__init__(**kwargs)
        self.units = units
        self.kernel_initializer = kernel_initializer
        self.bias_initializer = bias_initializer
        self.trainable = trainable

    def build(self, input_shape):
        self.diag = self.add_weight(
            shape=(self.units,),
            initializer=tf.keras.initializers.get(self.kernel_initializer),
            trainable=self.trainable,
            name='diag'
        )
        self.bias = self.add_weight(
            shape=(self.units,),
            initializer=tf.keras.initializers.get(self.bias_initializer),
            trainable=self.trainable,
            name='bias'
        )

    def call(self, inputs):
        scaled = tf.multiply(inputs, self.diag)
        return scaled + self.bias

# %%
class ScalingLayer(tf.keras.layers.Layer):
    def __init__(self, units, initial_scale=1.0, trainable=True, kernel_initializer='he_normal', bias_initializer='zeros', **kwargs):
        super(ScalingLayer, self).__init__(**kwargs)
        self.units = units
        self.initial_scale = initial_scale
        self.kernel_initializer = kernel_initializer
        self.bias_initializer = bias_initializer

    def build(self, input_shape):

      self.log_scale = self.add_weight(
          shape=(),
          initializer=tf.keras.initializers.Constant(self.initial_scale),
          trainable=True,
          name="log_scale",
      )
      self.diag = self.add_weight(
          shape=(self.units,),
          initializer=tf.keras.initializers.get(self.kernel_initializer),
          regularizer=tf.keras.regularizers.l2(1e-4),
          trainable=True,
          name='diag'
      )
      self.bias = self.add_weight(
          shape=(self.units,),
          initializer=tf.keras.initializers.get(self.bias_initializer),
          trainable=True,
          name='bias'
        )

      super().build(input_shape)

    def call(self, inputs):
      perm = tf.concat([inputs[:, ::2], inputs[:, 1::2][:, ::-1]], axis=-1)

      dim = tf.shape(perm)[1]

      D_hat_n = tf.exp(self.log_scale * tf.cast(tf.range(dim), tf.float32))

      scaled = perm * D_hat_n * self.diag

      return scaled + self.bias

# %% [markdown]
# Model

# %%
def custom_accuracy(y_true, y_pred):
    y_true_int = tf.cast(y_true*(q-1), tf.int32)
    y_pred_int = tf.cast(tf.round(y_pred*(q-1)), tf.int32)
    correct = tf.cast(tf.equal(y_true_int, y_pred_int), tf.float32)
    return tf.reduce_mean(correct)

def custom_accuracy_without_padding(y_true, y_pred):
    y_true_int = tf.cast(y_true * (q - 1), tf.int32)
    y_pred_int = tf.cast(tf.round(y_pred * (q - 1)), tf.int32)
    mask = tf.concat(
        [tf.ones((tf.shape(y_true)[0], n), dtype=tf.float32),
         tf.zeros((tf.shape(y_true)[0], n_padded - n), dtype=tf.float32)],
        axis=1
    )
    correct = tf.cast(tf.equal(y_true_int, y_pred_int), tf.float32) * mask
    return tf.reduce_sum(correct) / tf.reduce_sum(mask)

def custom_mse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    loss = tf.reduce_mean(tf.square(tf.cast(y_true - y_pred, tf.float32)))
    return loss

# %%
from tensorflow.keras.layers import InputLayer, LeakyReLU, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

initial_log_scale = np.log(z0 / w0)
initial_scale = (z0 / w0)

input_shape = (n_padded,)
model = Sequential([
    InputLayer(shape=input_shape),
    FirstLayer(units=n_padded, trainable=True, name="first_layer"),
    # LeakyReLU(negative_slope=0.1),
    SecondLayer(units=n_padded, trainable=True, name="second_layer"),
    # LeakyReLU(negative_slope=0.1),
    ThirdLayer(units=n_padded, trainable=True, name="third_layer"),
    LeakyReLU(negative_slope=0.1),
    ScalingLayer(units=n_padded, initial_scale=initial_log_scale, trainable=True, kernel_initializer='ones', bias_initializer='zeros', name="scaling_layer"),
    LeakyReLU(negative_slope=0.1),
    DiagonalLayer(units=n_padded, trainable=False, kernel_initializer='ones', bias_initializer='zeros', name="output_layer"),
    Activation('linear')
])

# notes:
# 1. adding the diagonal layers in the middle worsens results
# 2. residual connections does not work
# 3. removing bias in hidden layers worsens performance
# 4. removing "LeakyReLU" activation in between layers improved performance


model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=custom_mse,
    metrics=[custom_mse, custom_accuracy_without_padding]
)

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ first_layer (FirstLayer)        │ (None, 32)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ second_layer (SecondLayer)      │ (None, 32)             │           240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ third_layer (ThirdLayer)        │ (None, 32)             │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_10 (LeakyReLU)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ scaling_layer (ScalingLayer)    │ (None, 32)             │            65 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_11 (LeakyReLU)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (DiagonalLayer)    │ (None, 32)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 32)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 481 (1.88 KB)
#  Trainable params: 417 (1.63 KB)
#  Non-trainable params: 64 (256.00 B)

# %%
# ------------- FLOP counts ---------------

# Create concrete function
input_shape = (1, n_padded)  # batch size 1
concrete_func = tf.function(model).get_concrete_function(tf.TensorSpec(input_shape, tf.float32))

from tensorflow.python.profiler import model_analyzer
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

profile_opts = ProfileOptionBuilder.float_operation()
flops = model_analyzer.profile(concrete_func.graph, options=profile_opts)

print('FLOPs:', flops.total_float_ops)
# Out:
# FLOPs: 943

# %% [markdown]
# Training

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

checkpoint_path = f"/content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_{n}.keras"

model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

adjust_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

history = model.fit(
    X_train, y_train,
    epochs=500,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[adjust_lr, early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.1427 - custom_mse: 0.2948 - loss: 0.2979
# Epoch 1: val_loss improved from inf to 0.24432, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - custom_accuracy_without_padding: 0.1426 - custom_mse: 0.2881 - loss: 0.2913 - val_custom_accuracy_without_padding: 0.1473 - val_custom_mse: 0.2403 - val_loss: 0.2443 - learning_rate: 0.0010
# Epoch 2/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.1429 - custom_mse: 0.2469 - loss: 0.2500
# Epoch 2: val_loss improved from 0.24432 to 0.21099, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.1421 - custom_mse: 0.2417 - loss: 0.2448 - val_custom_accuracy_without_padding: 0.1503 - val_custom_mse: 0.2068 - val_loss: 0.2110 - learning_rate: 0.0010
# Epoch 3/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.1428 - custom_mse: 0.2114 - loss: 0.2146
# Epoch 3: val_loss improved from 0.21099 to 0.18645, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.1430 - custom_mse: 0.2086 - loss: 0.2118 - val_custom_accuracy_without_padding: 0.1551 - val_custom_mse: 0.1822 - val_loss: 0.1864 - learning_rate: 0.0010
# Epoch 4/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.1531 - custom_mse: 0.1845 - loss: 0.1878
# Epoch 4: val_loss improved from 0.18645 to 0.16453, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_accuracy_without_padding: 0.1522 - custom_mse: 0.1834 - loss: 0.1866 - val_custom_accuracy_without_padding: 0.1481 - val_custom_mse: 0.1605 - val_loss: 0.1645 - learning_rate: 0.0010
# Epoch 5/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.1438 - custom_mse: 0.1613 - loss: 0.1647
# Epoch 5: val_loss improved from 0.16453 to 0.13609, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - custom_accuracy_without_padding: 0.1440 - custom_mse: 0.1596 - loss: 0.1630 - val_custom_accuracy_without_padding: 0.1498 - val_custom_mse: 0.1323 - val_loss: 0.1361 - learning_rate: 0.0010
# Epoch 6/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.1448 - custom_mse: 0.1308 - loss: 0.1343
# Epoch 6: val_loss improved from 0.13609 to 0.08928, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.1472 - custom_mse: 0.1254 - loss: 0.1289 - val_custom_accuracy_without_padding: 0.1971 - val_custom_mse: 0.0858 - val_loss: 0.0893 - learning_rate: 0.0010
# Epoch 7/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.1858 - custom_mse: 0.0826 - loss: 0.0862
# Epoch 7: val_loss improved from 0.08928 to 0.07315, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.1898 - custom_mse: 0.0799 - loss: 0.0835 - val_custom_accuracy_without_padding: 0.1948 - val_custom_mse: 0.0696 - val_loss: 0.0732 - learning_rate: 0.0010
# Epoch 8/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.2097 - custom_mse: 0.0684 - loss: 0.0721
# Epoch 8: val_loss improved from 0.07315 to 0.06948, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.2092 - custom_mse: 0.0682 - loss: 0.0718 - val_custom_accuracy_without_padding: 0.1933 - val_custom_mse: 0.0659 - val_loss: 0.0695 - learning_rate: 0.0010
# Epoch 9/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2112 - custom_mse: 0.0647 - loss: 0.0684
# Epoch 9: val_loss improved from 0.06948 to 0.06788, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.2119 - custom_mse: 0.0648 - loss: 0.0684 - val_custom_accuracy_without_padding: 0.2149 - val_custom_mse: 0.0643 - val_loss: 0.0679 - learning_rate: 0.0010
# Epoch 10/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.2339 - custom_mse: 0.0635 - loss: 0.0672
# Epoch 10: val_loss improved from 0.06788 to 0.06717, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - custom_accuracy_without_padding: 0.2346 - custom_mse: 0.0637 - loss: 0.0674 - val_custom_accuracy_without_padding: 0.2275 - val_custom_mse: 0.0637 - val_loss: 0.0672 - learning_rate: 0.0010
# Epoch 11/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.2424 - custom_mse: 0.0631 - loss: 0.0668
# Epoch 11: val_loss improved from 0.06717 to 0.06601, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.2471 - custom_mse: 0.0630 - loss: 0.0667 - val_custom_accuracy_without_padding: 0.2479 - val_custom_mse: 0.0624 - val_loss: 0.0660 - learning_rate: 0.0010
# Epoch 12/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.2614 - custom_mse: 0.0612 - loss: 0.0649
# Epoch 12: val_loss improved from 0.06601 to 0.06518, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.2623 - custom_mse: 0.0614 - loss: 0.0651 - val_custom_accuracy_without_padding: 0.2591 - val_custom_mse: 0.0616 - val_loss: 0.0652 - learning_rate: 0.0010
# Epoch 13/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.2648 - custom_mse: 0.0611 - loss: 0.0648
# Epoch 13: val_loss improved from 0.06518 to 0.06441, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.2677 - custom_mse: 0.0610 - loss: 0.0647 - val_custom_accuracy_without_padding: 0.2695 - val_custom_mse: 0.0609 - val_loss: 0.0644 - learning_rate: 0.0010
# Epoch 14/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.2743 - custom_mse: 0.0613 - loss: 0.0650
# Epoch 14: val_loss improved from 0.06441 to 0.06353, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.2758 - custom_mse: 0.0611 - loss: 0.0648 - val_custom_accuracy_without_padding: 0.2829 - val_custom_mse: 0.0600 - val_loss: 0.0635 - learning_rate: 0.0010
# Epoch 15/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.2867 - custom_mse: 0.0601 - loss: 0.0638
# Epoch 15: val_loss improved from 0.06353 to 0.06292, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - custom_accuracy_without_padding: 0.2878 - custom_mse: 0.0599 - loss: 0.0636 - val_custom_accuracy_without_padding: 0.2894 - val_custom_mse: 0.0595 - val_loss: 0.0629 - learning_rate: 0.0010
# Epoch 16/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.2951 - custom_mse: 0.0591 - loss: 0.0627
# Epoch 16: val_loss improved from 0.06292 to 0.06227, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.2953 - custom_mse: 0.0590 - loss: 0.0626 - val_custom_accuracy_without_padding: 0.2955 - val_custom_mse: 0.0587 - val_loss: 0.0623 - learning_rate: 0.0010
# Epoch 17/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3020 - custom_mse: 0.0580 - loss: 0.0616
# Epoch 17: val_loss improved from 0.06227 to 0.06167, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3020 - custom_mse: 0.0580 - loss: 0.0616 - val_custom_accuracy_without_padding: 0.2989 - val_custom_mse: 0.0581 - val_loss: 0.0617 - learning_rate: 0.0010
# Epoch 18/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3026 - custom_mse: 0.0576 - loss: 0.0612
# Epoch 18: val_loss improved from 0.06167 to 0.06107, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3039 - custom_mse: 0.0575 - loss: 0.0611 - val_custom_accuracy_without_padding: 0.3099 - val_custom_mse: 0.0575 - val_loss: 0.0611 - learning_rate: 0.0010
# Epoch 19/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3149 - custom_mse: 0.0569 - loss: 0.0606
# Epoch 19: val_loss improved from 0.06107 to 0.06036, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3136 - custom_mse: 0.0569 - loss: 0.0605 - val_custom_accuracy_without_padding: 0.3117 - val_custom_mse: 0.0569 - val_loss: 0.0604 - learning_rate: 0.0010
# Epoch 20/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3074 - custom_mse: 0.0559 - loss: 0.0595
# Epoch 20: val_loss improved from 0.06036 to 0.05979, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - custom_accuracy_without_padding: 0.3112 - custom_mse: 0.0560 - loss: 0.0596 - val_custom_accuracy_without_padding: 0.3165 - val_custom_mse: 0.0564 - val_loss: 0.0598 - learning_rate: 0.0010
# Epoch 21/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3243 - custom_mse: 0.0565 - loss: 0.0601
# Epoch 21: val_loss improved from 0.05979 to 0.05921, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.3234 - custom_mse: 0.0561 - loss: 0.0598 - val_custom_accuracy_without_padding: 0.3203 - val_custom_mse: 0.0558 - val_loss: 0.0592 - learning_rate: 0.0010
# Epoch 22/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3244 - custom_mse: 0.0547 - loss: 0.0584
# Epoch 22: val_loss improved from 0.05921 to 0.05863, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3245 - custom_mse: 0.0549 - loss: 0.0586 - val_custom_accuracy_without_padding: 0.3218 - val_custom_mse: 0.0552 - val_loss: 0.0586 - learning_rate: 0.0010
# Epoch 23/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3228 - custom_mse: 0.0542 - loss: 0.0578
# Epoch 23: val_loss improved from 0.05863 to 0.05828, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - custom_accuracy_without_padding: 0.3255 - custom_mse: 0.0544 - loss: 0.0580 - val_custom_accuracy_without_padding: 0.3264 - val_custom_mse: 0.0548 - val_loss: 0.0583 - learning_rate: 0.0010
# Epoch 24/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3316 - custom_mse: 0.0545 - loss: 0.0581
# Epoch 24: val_loss improved from 0.05828 to 0.05770, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.3340 - custom_mse: 0.0543 - loss: 0.0579 - val_custom_accuracy_without_padding: 0.3333 - val_custom_mse: 0.0543 - val_loss: 0.0577 - learning_rate: 0.0010
# Epoch 25/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3328 - custom_mse: 0.0536 - loss: 0.0572
# Epoch 25: val_loss improved from 0.05770 to 0.05704, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.3367 - custom_mse: 0.0536 - loss: 0.0572 - val_custom_accuracy_without_padding: 0.3388 - val_custom_mse: 0.0536 - val_loss: 0.0570 - learning_rate: 0.0010
# Epoch 26/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3460 - custom_mse: 0.0529 - loss: 0.0565
# Epoch 26: val_loss improved from 0.05704 to 0.05675, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.3463 - custom_mse: 0.0529 - loss: 0.0565 - val_custom_accuracy_without_padding: 0.3383 - val_custom_mse: 0.0534 - val_loss: 0.0567 - learning_rate: 0.0010
# Epoch 27/500
# 17/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.3523 - custom_mse: 0.0531 - loss: 0.0567
# Epoch 27: val_loss improved from 0.05675 to 0.05607, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.3532 - custom_mse: 0.0529 - loss: 0.0565 - val_custom_accuracy_without_padding: 0.3527 - val_custom_mse: 0.0527 - val_loss: 0.0561 - learning_rate: 0.0010
# Epoch 28/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3622 - custom_mse: 0.0510 - loss: 0.0545
# Epoch 28: val_loss improved from 0.05607 to 0.05556, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3624 - custom_mse: 0.0513 - loss: 0.0549 - val_custom_accuracy_without_padding: 0.3596 - val_custom_mse: 0.0522 - val_loss: 0.0556 - learning_rate: 0.0010
# Epoch 29/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3709 - custom_mse: 0.0523 - loss: 0.0558
# Epoch 29: val_loss improved from 0.05556 to 0.05513, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3710 - custom_mse: 0.0522 - loss: 0.0558 - val_custom_accuracy_without_padding: 0.3661 - val_custom_mse: 0.0518 - val_loss: 0.0551 - learning_rate: 0.0010
# Epoch 30/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3854 - custom_mse: 0.0516 - loss: 0.0552
# Epoch 30: val_loss improved from 0.05513 to 0.05473, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.3829 - custom_mse: 0.0513 - loss: 0.0549 - val_custom_accuracy_without_padding: 0.3771 - val_custom_mse: 0.0514 - val_loss: 0.0547 - learning_rate: 0.0010
# Epoch 31/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3897 - custom_mse: 0.0509 - loss: 0.0544
# Epoch 31: val_loss improved from 0.05473 to 0.05415, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3887 - custom_mse: 0.0507 - loss: 0.0543 - val_custom_accuracy_without_padding: 0.3848 - val_custom_mse: 0.0509 - val_loss: 0.0542 - learning_rate: 0.0010
# Epoch 32/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3865 - custom_mse: 0.0498 - loss: 0.0534
# Epoch 32: val_loss improved from 0.05415 to 0.05377, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3870 - custom_mse: 0.0498 - loss: 0.0534 - val_custom_accuracy_without_padding: 0.3834 - val_custom_mse: 0.0505 - val_loss: 0.0538 - learning_rate: 0.0010
# Epoch 33/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.3941 - custom_mse: 0.0491 - loss: 0.0527
# Epoch 33: val_loss improved from 0.05377 to 0.05363, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.3959 - custom_mse: 0.0493 - loss: 0.0528 - val_custom_accuracy_without_padding: 0.3924 - val_custom_mse: 0.0504 - val_loss: 0.0536 - learning_rate: 0.0010
# Epoch 34/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.4018 - custom_mse: 0.0497 - loss: 0.0533
# Epoch 34: val_loss improved from 0.05363 to 0.05286, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.4019 - custom_mse: 0.0497 - loss: 0.0533 - val_custom_accuracy_without_padding: 0.4006 - val_custom_mse: 0.0496 - val_loss: 0.0529 - learning_rate: 0.0010
# Epoch 35/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.4078 - custom_mse: 0.0487 - loss: 0.0522
# Epoch 35: val_loss improved from 0.05286 to 0.05240, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.4085 - custom_mse: 0.0487 - loss: 0.0523 - val_custom_accuracy_without_padding: 0.4077 - val_custom_mse: 0.0491 - val_loss: 0.0524 - learning_rate: 0.0010
# Epoch 36/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.4158 - custom_mse: 0.0480 - loss: 0.0515
# Epoch 36: val_loss improved from 0.05240 to 0.05210, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.4171 - custom_mse: 0.0481 - loss: 0.0516 - val_custom_accuracy_without_padding: 0.4233 - val_custom_mse: 0.0489 - val_loss: 0.0521 - learning_rate: 0.0010
# Epoch 37/500
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.4200 - custom_mse: 0.0484 - loss: 0.0519
# Epoch 37: val_loss improved from 0.05210 to 0.05172, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_accuracy_without_padding: 0.4235 - custom_mse: 0.0483 - loss: 0.0518 - val_custom_accuracy_without_padding: 0.4307 - val_custom_mse: 0.0486 - val_loss: 0.0517 - learning_rate: 0.0010
# Epoch 38/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.4446 - custom_mse: 0.0474 - loss: 0.0509
# Epoch 38: val_loss improved from 0.05172 to 0.05141, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - custom_accuracy_without_padding: 0.4437 - custom_mse: 0.0475 - loss: 0.0510 - val_custom_accuracy_without_padding: 0.4401 - val_custom_mse: 0.0483 - val_loss: 0.0514 - learning_rate: 0.0010
# Epoch 39/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.4487 - custom_mse: 0.0471 - loss: 0.0506
# Epoch 39: val_loss improved from 0.05141 to 0.05102, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.4499 - custom_mse: 0.0472 - loss: 0.0506 - val_custom_accuracy_without_padding: 0.4453 - val_custom_mse: 0.0479 - val_loss: 0.0510 - learning_rate: 0.0010
# Epoch 40/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.4554 - custom_mse: 0.0463 - loss: 0.0498
# Epoch 40: val_loss improved from 0.05102 to 0.05058, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.4559 - custom_mse: 0.0466 - loss: 0.0501 - val_custom_accuracy_without_padding: 0.4547 - val_custom_mse: 0.0474 - val_loss: 0.0506 - learning_rate: 0.0010
# Epoch 41/500
# 17/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.4668 - custom_mse: 0.0466 - loss: 0.0501
# Epoch 41: val_loss improved from 0.05058 to 0.05027, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.4669 - custom_mse: 0.0466 - loss: 0.0501 - val_custom_accuracy_without_padding: 0.4645 - val_custom_mse: 0.0472 - val_loss: 0.0503 - learning_rate: 0.0010
# Epoch 42/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.4782 - custom_mse: 0.0470 - loss: 0.0504
# Epoch 42: val_loss improved from 0.05027 to 0.04973, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.4768 - custom_mse: 0.0468 - loss: 0.0502 - val_custom_accuracy_without_padding: 0.4676 - val_custom_mse: 0.0466 - val_loss: 0.0497 - learning_rate: 0.0010
# Epoch 43/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.4741 - custom_mse: 0.0463 - loss: 0.0497
# Epoch 43: val_loss did not improve from 0.04973
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.4748 - custom_mse: 0.0462 - loss: 0.0497 - val_custom_accuracy_without_padding: 0.4754 - val_custom_mse: 0.0467 - val_loss: 0.0498 - learning_rate: 0.0010
# Epoch 44/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.4823 - custom_mse: 0.0454 - loss: 0.0489
# Epoch 44: val_loss improved from 0.04973 to 0.04925, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.4827 - custom_mse: 0.0455 - loss: 0.0489 - val_custom_accuracy_without_padding: 0.4745 - val_custom_mse: 0.0462 - val_loss: 0.0492 - learning_rate: 0.0010
# Epoch 45/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.4958 - custom_mse: 0.0453 - loss: 0.0487
# Epoch 45: val_loss improved from 0.04925 to 0.04892, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.4959 - custom_mse: 0.0453 - loss: 0.0487 - val_custom_accuracy_without_padding: 0.4916 - val_custom_mse: 0.0459 - val_loss: 0.0489 - learning_rate: 0.0010
# Epoch 46/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5018 - custom_mse: 0.0449 - loss: 0.0483
# Epoch 46: val_loss improved from 0.04892 to 0.04839, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - custom_accuracy_without_padding: 0.5035 - custom_mse: 0.0450 - loss: 0.0483 - val_custom_accuracy_without_padding: 0.4962 - val_custom_mse: 0.0453 - val_loss: 0.0484 - learning_rate: 0.0010
# Epoch 47/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.5092 - custom_mse: 0.0453 - loss: 0.0486
# Epoch 47: val_loss improved from 0.04839 to 0.04833, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5098 - custom_mse: 0.0451 - loss: 0.0485 - val_custom_accuracy_without_padding: 0.4959 - val_custom_mse: 0.0453 - val_loss: 0.0483 - learning_rate: 0.0010
# Epoch 48/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5159 - custom_mse: 0.0438 - loss: 0.0471
# Epoch 48: val_loss improved from 0.04833 to 0.04795, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5160 - custom_mse: 0.0440 - loss: 0.0474 - val_custom_accuracy_without_padding: 0.5058 - val_custom_mse: 0.0450 - val_loss: 0.0480 - learning_rate: 0.0010
# Epoch 49/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5185 - custom_mse: 0.0441 - loss: 0.0474
# Epoch 49: val_loss improved from 0.04795 to 0.04756, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5184 - custom_mse: 0.0443 - loss: 0.0476 - val_custom_accuracy_without_padding: 0.5175 - val_custom_mse: 0.0446 - val_loss: 0.0476 - learning_rate: 0.0010
# Epoch 50/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.5233 - custom_mse: 0.0443 - loss: 0.0476
# Epoch 50: val_loss improved from 0.04756 to 0.04723, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.5241 - custom_mse: 0.0442 - loss: 0.0474 - val_custom_accuracy_without_padding: 0.5162 - val_custom_mse: 0.0442 - val_loss: 0.0472 - learning_rate: 0.0010
# Epoch 51/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.5321 - custom_mse: 0.0436 - loss: 0.0468
# Epoch 51: val_loss improved from 0.04723 to 0.04721, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5315 - custom_mse: 0.0436 - loss: 0.0469 - val_custom_accuracy_without_padding: 0.5210 - val_custom_mse: 0.0443 - val_loss: 0.0472 - learning_rate: 0.0010
# Epoch 52/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.5342 - custom_mse: 0.0445 - loss: 0.0477
# Epoch 52: val_loss improved from 0.04721 to 0.04667, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5341 - custom_mse: 0.0441 - loss: 0.0474 - val_custom_accuracy_without_padding: 0.5281 - val_custom_mse: 0.0438 - val_loss: 0.0467 - learning_rate: 0.0010
# Epoch 53/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5347 - custom_mse: 0.0429 - loss: 0.0461
# Epoch 53: val_loss improved from 0.04667 to 0.04649, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5347 - custom_mse: 0.0431 - loss: 0.0463 - val_custom_accuracy_without_padding: 0.5279 - val_custom_mse: 0.0436 - val_loss: 0.0465 - learning_rate: 0.0010
# Epoch 54/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5389 - custom_mse: 0.0437 - loss: 0.0469
# Epoch 54: val_loss improved from 0.04649 to 0.04609, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5395 - custom_mse: 0.0434 - loss: 0.0466 - val_custom_accuracy_without_padding: 0.5352 - val_custom_mse: 0.0433 - val_loss: 0.0461 - learning_rate: 0.0010
# Epoch 55/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5447 - custom_mse: 0.0420 - loss: 0.0451
# Epoch 55: val_loss improved from 0.04609 to 0.04581, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5445 - custom_mse: 0.0422 - loss: 0.0454 - val_custom_accuracy_without_padding: 0.5367 - val_custom_mse: 0.0429 - val_loss: 0.0458 - learning_rate: 0.0010
# Epoch 56/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5449 - custom_mse: 0.0426 - loss: 0.0458
# Epoch 56: val_loss did not improve from 0.04581
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.5455 - custom_mse: 0.0426 - loss: 0.0457 - val_custom_accuracy_without_padding: 0.5402 - val_custom_mse: 0.0430 - val_loss: 0.0459 - learning_rate: 0.0010
# Epoch 57/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.5458 - custom_mse: 0.0426 - loss: 0.0457
# Epoch 57: val_loss improved from 0.04581 to 0.04512, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.5472 - custom_mse: 0.0425 - loss: 0.0456 - val_custom_accuracy_without_padding: 0.5478 - val_custom_mse: 0.0423 - val_loss: 0.0451 - learning_rate: 0.0010
# Epoch 58/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5553 - custom_mse: 0.0419 - loss: 0.0450
# Epoch 58: val_loss improved from 0.04512 to 0.04504, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5551 - custom_mse: 0.0420 - loss: 0.0450 - val_custom_accuracy_without_padding: 0.5488 - val_custom_mse: 0.0422 - val_loss: 0.0450 - learning_rate: 0.0010
# Epoch 59/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5589 - custom_mse: 0.0414 - loss: 0.0444
# Epoch 59: val_loss improved from 0.04504 to 0.04491, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5584 - custom_mse: 0.0415 - loss: 0.0446 - val_custom_accuracy_without_padding: 0.5493 - val_custom_mse: 0.0421 - val_loss: 0.0449 - learning_rate: 0.0010
# Epoch 60/500
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.5603 - custom_mse: 0.0419 - loss: 0.0449
# Epoch 60: val_loss improved from 0.04491 to 0.04468, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_accuracy_without_padding: 0.5605 - custom_mse: 0.0419 - loss: 0.0449 - val_custom_accuracy_without_padding: 0.5570 - val_custom_mse: 0.0418 - val_loss: 0.0447 - learning_rate: 0.0010
# Epoch 61/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5658 - custom_mse: 0.0414 - loss: 0.0445
# Epoch 61: val_loss improved from 0.04468 to 0.04454, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5644 - custom_mse: 0.0415 - loss: 0.0445 - val_custom_accuracy_without_padding: 0.5567 - val_custom_mse: 0.0417 - val_loss: 0.0445 - learning_rate: 0.0010
# Epoch 62/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5647 - custom_mse: 0.0422 - loss: 0.0452
# Epoch 62: val_loss improved from 0.04454 to 0.04416, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5656 - custom_mse: 0.0419 - loss: 0.0449 - val_custom_accuracy_without_padding: 0.5610 - val_custom_mse: 0.0414 - val_loss: 0.0442 - learning_rate: 0.0010
# Epoch 63/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5722 - custom_mse: 0.0417 - loss: 0.0446
# Epoch 63: val_loss did not improve from 0.04416
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.5709 - custom_mse: 0.0415 - loss: 0.0444 - val_custom_accuracy_without_padding: 0.5660 - val_custom_mse: 0.0418 - val_loss: 0.0446 - learning_rate: 0.0010
# Epoch 64/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5723 - custom_mse: 0.0403 - loss: 0.0432
# Epoch 64: val_loss improved from 0.04416 to 0.04396, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5721 - custom_mse: 0.0406 - loss: 0.0435 - val_custom_accuracy_without_padding: 0.5703 - val_custom_mse: 0.0413 - val_loss: 0.0440 - learning_rate: 0.0010
# Epoch 65/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5787 - custom_mse: 0.0406 - loss: 0.0435
# Epoch 65: val_loss improved from 0.04396 to 0.04368, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.5785 - custom_mse: 0.0407 - loss: 0.0436 - val_custom_accuracy_without_padding: 0.5729 - val_custom_mse: 0.0410 - val_loss: 0.0437 - learning_rate: 0.0010
# Epoch 66/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5758 - custom_mse: 0.0418 - loss: 0.0446
# Epoch 66: val_loss improved from 0.04368 to 0.04342, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.5775 - custom_mse: 0.0414 - loss: 0.0442 - val_custom_accuracy_without_padding: 0.5780 - val_custom_mse: 0.0408 - val_loss: 0.0434 - learning_rate: 0.0010
# Epoch 67/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.5821 - custom_mse: 0.0398 - loss: 0.0426
# Epoch 67: val_loss improved from 0.04342 to 0.04334, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5821 - custom_mse: 0.0400 - loss: 0.0428 - val_custom_accuracy_without_padding: 0.5785 - val_custom_mse: 0.0407 - val_loss: 0.0433 - learning_rate: 0.0010
# Epoch 68/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5873 - custom_mse: 0.0400 - loss: 0.0428
# Epoch 68: val_loss improved from 0.04334 to 0.04303, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5853 - custom_mse: 0.0402 - loss: 0.0430 - val_custom_accuracy_without_padding: 0.5771 - val_custom_mse: 0.0403 - val_loss: 0.0430 - learning_rate: 0.0010
# Epoch 69/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5853 - custom_mse: 0.0398 - loss: 0.0426
# Epoch 69: val_loss improved from 0.04303 to 0.04303, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.5853 - custom_mse: 0.0398 - loss: 0.0426 - val_custom_accuracy_without_padding: 0.5779 - val_custom_mse: 0.0404 - val_loss: 0.0430 - learning_rate: 0.0010
# Epoch 70/500
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.5845 - custom_mse: 0.0401 - loss: 0.0429
# Epoch 70: val_loss did not improve from 0.04303
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.5859 - custom_mse: 0.0402 - loss: 0.0429 - val_custom_accuracy_without_padding: 0.5838 - val_custom_mse: 0.0406 - val_loss: 0.0432 - learning_rate: 0.0010
# Epoch 71/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.5895 - custom_mse: 0.0406 - loss: 0.0433
# Epoch 71: val_loss improved from 0.04303 to 0.04275, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - custom_accuracy_without_padding: 0.5899 - custom_mse: 0.0405 - loss: 0.0432 - val_custom_accuracy_without_padding: 0.5876 - val_custom_mse: 0.0402 - val_loss: 0.0427 - learning_rate: 0.0010
# Epoch 72/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.5933 - custom_mse: 0.0393 - loss: 0.0421
# Epoch 72: val_loss improved from 0.04275 to 0.04251, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - custom_accuracy_without_padding: 0.5930 - custom_mse: 0.0394 - loss: 0.0421 - val_custom_accuracy_without_padding: 0.5911 - val_custom_mse: 0.0400 - val_loss: 0.0425 - learning_rate: 0.0010
# Epoch 73/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5912 - custom_mse: 0.0397 - loss: 0.0424
# Epoch 73: val_loss did not improve from 0.04251
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.5913 - custom_mse: 0.0397 - loss: 0.0424 - val_custom_accuracy_without_padding: 0.5931 - val_custom_mse: 0.0400 - val_loss: 0.0425 - learning_rate: 0.0010
# Epoch 74/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6037 - custom_mse: 0.0388 - loss: 0.0414
# Epoch 74: val_loss improved from 0.04251 to 0.04218, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5997 - custom_mse: 0.0391 - loss: 0.0418 - val_custom_accuracy_without_padding: 0.5936 - val_custom_mse: 0.0396 - val_loss: 0.0422 - learning_rate: 0.0010
# Epoch 75/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5914 - custom_mse: 0.0404 - loss: 0.0430
# Epoch 75: val_loss improved from 0.04218 to 0.04180, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5926 - custom_mse: 0.0400 - loss: 0.0426 - val_custom_accuracy_without_padding: 0.5938 - val_custom_mse: 0.0394 - val_loss: 0.0418 - learning_rate: 0.0010
# Epoch 76/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5971 - custom_mse: 0.0388 - loss: 0.0414
# Epoch 76: val_loss improved from 0.04180 to 0.04172, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.5971 - custom_mse: 0.0388 - loss: 0.0414 - val_custom_accuracy_without_padding: 0.5924 - val_custom_mse: 0.0392 - val_loss: 0.0417 - learning_rate: 0.0010
# Epoch 77/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5959 - custom_mse: 0.0394 - loss: 0.0420
# Epoch 77: val_loss did not improve from 0.04172
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.5958 - custom_mse: 0.0392 - loss: 0.0418 - val_custom_accuracy_without_padding: 0.5933 - val_custom_mse: 0.0394 - val_loss: 0.0419 - learning_rate: 0.0010
# Epoch 78/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5942 - custom_mse: 0.0390 - loss: 0.0415
# Epoch 78: val_loss did not improve from 0.04172
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.5943 - custom_mse: 0.0390 - loss: 0.0415 - val_custom_accuracy_without_padding: 0.5949 - val_custom_mse: 0.0394 - val_loss: 0.0418 - learning_rate: 0.0010
# Epoch 79/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5974 - custom_mse: 0.0386 - loss: 0.0411
# Epoch 79: val_loss improved from 0.04172 to 0.04113, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.5974 - custom_mse: 0.0386 - loss: 0.0411 - val_custom_accuracy_without_padding: 0.5938 - val_custom_mse: 0.0388 - val_loss: 0.0411 - learning_rate: 0.0010
# Epoch 80/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5948 - custom_mse: 0.0385 - loss: 0.0410
# Epoch 80: val_loss did not improve from 0.04113
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.5961 - custom_mse: 0.0387 - loss: 0.0412 - val_custom_accuracy_without_padding: 0.5982 - val_custom_mse: 0.0392 - val_loss: 0.0414 - learning_rate: 0.0010
# Epoch 81/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5986 - custom_mse: 0.0386 - loss: 0.0411
# Epoch 81: val_loss improved from 0.04113 to 0.04082, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5991 - custom_mse: 0.0385 - loss: 0.0410 - val_custom_accuracy_without_padding: 0.5966 - val_custom_mse: 0.0385 - val_loss: 0.0408 - learning_rate: 0.0010
# Epoch 82/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6012 - custom_mse: 0.0386 - loss: 0.0411
# Epoch 82: val_loss improved from 0.04082 to 0.04070, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.6007 - custom_mse: 0.0385 - loss: 0.0410 - val_custom_accuracy_without_padding: 0.6010 - val_custom_mse: 0.0384 - val_loss: 0.0407 - learning_rate: 0.0010
# Epoch 83/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6016 - custom_mse: 0.0383 - loss: 0.0407
# Epoch 83: val_loss did not improve from 0.04070
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.6017 - custom_mse: 0.0383 - loss: 0.0407 - val_custom_accuracy_without_padding: 0.6002 - val_custom_mse: 0.0386 - val_loss: 0.0409 - learning_rate: 0.0010
# Epoch 84/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6026 - custom_mse: 0.0386 - loss: 0.0410
# Epoch 84: val_loss did not improve from 0.04070
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.6027 - custom_mse: 0.0384 - loss: 0.0408 - val_custom_accuracy_without_padding: 0.6030 - val_custom_mse: 0.0386 - val_loss: 0.0407 - learning_rate: 0.0010
# Epoch 85/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6018 - custom_mse: 0.0376 - loss: 0.0399
# Epoch 85: val_loss improved from 0.04070 to 0.04056, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.6020 - custom_mse: 0.0378 - loss: 0.0402 - val_custom_accuracy_without_padding: 0.5994 - val_custom_mse: 0.0383 - val_loss: 0.0406 - learning_rate: 0.0010
# Epoch 86/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6033 - custom_mse: 0.0383 - loss: 0.0406
# Epoch 86: val_loss improved from 0.04056 to 0.04054, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.6036 - custom_mse: 0.0381 - loss: 0.0405 - val_custom_accuracy_without_padding: 0.6062 - val_custom_mse: 0.0383 - val_loss: 0.0405 - learning_rate: 0.0010
# Epoch 87/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6076 - custom_mse: 0.0376 - loss: 0.0399
# Epoch 87: val_loss improved from 0.04054 to 0.04052, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.6066 - custom_mse: 0.0378 - loss: 0.0401 - val_custom_accuracy_without_padding: 0.6113 - val_custom_mse: 0.0385 - val_loss: 0.0405 - learning_rate: 0.0010
# Epoch 88/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - custom_accuracy_without_padding: 0.6073 - custom_mse: 0.0374 - loss: 0.0397
# Epoch 88: val_loss improved from 0.04052 to 0.04035, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.6075 - custom_mse: 0.0374 - loss: 0.0398 - val_custom_accuracy_without_padding: 0.6050 - val_custom_mse: 0.0382 - val_loss: 0.0404 - learning_rate: 0.0010
# Epoch 89/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6160 - custom_mse: 0.0370 - loss: 0.0393
# Epoch 89: val_loss improved from 0.04035 to 0.03982, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.6142 - custom_mse: 0.0372 - loss: 0.0395 - val_custom_accuracy_without_padding: 0.6104 - val_custom_mse: 0.0377 - val_loss: 0.0398 - learning_rate: 0.0010
# Epoch 90/500
# 11/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.6142 - custom_mse: 0.0375 - loss: 0.0398
# Epoch 90: val_loss improved from 0.03982 to 0.03977, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.6134 - custom_mse: 0.0373 - loss: 0.0396 - val_custom_accuracy_without_padding: 0.6098 - val_custom_mse: 0.0375 - val_loss: 0.0398 - learning_rate: 0.0010
# Epoch 91/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6169 - custom_mse: 0.0370 - loss: 0.0392
# Epoch 91: val_loss improved from 0.03977 to 0.03925, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# ...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_accuracy_without_padding: 0.7134 - custom_mse: 0.0274 - loss: 0.0288 - val_custom_accuracy_without_padding: 0.7080 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 6.2500e-05
# Epoch 195/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7124 - custom_mse: 0.0279 - loss: 0.0292
# Epoch 195: val_loss did not improve from 0.02852
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7128 - custom_mse: 0.0276 - loss: 0.0290 - val_custom_accuracy_without_padding: 0.7085 - val_custom_mse: 0.0272 - val_loss: 0.0285 - learning_rate: 6.2500e-05
# Epoch 196/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7074 - custom_mse: 0.0275 - loss: 0.0288
# Epoch 196: val_loss improved from 0.02852 to 0.02852, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_accuracy_without_padding: 0.7079 - custom_mse: 0.0275 - loss: 0.0288 - val_custom_accuracy_without_padding: 0.7090 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 6.2500e-05
# Epoch 197/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7130 - custom_mse: 0.0269 - loss: 0.0282
# Epoch 197: val_loss improved from 0.02852 to 0.02851, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - custom_accuracy_without_padding: 0.7128 - custom_mse: 0.0269 - loss: 0.0283 - val_custom_accuracy_without_padding: 0.7090 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 6.2500e-05
# Epoch 198/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7127 - custom_mse: 0.0273 - loss: 0.0286
# Epoch 198: val_loss improved from 0.02851 to 0.02850, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.7127 - custom_mse: 0.0273 - loss: 0.0286 - val_custom_accuracy_without_padding: 0.7082 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 6.2500e-05
# Epoch 199/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7118 - custom_mse: 0.0273 - loss: 0.0287
# Epoch 199: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 199: val_loss did not improve from 0.02850
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7119 - custom_mse: 0.0273 - loss: 0.0287 - val_custom_accuracy_without_padding: 0.7067 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 6.2500e-05
# Epoch 200/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7122 - custom_mse: 0.0272 - loss: 0.0285
# Epoch 200: val_loss improved from 0.02850 to 0.02848, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_accuracy_without_padding: 0.7121 - custom_mse: 0.0272 - loss: 0.0285 - val_custom_accuracy_without_padding: 0.7083 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 3.1250e-05
# Epoch 201/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7113 - custom_mse: 0.0276 - loss: 0.0290
# Epoch 201: val_loss did not improve from 0.02848
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - custom_accuracy_without_padding: 0.7112 - custom_mse: 0.0276 - loss: 0.0289 - val_custom_accuracy_without_padding: 0.7070 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 3.1250e-05
# Epoch 202/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7115 - custom_mse: 0.0275 - loss: 0.0289
# Epoch 202: val_loss improved from 0.02848 to 0.02847, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.7116 - custom_mse: 0.0275 - loss: 0.0288 - val_custom_accuracy_without_padding: 0.7077 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 3.1250e-05
# Epoch 203/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.7092 - custom_mse: 0.0275 - loss: 0.0289
# Epoch 203: val_loss did not improve from 0.02847
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.7094 - custom_mse: 0.0275 - loss: 0.0289 - val_custom_accuracy_without_padding: 0.7083 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 3.1250e-05
# Epoch 204/500
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.7116 - custom_mse: 0.0278 - loss: 0.0291
# Epoch 204: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 204: val_loss did not improve from 0.02847
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.7115 - custom_mse: 0.0276 - loss: 0.0290 - val_custom_accuracy_without_padding: 0.7082 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 3.1250e-05
# Epoch 205/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7140 - custom_mse: 0.0270 - loss: 0.0284
# Epoch 205: val_loss improved from 0.02847 to 0.02846, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_accuracy_without_padding: 0.7138 - custom_mse: 0.0271 - loss: 0.0284 - val_custom_accuracy_without_padding: 0.7080 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 1.5625e-05
# Epoch 206/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7121 - custom_mse: 0.0269 - loss: 0.0282
# Epoch 206: val_loss did not improve from 0.02846
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.7120 - custom_mse: 0.0269 - loss: 0.0283 - val_custom_accuracy_without_padding: 0.7080 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 1.5625e-05
# Epoch 207/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7126 - custom_mse: 0.0273 - loss: 0.0287
# Epoch 207: val_loss did not improve from 0.02846
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.7126 - custom_mse: 0.0273 - loss: 0.0287 - val_custom_accuracy_without_padding: 0.7072 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 1.5625e-05
# Epoch 208/500
# 12/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7109 - custom_mse: 0.0276 - loss: 0.0289
# Epoch 208: val_loss did not improve from 0.02846
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7109 - custom_mse: 0.0274 - loss: 0.0287 - val_custom_accuracy_without_padding: 0.7073 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 1.5625e-05
# Epoch 209/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7135 - custom_mse: 0.0266 - loss: 0.0279
# Epoch 209: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 209: val_loss improved from 0.02846 to 0.02845, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.7128 - custom_mse: 0.0268 - loss: 0.0282 - val_custom_accuracy_without_padding: 0.7080 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 1.5625e-05
# Epoch 210/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7127 - custom_mse: 0.0272 - loss: 0.0286
# Epoch 210: val_loss did not improve from 0.02845
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7125 - custom_mse: 0.0272 - loss: 0.0286 - val_custom_accuracy_without_padding: 0.7077 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 7.8125e-06
# Epoch 211/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7114 - custom_mse: 0.0282 - loss: 0.0295
# Epoch 211: val_loss improved from 0.02845 to 0.02845, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.7110 - custom_mse: 0.0278 - loss: 0.0291 - val_custom_accuracy_without_padding: 0.7077 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 7.8125e-06
# Epoch 212/500
# 12/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7108 - custom_mse: 0.0270 - loss: 0.0283
# Epoch 212: val_loss did not improve from 0.02845
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7113 - custom_mse: 0.0270 - loss: 0.0284 - val_custom_accuracy_without_padding: 0.7077 - val_custom_mse: 0.0271 - val_loss: 0.0285 - learning_rate: 7.8125e-06
# Epoch 213/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7146 - custom_mse: 0.0273 - loss: 0.0286
# Epoch 213: val_loss improved from 0.02845 to 0.02845, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.7131 - custom_mse: 0.0273 - loss: 0.0286 - val_custom_accuracy_without_padding: 0.7078 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 7.8125e-06
# Epoch 214/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7111 - custom_mse: 0.0269 - loss: 0.0282
# Epoch 214: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 214: val_loss did not improve from 0.02845
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7111 - custom_mse: 0.0269 - loss: 0.0283 - val_custom_accuracy_without_padding: 0.7080 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 7.8125e-06
# Epoch 215/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7103 - custom_mse: 0.0274 - loss: 0.0288
# Epoch 215: val_loss improved from 0.02845 to 0.02845, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.7104 - custom_mse: 0.0274 - loss: 0.0287 - val_custom_accuracy_without_padding: 0.7080 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 3.9063e-06
# Epoch 216/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7119 - custom_mse: 0.0274 - loss: 0.0288
# Epoch 216: val_loss did not improve from 0.02845
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7118 - custom_mse: 0.0274 - loss: 0.0287 - val_custom_accuracy_without_padding: 0.7077 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 3.9063e-06
# Epoch 217/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7098 - custom_mse: 0.0273 - loss: 0.0286
# Epoch 217: val_loss improved from 0.02845 to 0.02844, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.7099 - custom_mse: 0.0273 - loss: 0.0286 - val_custom_accuracy_without_padding: 0.7075 - val_custom_mse: 0.0270 - val_loss: 0.0284 - learning_rate: 3.9063e-06
# Epoch 218/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7122 - custom_mse: 0.0270 - loss: 0.0284
# Epoch 218: val_loss did not improve from 0.02844
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7119 - custom_mse: 0.0271 - loss: 0.0285 - val_custom_accuracy_without_padding: 0.7075 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 3.9063e-06
# Epoch 219/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7153 - custom_mse: 0.0265 - loss: 0.0279
# Epoch 219: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 219: val_loss did not improve from 0.02844
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7134 - custom_mse: 0.0269 - loss: 0.0282 - val_custom_accuracy_without_padding: 0.7072 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 3.9063e-06
# Epoch 220/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7072 - custom_mse: 0.0275 - loss: 0.0288
# Epoch 220: val_loss did not improve from 0.02844
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7088 - custom_mse: 0.0275 - loss: 0.0288 - val_custom_accuracy_without_padding: 0.7080 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 1.9531e-06
# Epoch 221/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7131 - custom_mse: 0.0270 - loss: 0.0284
# Epoch 221: val_loss did not improve from 0.02844
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.7130 - custom_mse: 0.0270 - loss: 0.0284 - val_custom_accuracy_without_padding: 0.7075 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 1.9531e-06
# Epoch 222/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7114 - custom_mse: 0.0275 - loss: 0.0288
# Epoch 222: val_loss did not improve from 0.02844
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7114 - custom_mse: 0.0274 - loss: 0.0288 - val_custom_accuracy_without_padding: 0.7077 - val_custom_mse: 0.0270 - val_loss: 0.0284 - learning_rate: 1.9531e-06
# Epoch 223/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7102 - custom_mse: 0.0272 - loss: 0.0285
# Epoch 223: val_loss did not improve from 0.02844
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7104 - custom_mse: 0.0272 - loss: 0.0285 - val_custom_accuracy_without_padding: 0.7078 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 1.9531e-06
# Epoch 224/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7087 - custom_mse: 0.0274 - loss: 0.0288
# Epoch 224: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 224: val_loss did not improve from 0.02844
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.7098 - custom_mse: 0.0273 - loss: 0.0287 - val_custom_accuracy_without_padding: 0.7080 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 1.9531e-06
# Epoch 225/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7082 - custom_mse: 0.0277 - loss: 0.0290
# Epoch 225: val_loss did not improve from 0.02844
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.7089 - custom_mse: 0.0275 - loss: 0.0289 - val_custom_accuracy_without_padding: 0.7078 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 9.7656e-07
# Epoch 226/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7116 - custom_mse: 0.0272 - loss: 0.0285
# Epoch 226: val_loss did not improve from 0.02844
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7116 - custom_mse: 0.0272 - loss: 0.0285 - val_custom_accuracy_without_padding: 0.7080 - val_custom_mse: 0.0271 - val_loss: 0.0284 - learning_rate: 9.7656e-07
# Epoch 227/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7093 - custom_mse: 0.0275 - loss: 0.0288
# Epoch 227: val_loss did not improve from 0.02844
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.7094 - custom_mse: 0.0275 - loss: 0.0288 - val_custom_accuracy_without_padding: 0.7075 - val_custom_mse: 0.0270 - val_loss: 0.0284 - learning_rate: 9.7656e-07

# %%
# Evaluate the model on the test set
eval_results = model.evaluate(X_test, y_test)
print(f"Test results - Loss: {eval_results[0]}, MSE: {eval_results[1]}, Accuracy: {eval_results[2]}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.7091 - custom_mse: 0.0266 - loss: 0.0279
# Test results - Loss: 0.02844047360122204, MSE: 0.027049710974097252, Accuracy: 0.7075065970420837

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['custom_accuracy_without_padding'], label='Training Accuracy')
plt.plot(history.history['val_custom_accuracy_without_padding'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.show()

# %%
y_pred = model.predict(X_test)
y_test_rescaled = y_test * (q - 1)
y_pred_rescaled = y_pred * (q - 1)

print("Comparison of predictions and ground truth:")
for i in range(3):
    print(f"Sample {i+1}:")
    print(f"  Predicted:    {np.round(y_pred_rescaled[i]).astype(int)}")
    print(f"  Ground Truth: {np.round(y_test_rescaled[i]).astype(int)}")
    print("-" * 40)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step
# Comparison of predictions and ground truth:
# Sample 1:
#   Predicted:    [3 3 3 3 3 3 3 3 4 2 3 1 4 0 3 2 5 1 4 3 4 4 6 5 2 3 1 0 0 0 0 0]
#   Ground Truth: [5 6 5 1 3 4 1 1 6 2 3 1 4 0 3 2 5 1 4 3 4 4 6 5 2 3 1 0 0 0 0 0]
# ----------------------------------------
# Sample 2:
#   Predicted:    [3 3 3 3 3 3 3 3 3 2 4 3 3 1 3 1 1 2 0 1 1 5 2 1 4 0 4 0 0 0 0 0]
#   Ground Truth: [1 4 1 3 3 3 0 5 5 2 4 3 3 1 3 1 1 2 0 1 1 5 2 1 4 0 4 0 0 0 0 0]
# ----------------------------------------
# Sample 3:
#   Predicted:    [3 3 3 3 3 3 3 3 3 6 4 1 0 5 2 3 5 1 4 6 0 4 3 2 3 4 4 0 0 0 0 0]
#   Ground Truth: [2 6 0 2 2 1 3 4 2 6 4 1 0 5 2 3 5 1 4 6 0 4 3 2 3 4 4 0 0 0 0 0]
# ----------------------------------------

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)

print(f"R² Score: {r2:.4f}")
# Out:
# R² Score: 0.6008

# %%
# ---------------------- Inference time on Test Set ----------------------------

import time

_ = model.predict(X_test, verbose=0)  # warm up

times = []
for _ in range(100):
    start = time.perf_counter()
    _ = model.predict(X_test, verbose=0)
    end = time.perf_counter()
    times.append(end - start)

average_inference_time = np.mean(times)
print(f"Average batch inference time over 100 runs: {average_inference_time:.6f} seconds")

average_per_sample = average_inference_time / X_test.shape[0]
print(f"Average inference time per sample (from batch): {average_per_sample:.6f} seconds")
# Out:
# Average batch inference time over 100 runs: 0.078583 seconds
# Average inference time per sample (from batch): 0.000393 seconds

# %% [markdown]
# Test on unseen samples

# %%
# --------------------- Predictions on unseen samples (no noise) -------------------------

np.random.seed(42)

x_unseen_original = np.random.randint(0, q, size=(num_unseen_samples, n))
x_unseen_original_padded = np.pad(x_unseen_original, ((0, 0), (0, padding)), mode='constant', constant_values=0)

# encode
encoded_dataset_unseen = np.array([np.dot(M_tilde, x) for x in x_unseen_original_padded])
encoded_dataset_unseen[np.abs(encoded_dataset_unseen) < 1e-10] = 0
encoded_dataset_unseen = np.round(encoded_dataset_unseen, decimals=10)

# pre-process
N = encoded_dataset_unseen.shape[1]
k = np.arange(N)
shift = np.exp(-1j * np.pi * k / (2 * N))
alpha_k = np.where(k == 0, np.sqrt(1/N), np.sqrt(2/N))

x_unseen_dct2 = np.array([np.real(alpha_k * shift * y) for y in encoded_dataset_unseen])
x_unseen_dct2[np.abs(x_unseen_dct2) < 1e-10] = 0
x_unseen_dct2 = np.round(x_unseen_dct2, decimals=10)

# Normalize
x_unseen_dct2_normalized = (x_unseen_dct2 - x_unseen_dct2.mean()) / x_unseen_dct2.std()

# Predict
nn_pred = model.predict(x_unseen_dct2_normalized)

# Rescale prediction
y_pred_final = np.mod(np.round(nn_pred * (q - 1)), q)

# Evaluate
x_unseen_original_padded_normalized = x_unseen_original_padded.astype(np.float32) / (q - 1)

mse_nn = custom_mse(x_unseen_original_padded_normalized, nn_pred)
acc_nn = custom_accuracy_without_padding(x_unseen_original_padded_normalized, nn_pred)

print(f"MSE on unseen data (no noise): {mse_nn}")
print(f"Accuracy on unseen data (no noise): {acc_nn}")

num_display_samples = 3
for i in range(num_display_samples):
    print(f"\nSample {i+1}:")
    print(f"Original : {x_unseen_original_padded[i]}")
    print(f"NN Pred  : {y_pred_final[i].astype(int)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# MSE on unseen data (no noise): 0.027900228276848793
# Accuracy on unseen data (no noise): 0.7222222089767456
#
# Sample 1:
# Original : [6 3 4 6 2 4 4 6 1 2 6 2 2 4 3 2 5 4 1 3 5 5 1 3 4 0 3 0 0 0 0 0]
# NN Pred  : [3 3 3 3 3 3 3 4 2 2 6 2 2 4 3 2 5 4 1 3 5 5 1 3 4 0 3 0 0 0 0 0]
#
# Sample 2:
# Original : [1 5 4 3 0 0 2 2 6 1 3 3 6 5 5 6 5 2 3 6 3 0 2 4 2 6 4 0 0 0 0 0]
# NN Pred  : [3 3 3 3 3 3 3 3 4 1 3 3 6 5 5 6 5 2 3 6 3 0 2 4 2 6 4 0 0 0 0 0]
#
# Sample 3:
# Original : [0 6 1 3 0 3 5 1 1 0 1 4 1 3 3 6 3 6 3 4 6 2 5 0 3 1 3 0 0 0 0 0]
# NN Pred  : [3 3 3 3 3 3 3 3 2 0 1 4 1 3 3 6 3 6 3 4 6 2 5 0 3 1 3 0 0 0 0 0]

# %% [markdown]
# Visualize and Analyse model training

# %%
import matplotlib.pyplot as plt

# exclude zero pads
y_pred_first_n = y_pred[:, :n]
y_pred_first_n_rescaled = y_pred_first_n * (q - 1)

plt.hist(y_pred_first_n_rescaled.flatten(), bins=50)
plt.xlabel('Prediction Value')
plt.ylabel('Frequency')
plt.show()

# %%
# for layer in model.layers:
#     if layer.trainable_variables:  # Check if the layer has trainable variables
#         for i, var in enumerate(layer.trainable_variables):
#             print(f"{layer.name} - Variable {i} ({var.name}): values: {var.numpy()}")
#     else:
#         print(layer.name, "has no trainable variables.")

# %%
# from tensorflow.keras import backend as K
# K.clear_session()
