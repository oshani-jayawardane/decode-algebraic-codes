# %% [markdown]
# ### 3-layer DCT-III StNN - Generator matrix encoded data

# %% [markdown]
# This code uses this technique:
# ![What I should change.jpg](data:image/jpeg;base64,...)

# %%
# %reset -f
import gc
gc.collect()
# Out:
# 0

# %%
global w0
global z0

w0 = 4
z0 = 3

n = 27
q = 7
num_samples = 1000

num_unseen_samples = 20

# %%
import numpy as np
import tensorflow as tf
import math

np.random.seed(42)

# %%
def next_power_of_two(x):
    return 2 ** math.ceil(math.log2(x))

n_padded = next_power_of_two(n)

x_original = np.random.randint(0, q, size=(num_samples, n))

padding = n_padded - n
dataset = np.pad(x_original, ((0, 0), (0, padding)), mode='constant', constant_values=0)

print(f"Original n: {n}, Padded to: {n_padded}")
# Out:
# Original n: 27, Padded to: 32

# %%
x_original.shape
# Out:
# (1000, 27)

# %%
dataset.shape
# Out:
# (1000, 32)

# %% [markdown]
# Encode using generator matrix
# $$
# \tilde{M}_{kj} = \left[ \left( \frac{w_0}{z_0} \right)^j \zeta^{kj} \right]_{k,j=0}^{n-1}
# $$

# %%
def padded_generator_matrix(N, w0, z0):
    n = np.arange(N)
    k = n.reshape((N, 1))
    zeta = np.exp(-2j * np.pi / N)
    M_tilde = ((w0 / z0) ** n) * (zeta ** (k * n))
    return M_tilde

# %%
M_tilde = padded_generator_matrix(n_padded, w0, z0)
print(M_tilde.shape)
# Out:
# (32, 32)

# %%
encoded_dataset = np.array([np.dot(M_tilde, x) for x in dataset])
encoded_dataset[np.abs(encoded_dataset) < 1e-10] = 0
encoded_dataset = np.round(encoded_dataset, decimals=10)
encoded_dataset.shape
# Out:
# (1000, 32)

# %%
print(f"x_original[0]:", x_original[0])
print(f"\nAfter encoding:\n", encoded_dataset[0])
# Out:
# x_original[0]: [6 3 4 6 2 4 4 6 1 2 6 2 2 4 3 2 5 4 1 3 5 5 1 3 4 0 3]
#
# After encoding:
#  [18563.60052945    +0.j         -3175.07412411+14542.65392496j
#  -9480.13851167 -1549.89213738j  -850.18419129 -5788.51248279j
#   2813.63372348 -2457.36436449j  3312.0476391   +337.88077825j
#   1059.2907911  +3489.68169028j -2366.82367016  +909.74502726j
#   -210.29906943  +357.85181443j -3878.07651347  +373.95548592j
#    -49.25036994 -6370.32567308j  6901.71964373 -1088.5938127j
#   2896.76301761 +7252.43377368j -6714.83312544 +4427.90575271j
#  -5496.28870703 -5330.43278044j  2828.24226801 -6162.17891893j
#   6446.94186958    -0.j          2828.24226801 +6162.17891893j
#  -5496.28870703 +5330.43278044j -6714.83312544 -4427.90575271j
#   2896.76301761 -7252.43377368j  6901.71964373 +1088.5938127j
#    -49.25036994 +6370.32567308j -3878.07651347  -373.95548592j
#   -210.29906943  -357.85181443j -2366.82367016  -909.74502726j
#   1059.2907911  -3489.68169028j  3312.0476391   -337.88077825j
#   2813.63372348 +2457.36436449j  -850.18419129 +5788.51248279j
#  -9480.13851167 +1549.89213738j -3175.07412411-14542.65392496j]

# %% [markdown]
# Pre-processing

# %%
N = encoded_dataset.shape[1]

k = np.arange(N)
shift = np.exp(-1j * np.pi * k / (2 * N))
alpha_k = np.where(k == 0, np.sqrt(1/N), np.sqrt(2/N))

dct2_dataset = np.array([np.real(alpha_k * shift * y) for y in encoded_dataset])
dct2_dataset[np.abs(dct2_dataset) < 1e-10] = 0
dct2_dataset = np.round(dct2_dataset, decimals=10) # Round for numerical stability

# %%
"""
The part below is for testing purposes only
"""

from scipy.fftpack import dct

dct3_dataset = np.array([dct(x, type=3, norm='ortho') for x in dct2_dataset])

X_perm = np.hstack((dct3_dataset[:, ::2], dct3_dataset[:, 1::2][:, ::-1]))

D_hat_n = np.array([(z0 / w0) ** k for k in range(N)])
decoded_dataset = X_perm * D_hat_n

# Print verification (for one sample)
sample_idx = 78
print("Original x:", dataset[sample_idx])
print("\nEncoded y:", encoded_dataset[sample_idx])
print("\nDCT Coefficients:", np.round(dct2_dataset[sample_idx], 4))
print("\nReconstructed Signal:", np.round(dct3_dataset[sample_idx], 4))
print("\nAfter Permutation:", np.round(X_perm[sample_idx], 4))
print("\nAfter Scaling:", np.round(decoded_dataset[sample_idx], 4))
# Out:
# Original x: [4 3 6 4 2 0 5 6 6 2 2 1 6 1 1 5 1 4 3 0 2 4 0 6 6 6 4 0 0 0 0 0]
#
# Encoded y: [ 29916.11588021    +0.j            328.95686704+26422.4846445j
#  -21936.20111033 +3988.95593508j  -7301.38988823-17810.36382931j
#   13577.84642585 -8953.74117052j   9354.9421295  +8727.48732799j
#   -4221.49645678 +8798.15590637j  -7861.90722461  -861.73832776j
#    -779.76795929 -5322.56486315j   2168.22506293 -1740.90057156j
#    1615.33333537 -1441.8771791j    5127.91361716 +2018.69510167j
#   -2943.81135295 +6208.60576073j  -5262.87924206 -2070.18847016j
#     798.8487054  -4460.7613612j    2679.94226354  +633.97975698j
#    -477.22622529    -0.j           2679.94226354  -633.97975698j
#     798.8487054  +4460.7613612j   -5262.87924206 +2070.18847016j
#   -2943.81135295 -6208.60576073j   5127.91361716 -2018.69510167j
#    1615.33333537 +1441.8771791j    2168.22506293 +1740.90057156j
#    -779.76795929 +5322.56486315j  -7861.90722461  +861.73832776j
#   -4221.49645678 -8798.15590637j   9354.9421295  -8727.48732799j
#   13577.84642585 +8953.74117052j  -7301.38988823+17810.36382931j
#  -21936.20111033 -3988.95593508j    328.95686704-26422.4846445j ]
#
# DCT Coefficients: [ 5288.4721   406.2626 -5359.8966 -2458.9216  2892.5409  2798.7982
#   -371.4376 -1923.1607  -689.3173   303.9303   186.2252  1359.0437
#    250.4067 -1365.0985  -553.0897   602.8653   -84.3625   332.4978
#    988.7499  -368.0756 -1699.4402   226.1955   508.2713   625.1978
#   1154.7511  -459.308  -2411.1865 -1548.2175  2857.651   4136.5643
#  -1529.9679 -6593.6291]
#
# Reconstructed Signal: [ 4.0000000e+00  0.0000000e+00  4.0000000e+00  0.0000000e+00
#   1.0666700e+01 -0.0000000e+00  9.4815000e+00  0.0000000e+00
#   6.3210000e+00  0.0000000e+00  0.0000000e+00  7.0870769e+03
#   2.8093300e+01  7.9729615e+03  4.4949200e+01  5.9797211e+03
#   5.9932300e+01  4.4847908e+03  2.6636600e+01 -0.0000000e+00
#   3.5515500e+01  1.6817966e+03  2.3677000e+01  6.3067370e+02
#   1.8941580e+02  0.0000000e+00  4.2092400e+01  5.3213090e+02
#   5.6123200e+01  5.3213090e+02  3.7415460e+02  9.9774600e+01]
#
# After Permutation: [ 4.0000000e+00  4.0000000e+00  1.0666700e+01  9.4815000e+00
#   6.3210000e+00  0.0000000e+00  2.8093300e+01  4.4949200e+01
#   5.9932300e+01  2.6636600e+01  3.5515500e+01  2.3677000e+01
#   1.8941580e+02  4.2092400e+01  5.6123200e+01  3.7415460e+02
#   9.9774600e+01  5.3213090e+02  5.3213090e+02  0.0000000e+00
#   6.3067370e+02  1.6817966e+03 -0.0000000e+00  4.4847908e+03
#   5.9797211e+03  7.9729615e+03  7.0870769e+03  0.0000000e+00
#   0.0000000e+00 -0.0000000e+00  0.0000000e+00  0.0000000e+00]
#
# After Scaling: [ 4.  3.  6.  4.  2.  0.  5.  6.  6.  2.  2.  1.  6.  1.  1.  5.  1.  4.
#   3.  0.  2.  4. -0.  6.  6.  6.  4.  0.  0. -0.  0.  0.]

# %%
y = dataset.astype(np.float32)
y_normalized = y / (q - 1)  # Scale to [0, 1]

# labels = y
labels = y_normalized

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    dct2_dataset, labels, test_size=0.2, random_state=42
)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (800, 32) (800, 32)
# (200, 32) (200, 32)

# %%
X_train = (X_train - X_train.mean()) / X_train.std()
X_test = (X_test - X_test.mean()) / X_test.std()

# %% [markdown]
# DCT-3 imposed StNN

# %%
class FirstLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, **kwargs):
        super(FirstLayer, self).__init__(**kwargs)
        self.n = units
        self.n1 = units // 2
        self.trainable = trainable

        init_diag = tf.ones(self.n1, dtype=tf.float32)
        init_diag = tf.tensor_scatter_nd_update(init_diag, [[0]], [tf.sqrt(2.0)])

        self.B_1 = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_diag),
                trainable=self.trainable,
                name='B_1'
            )
        self.B_2 = self.add_weight(
                shape=(self.n1 - 1,), # size of B_2 is (n1 - 1)
                initializer='ones',
                trainable=self.trainable,
                name='B_2'
            )
        self.bias = self.add_weight(
            shape=(self.n,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

    def call(self, x):
        even = x[:, ::2]
        odd = x[:, 1::2]

        d1 = tf.multiply(odd, self.B_1) # diagonal ex: [x1, x3, x5, x7] and multiply by B_1
        temp = tf.multiply(odd[:, :(self.n1 - 1)], self.B_2) # ex: get [x1, x3, x5] and multiply by B_2
        d2 = tf.concat([tf.zeros_like(temp[:, :1]), temp], axis=1) # rearrange it to [0, x1.B2_1, x3.B2_2, x5..B2_3]
        B_n = tf.add(d1, d2)

        u = tf.concat([even, B_n], axis=1)

        return u + self.bias

# %%
class SecondLayerDCTIII(tf.keras.layers.Layer):
    def __init__(self, n, trainable=True, **kwargs):
        super(SecondLayerDCTIII, self).__init__(**kwargs)
        self.n = n
        self.n1 = n // 2 if n > 2 else 1
        self.trainable = trainable

        if n == 2:
            # Base case: trainable 2x2 matrix
            self.C_2 = self.add_weight(
                shape=(2, 2),
                initializer=tf.keras.initializers.Constant((1 / np.sqrt(2)) * np.array([[1., 1.], [1., -1.]])),
                trainable=self.trainable,
                name='C_2'
            )
        else:
            init_diag = tf.ones(self.n1, dtype=tf.float32)
            init_diag = tf.tensor_scatter_nd_update(init_diag, [[0]], [tf.sqrt(2.0)])

            # Weights for B^T_{n/2}
            self.B_1 = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_diag),
                trainable=self.trainable,
                name='B_1'
            )
            self.B_2 = self.add_weight(
                shape=(self.n1 - 1,), # again length of B_2 should be n1-1 in each recursion - this will be adapted dynamically since DCT111 will be called each time for different n
                initializer='ones',
                trainable=self.trainable,
                name='B_2'
            )

            k = tf.cast(tf.range(1, self.n1 + 1), tf.float32)
            pi = tf.constant(np.pi, dtype=tf.float32)
            init_W_c = 1 / (2 * tf.cos((2 * k - 1) * (pi / (2 * self.n))))

            # Weight for W_c
            self.w_c = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_W_c),
                trainable=self.trainable,
                name='W_c'
            )

            self.bias = self.add_weight(
                shape=(self.n,),
                initializer='zeros',
                trainable=True,
                name='bias'
            )

            # Recursive DCTIII for n/2
            self.dctiii_layer1 = SecondLayerDCTIII(self.n1,trainable=self.trainable)
            self.dctiii_layer2 = SecondLayerDCTIII(self.n1,trainable=self.trainable)

    def call(self, x):
        if self.n == 2:
            y = tf.matmul(self.C_2, x, transpose_b=True)
            return tf.transpose(y)
        else:
            # Permutation
            even = x[:, ::2]
            odd = x[:, 1::2]

            # B^T - same as in the FirstLayeer
            d1 = tf.multiply(odd, self.B_1)
            temp = tf.multiply(odd[:, :(self.n1 - 1)], self.B_2)
            d2 = tf.concat([tf.zeros_like(temp[:, :1]), temp], axis=1)
            B_n = tf.add(d1, d2)
            u = tf.concat([even, B_n], axis=1)

            # Recursive DCTIII
            z1 = self.dctiii_layer1(u[:, :self.n1])
            z2 = self.dctiii_layer2(u[:, self.n1:])
            recurs_out = tf.concat([z1, z2], axis=1)

            # W_c - same as in the ThirdLayer
            W_n = tf.multiply(recurs_out[:, self.n1:], self.w_c)
            v = tf.concat([recurs_out[:, :self.n1], W_n], axis=1)

            # H_n
            out1 = v[:, :self.n1]
            out2 = v[:, self.n1:]
            y = (1 / tf.sqrt(tf.constant(2.0, dtype=tf.float32))) * tf.concat(
                [(out1 + out2), tf.reverse((out1 - out2), axis=[1])],
                axis=1
            )

            return y + self.bias

# %%
class ThirdLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, **kwargs):
        super(ThirdLayer, self).__init__(**kwargs)
        self.n = units
        self.n1 = units // 2
        self.trainable = trainable

        k = tf.cast(tf.range(1, self.n1 + 1), tf.float32)
        pi = tf.constant(np.pi, dtype=tf.float32)
        init_W_c = 1 / (2 * tf.cos((2 * k - 1) * (pi / (2 * self.n))))

        self.w_c = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_W_c),
                trainable=self.trainable,
                name='W_c'
            )

        self.bias = self.add_weight(
            shape=(self.n,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

    def call(self, x):
        input1 = x[:, :self.n1]
        input2 = x[:, self.n1:]

        # W_{N/2}
        W_n = tf.multiply(input2, self.w_c)
        v = tf.concat([input1, W_n], axis=1)

        # H_n^T
        out1 = v[:, :self.n1]
        out2 = v[:, self.n1:]

        y = (1 / tf.sqrt(tf.constant(2.0, dtype=tf.float32))) * tf.concat([(out1 + out2), tf.reverse((out1 - out2), axis=[1])], axis=1)

        return y + self.bias

# %%
class DiagonalLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, kernel_initializer='he_normal', bias_initializer='zeros', **kwargs):
        super(DiagonalLayer, self).__init__(**kwargs)
        self.units = units
        self.kernel_initializer = kernel_initializer
        self.bias_initializer = bias_initializer
        self.trainable = trainable

    def build(self, input_shape):
        self.diag = self.add_weight(
            shape=(self.units,),
            initializer=tf.keras.initializers.get(self.kernel_initializer),
            trainable=self.trainable,
            name='diag'
        )
        self.bias = self.add_weight(
            shape=(self.units,),
            initializer=tf.keras.initializers.get(self.bias_initializer),
            trainable=self.trainable,
            name='bias'
        )

    def call(self, inputs):
        scaled = tf.multiply(inputs, self.diag)
        return scaled + self.bias

# %%
class ScalingLayer(tf.keras.layers.Layer):
    def __init__(self, units, initial_scale=1.0, trainable=True, kernel_initializer='he_normal', bias_initializer='zeros', **kwargs):
        super(ScalingLayer, self).__init__(**kwargs)
        self.units = units
        self.initial_scale = initial_scale
        self.kernel_initializer = kernel_initializer
        self.bias_initializer = bias_initializer

    def build(self, input_shape):

      self.log_scale = self.add_weight(
          shape=(),
          initializer=tf.keras.initializers.Constant(self.initial_scale),
          trainable=True,
          name="log_scale",
      )
      self.diag = self.add_weight(
          shape=(self.units,),
          initializer=tf.keras.initializers.get(self.kernel_initializer),
          regularizer=tf.keras.regularizers.l2(1e-4),
          trainable=True,
          name='diag'
      )
      self.bias = self.add_weight(
          shape=(self.units,),
          initializer=tf.keras.initializers.get(self.bias_initializer),
          trainable=True,
          name='bias'
        )

      super().build(input_shape)

    def call(self, inputs):
      perm = tf.concat([inputs[:, ::2], inputs[:, 1::2][:, ::-1]], axis=-1)

      dim = tf.shape(perm)[1]

      D_hat_n = tf.exp(self.log_scale * tf.cast(tf.range(dim), tf.float32))

      scaled = perm * D_hat_n * self.diag

      return scaled + self.bias

# %% [markdown]
# Model

# %%
def custom_accuracy(y_true, y_pred):
    y_true_int = tf.cast(y_true*(q-1), tf.int32)
    y_pred_int = tf.cast(tf.round(y_pred*(q-1)), tf.int32)
    correct = tf.cast(tf.equal(y_true_int, y_pred_int), tf.float32)
    return tf.reduce_mean(correct)

def custom_accuracy_without_padding(y_true, y_pred):
    y_true_int = tf.cast(y_true * (q - 1), tf.int32)
    y_pred_int = tf.cast(tf.round(y_pred * (q - 1)), tf.int32)
    mask = tf.concat(
        [tf.ones((tf.shape(y_true)[0], n), dtype=tf.float32),
         tf.zeros((tf.shape(y_true)[0], n_padded - n), dtype=tf.float32)],
        axis=1
    )
    correct = tf.cast(tf.equal(y_true_int, y_pred_int), tf.float32) * mask
    return tf.reduce_sum(correct) / tf.reduce_sum(mask)

def custom_mse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    loss = tf.reduce_mean(tf.square(tf.cast(y_true - y_pred, tf.float32)))
    return loss

# %%
from tensorflow.keras.layers import InputLayer, LeakyReLU, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

initial_log_scale = np.log(z0 / w0)
initial_scale = (z0 / w0)

input_shape = (n_padded,)
model = Sequential([
    InputLayer(shape=input_shape),
    FirstLayer(units=n_padded, trainable=True, name="first_layer"),
    # LeakyReLU(negative_slope=0.1),
    SecondLayerDCTIII(n=n_padded, trainable=True, name="second_layer"),
    # LeakyReLU(negative_slope=0.1),
    ThirdLayer(units=n_padded, trainable=True, name="third_layer"),
    LeakyReLU(negative_slope=0.1),
    ScalingLayer(units=n_padded, initial_scale=initial_log_scale, trainable=True, kernel_initializer='ones', bias_initializer='zeros', name="scaling_layer"),
    LeakyReLU(negative_slope=0.1)
    # DiagonalLayer(units=n_padded, trainable=False, kernel_initializer='ones', bias_initializer='zeros', name="output_layer"),
    # Activation('linear')
])

# notes:
# 1. adding the diagonal layers in the middle worsens results
# 2. residual connections does not work
# 3. removing bias in hidden layers worsens performance
# 4. removing "LeakyReLU" activation in between layers improved performance


model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=custom_mse,
    metrics=[custom_mse, custom_accuracy_without_padding]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ first_layer (FirstLayer)        │ (None, 32)             │            63 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ second_layer                    │ (None, 32)             │           369 │
# │ (SecondLayerDCTIII)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ third_layer (ThirdLayer)        │ (None, 32)             │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ scaling_layer (ScalingLayer)    │ (None, 32)             │            65 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 32)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 545 (2.13 KB)
#  Trainable params: 545 (2.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ------------- FLOP counts ---------------

# Create concrete function
input_shape = (1, n_padded)  # batch size 1
concrete_func = tf.function(model).get_concrete_function(tf.TensorSpec(input_shape, tf.float32))

from tensorflow.python.profiler import model_analyzer
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

profile_opts = ProfileOptionBuilder.float_operation()
flops = model_analyzer.profile(concrete_func.graph, options=profile_opts)

print('FLOPs:', flops.total_float_ops)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/profiler/internal/flops_registry.py:140: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# FLOPs: 1088

# %% [markdown]
# Training

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

checkpoint_path = f"/content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_{n}.keras"

model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

adjust_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

history = model.fit(
    X_train, y_train,
    epochs=500,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[adjust_lr, early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1462 - custom_mse: 0.2729 - loss: 0.2761
# Epoch 1: val_loss improved from inf to 0.23668, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 31s 276ms/step - custom_accuracy_without_padding: 0.1458 - custom_mse: 0.2722 - loss: 0.2753 - val_custom_accuracy_without_padding: 0.1505 - val_custom_mse: 0.2322 - val_loss: 0.2367 - learning_rate: 0.0010
# Epoch 2/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1407 - custom_mse: 0.2363 - loss: 0.2394
# Epoch 2: val_loss improved from 0.23668 to 0.21572, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - custom_accuracy_without_padding: 0.1407 - custom_mse: 0.2359 - loss: 0.2390 - val_custom_accuracy_without_padding: 0.1477 - val_custom_mse: 0.2112 - val_loss: 0.2157 - learning_rate: 0.0010
# Epoch 3/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1386 - custom_mse: 0.2190 - loss: 0.2220
# Epoch 3: val_loss improved from 0.21572 to 0.20094, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1391 - custom_mse: 0.2182 - loss: 0.2213 - val_custom_accuracy_without_padding: 0.1467 - val_custom_mse: 0.1965 - val_loss: 0.2009 - learning_rate: 0.0010
# Epoch 4/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1436 - custom_mse: 0.2018 - loss: 0.2048
# Epoch 4: val_loss improved from 0.20094 to 0.18734, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1438 - custom_mse: 0.2014 - loss: 0.2043 - val_custom_accuracy_without_padding: 0.1486 - val_custom_mse: 0.1832 - val_loss: 0.1873 - learning_rate: 0.0010
# Epoch 5/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1407 - custom_mse: 0.1874 - loss: 0.1904
# Epoch 5: val_loss improved from 0.18734 to 0.17290, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.1412 - custom_mse: 0.1868 - loss: 0.1898 - val_custom_accuracy_without_padding: 0.1495 - val_custom_mse: 0.1691 - val_loss: 0.1729 - learning_rate: 0.0010
# Epoch 6/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1460 - custom_mse: 0.1694 - loss: 0.1723
# Epoch 6: val_loss improved from 0.17290 to 0.15596, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.1461 - custom_mse: 0.1691 - loss: 0.1720 - val_custom_accuracy_without_padding: 0.1548 - val_custom_mse: 0.1527 - val_loss: 0.1560 - learning_rate: 0.0010
# Epoch 7/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.1541 - custom_mse: 0.1506 - loss: 0.1536
# Epoch 7: val_loss improved from 0.15596 to 0.14241, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1539 - custom_mse: 0.1503 - loss: 0.1532 - val_custom_accuracy_without_padding: 0.1473 - val_custom_mse: 0.1398 - val_loss: 0.1424 - learning_rate: 0.0010
# Epoch 8/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1469 - custom_mse: 0.1373 - loss: 0.1403
# Epoch 8: val_loss improved from 0.14241 to 0.13286, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1471 - custom_mse: 0.1368 - loss: 0.1398 - val_custom_accuracy_without_padding: 0.1473 - val_custom_mse: 0.1304 - val_loss: 0.1329 - learning_rate: 0.0010
# Epoch 9/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1493 - custom_mse: 0.1256 - loss: 0.1286
# Epoch 9: val_loss improved from 0.13286 to 0.12492, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.1494 - custom_mse: 0.1254 - loss: 0.1284 - val_custom_accuracy_without_padding: 0.1500 - val_custom_mse: 0.1226 - val_loss: 0.1249 - learning_rate: 0.0010
# Epoch 10/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1448 - custom_mse: 0.1181 - loss: 0.1211
# Epoch 10: val_loss improved from 0.12492 to 0.11862, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.1452 - custom_mse: 0.1179 - loss: 0.1210 - val_custom_accuracy_without_padding: 0.1488 - val_custom_mse: 0.1165 - val_loss: 0.1186 - learning_rate: 0.0010
# Epoch 11/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1555 - custom_mse: 0.1087 - loss: 0.1118
# Epoch 11: val_loss improved from 0.11862 to 0.11336, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - custom_accuracy_without_padding: 0.1554 - custom_mse: 0.1089 - loss: 0.1119 - val_custom_accuracy_without_padding: 0.1528 - val_custom_mse: 0.1113 - val_loss: 0.1134 - learning_rate: 0.0010
# Epoch 12/500
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.1584 - custom_mse: 0.1063 - loss: 0.1093
# Epoch 12: val_loss improved from 0.11336 to 0.10900, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - custom_accuracy_without_padding: 0.1578 - custom_mse: 0.1060 - loss: 0.1091 - val_custom_accuracy_without_padding: 0.1526 - val_custom_mse: 0.1068 - val_loss: 0.1090 - learning_rate: 0.0010
# Epoch 13/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.1609 - custom_mse: 0.1029 - loss: 0.1059
# Epoch 13: val_loss improved from 0.10900 to 0.10594, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - custom_accuracy_without_padding: 0.1609 - custom_mse: 0.1028 - loss: 0.1058 - val_custom_accuracy_without_padding: 0.1543 - val_custom_mse: 0.1036 - val_loss: 0.1059 - learning_rate: 0.0010
# Epoch 14/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.1579 - custom_mse: 0.1004 - loss: 0.1033
# Epoch 14: val_loss improved from 0.10594 to 0.10312, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - custom_accuracy_without_padding: 0.1581 - custom_mse: 0.1002 - loss: 0.1032 - val_custom_accuracy_without_padding: 0.1562 - val_custom_mse: 0.1008 - val_loss: 0.1031 - learning_rate: 0.0010
# Epoch 15/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1627 - custom_mse: 0.0975 - loss: 0.1004
# Epoch 15: val_loss improved from 0.10312 to 0.10124, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.1627 - custom_mse: 0.0974 - loss: 0.1003 - val_custom_accuracy_without_padding: 0.1549 - val_custom_mse: 0.0988 - val_loss: 0.1012 - learning_rate: 0.0010
# Epoch 16/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1645 - custom_mse: 0.0967 - loss: 0.0996
# Epoch 16: val_loss improved from 0.10124 to 0.09974, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1646 - custom_mse: 0.0965 - loss: 0.0994 - val_custom_accuracy_without_padding: 0.1577 - val_custom_mse: 0.0973 - val_loss: 0.0997 - learning_rate: 0.0010
# Epoch 17/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1664 - custom_mse: 0.0951 - loss: 0.0980
# Epoch 17: val_loss improved from 0.09974 to 0.09847, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy_without_padding: 0.1663 - custom_mse: 0.0950 - loss: 0.0979 - val_custom_accuracy_without_padding: 0.1597 - val_custom_mse: 0.0960 - val_loss: 0.0985 - learning_rate: 0.0010
# Epoch 18/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1678 - custom_mse: 0.0928 - loss: 0.0956
# Epoch 18: val_loss improved from 0.09847 to 0.09758, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.1676 - custom_mse: 0.0928 - loss: 0.0956 - val_custom_accuracy_without_padding: 0.1605 - val_custom_mse: 0.0951 - val_loss: 0.0976 - learning_rate: 0.0010
# Epoch 19/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1653 - custom_mse: 0.0932 - loss: 0.0960
# Epoch 19: val_loss improved from 0.09758 to 0.09684, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1655 - custom_mse: 0.0931 - loss: 0.0959 - val_custom_accuracy_without_padding: 0.1591 - val_custom_mse: 0.0944 - val_loss: 0.0968 - learning_rate: 0.0010
# Epoch 20/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.1701 - custom_mse: 0.0916 - loss: 0.0944
# Epoch 20: val_loss improved from 0.09684 to 0.09615, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.1700 - custom_mse: 0.0916 - loss: 0.0944 - val_custom_accuracy_without_padding: 0.1589 - val_custom_mse: 0.0937 - val_loss: 0.0961 - learning_rate: 0.0010
# Epoch 21/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1718 - custom_mse: 0.0904 - loss: 0.0931
# Epoch 21: val_loss improved from 0.09615 to 0.09560, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1714 - custom_mse: 0.0905 - loss: 0.0932 - val_custom_accuracy_without_padding: 0.1599 - val_custom_mse: 0.0932 - val_loss: 0.0956 - learning_rate: 0.0010
# Epoch 22/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1692 - custom_mse: 0.0904 - loss: 0.0931
# Epoch 22: val_loss improved from 0.09560 to 0.09533, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1692 - custom_mse: 0.0904 - loss: 0.0931 - val_custom_accuracy_without_padding: 0.1604 - val_custom_mse: 0.0929 - val_loss: 0.0953 - learning_rate: 0.0010
# Epoch 23/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.1691 - custom_mse: 0.0900 - loss: 0.0927
# Epoch 23: val_loss improved from 0.09533 to 0.09480, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.1690 - custom_mse: 0.0900 - loss: 0.0927 - val_custom_accuracy_without_padding: 0.1615 - val_custom_mse: 0.0924 - val_loss: 0.0948 - learning_rate: 0.0010
# Epoch 24/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1651 - custom_mse: 0.0900 - loss: 0.0927
# Epoch 24: val_loss improved from 0.09480 to 0.09435, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1654 - custom_mse: 0.0900 - loss: 0.0927 - val_custom_accuracy_without_padding: 0.1614 - val_custom_mse: 0.0920 - val_loss: 0.0944 - learning_rate: 0.0010
# Epoch 25/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1685 - custom_mse: 0.0893 - loss: 0.0919
# Epoch 25: val_loss improved from 0.09435 to 0.09405, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1685 - custom_mse: 0.0893 - loss: 0.0919 - val_custom_accuracy_without_padding: 0.1634 - val_custom_mse: 0.0917 - val_loss: 0.0941 - learning_rate: 0.0010
# Epoch 26/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1688 - custom_mse: 0.0887 - loss: 0.0913
# Epoch 26: val_loss improved from 0.09405 to 0.09372, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1688 - custom_mse: 0.0888 - loss: 0.0913 - val_custom_accuracy_without_padding: 0.1634 - val_custom_mse: 0.0914 - val_loss: 0.0937 - learning_rate: 0.0010
# Epoch 27/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1712 - custom_mse: 0.0890 - loss: 0.0916
# Epoch 27: val_loss improved from 0.09372 to 0.09337, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1711 - custom_mse: 0.0890 - loss: 0.0916 - val_custom_accuracy_without_padding: 0.1625 - val_custom_mse: 0.0910 - val_loss: 0.0934 - learning_rate: 0.0010
# Epoch 28/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1697 - custom_mse: 0.0891 - loss: 0.0916
# Epoch 28: val_loss improved from 0.09337 to 0.09320, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1698 - custom_mse: 0.0890 - loss: 0.0916 - val_custom_accuracy_without_padding: 0.1640 - val_custom_mse: 0.0909 - val_loss: 0.0932 - learning_rate: 0.0010
# Epoch 29/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1710 - custom_mse: 0.0876 - loss: 0.0901
# Epoch 29: val_loss improved from 0.09320 to 0.09307, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1711 - custom_mse: 0.0877 - loss: 0.0902 - val_custom_accuracy_without_padding: 0.1644 - val_custom_mse: 0.0908 - val_loss: 0.0931 - learning_rate: 0.0010
# Epoch 30/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1754 - custom_mse: 0.0882 - loss: 0.0907
# Epoch 30: val_loss improved from 0.09307 to 0.09274, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.1752 - custom_mse: 0.0883 - loss: 0.0907 - val_custom_accuracy_without_padding: 0.1663 - val_custom_mse: 0.0905 - val_loss: 0.0927 - learning_rate: 0.0010
# Epoch 31/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1723 - custom_mse: 0.0882 - loss: 0.0906
# Epoch 31: val_loss improved from 0.09274 to 0.09239, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1723 - custom_mse: 0.0882 - loss: 0.0906 - val_custom_accuracy_without_padding: 0.1624 - val_custom_mse: 0.0902 - val_loss: 0.0924 - learning_rate: 0.0010
# Epoch 32/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1729 - custom_mse: 0.0880 - loss: 0.0904
# Epoch 32: val_loss improved from 0.09239 to 0.09223, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1732 - custom_mse: 0.0880 - loss: 0.0904 - val_custom_accuracy_without_padding: 0.1645 - val_custom_mse: 0.0900 - val_loss: 0.0922 - learning_rate: 0.0010
# Epoch 33/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1743 - custom_mse: 0.0874 - loss: 0.0898
# Epoch 33: val_loss improved from 0.09223 to 0.09200, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.1743 - custom_mse: 0.0874 - loss: 0.0898 - val_custom_accuracy_without_padding: 0.1642 - val_custom_mse: 0.0898 - val_loss: 0.0920 - learning_rate: 0.0010
# Epoch 34/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.1749 - custom_mse: 0.0873 - loss: 0.0897
# Epoch 34: val_loss improved from 0.09200 to 0.09165, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - custom_accuracy_without_padding: 0.1750 - custom_mse: 0.0873 - loss: 0.0897 - val_custom_accuracy_without_padding: 0.1673 - val_custom_mse: 0.0894 - val_loss: 0.0917 - learning_rate: 0.0010
# Epoch 35/500
# 17/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.1723 - custom_mse: 0.0875 - loss: 0.0898
# Epoch 35: val_loss improved from 0.09165 to 0.09138, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - custom_accuracy_without_padding: 0.1734 - custom_mse: 0.0875 - loss: 0.0898 - val_custom_accuracy_without_padding: 0.1658 - val_custom_mse: 0.0892 - val_loss: 0.0914 - learning_rate: 0.0010
# Epoch 36/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.1763 - custom_mse: 0.0865 - loss: 0.0888
# Epoch 36: val_loss improved from 0.09138 to 0.09134, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - custom_accuracy_without_padding: 0.1763 - custom_mse: 0.0865 - loss: 0.0888 - val_custom_accuracy_without_padding: 0.1657 - val_custom_mse: 0.0893 - val_loss: 0.0913 - learning_rate: 0.0010
# Epoch 37/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.1781 - custom_mse: 0.0865 - loss: 0.0888
# Epoch 37: val_loss improved from 0.09134 to 0.09101, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_accuracy_without_padding: 0.1779 - custom_mse: 0.0865 - loss: 0.0888 - val_custom_accuracy_without_padding: 0.1642 - val_custom_mse: 0.0888 - val_loss: 0.0910 - learning_rate: 0.0010
# Epoch 38/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1763 - custom_mse: 0.0859 - loss: 0.0882
# Epoch 38: val_loss improved from 0.09101 to 0.09082, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy_without_padding: 0.1763 - custom_mse: 0.0859 - loss: 0.0882 - val_custom_accuracy_without_padding: 0.1665 - val_custom_mse: 0.0887 - val_loss: 0.0908 - learning_rate: 0.0010
# Epoch 39/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1791 - custom_mse: 0.0856 - loss: 0.0878
# Epoch 39: val_loss improved from 0.09082 to 0.09057, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1788 - custom_mse: 0.0857 - loss: 0.0879 - val_custom_accuracy_without_padding: 0.1640 - val_custom_mse: 0.0885 - val_loss: 0.0906 - learning_rate: 0.0010
# Epoch 40/500
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.1826 - custom_mse: 0.0857 - loss: 0.0880
# Epoch 40: val_loss improved from 0.09057 to 0.09029, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1810 - custom_mse: 0.0859 - loss: 0.0881 - val_custom_accuracy_without_padding: 0.1673 - val_custom_mse: 0.0882 - val_loss: 0.0903 - learning_rate: 0.0010
# Epoch 41/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.1734 - custom_mse: 0.0849 - loss: 0.0871
# Epoch 41: val_loss improved from 0.09029 to 0.09004, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - custom_accuracy_without_padding: 0.1740 - custom_mse: 0.0850 - loss: 0.0872 - val_custom_accuracy_without_padding: 0.1660 - val_custom_mse: 0.0880 - val_loss: 0.0900 - learning_rate: 0.0010
# Epoch 42/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1755 - custom_mse: 0.0864 - loss: 0.0886
# Epoch 42: val_loss improved from 0.09004 to 0.08966, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.1756 - custom_mse: 0.0863 - loss: 0.0885 - val_custom_accuracy_without_padding: 0.1693 - val_custom_mse: 0.0876 - val_loss: 0.0897 - learning_rate: 0.0010
# Epoch 43/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1797 - custom_mse: 0.0843 - loss: 0.0865
# Epoch 43: val_loss improved from 0.08966 to 0.08934, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.1795 - custom_mse: 0.0844 - loss: 0.0865 - val_custom_accuracy_without_padding: 0.1685 - val_custom_mse: 0.0873 - val_loss: 0.0893 - learning_rate: 0.0010
# Epoch 44/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1774 - custom_mse: 0.0855 - loss: 0.0877
# Epoch 44: val_loss improved from 0.08934 to 0.08906, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1774 - custom_mse: 0.0855 - loss: 0.0876 - val_custom_accuracy_without_padding: 0.1673 - val_custom_mse: 0.0871 - val_loss: 0.0891 - learning_rate: 0.0010
# Epoch 45/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1806 - custom_mse: 0.0847 - loss: 0.0868
# Epoch 45: val_loss improved from 0.08906 to 0.08884, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1805 - custom_mse: 0.0847 - loss: 0.0868 - val_custom_accuracy_without_padding: 0.1696 - val_custom_mse: 0.0868 - val_loss: 0.0888 - learning_rate: 0.0010
# Epoch 46/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1765 - custom_mse: 0.0847 - loss: 0.0868
# Epoch 46: val_loss improved from 0.08884 to 0.08856, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1767 - custom_mse: 0.0846 - loss: 0.0867 - val_custom_accuracy_without_padding: 0.1687 - val_custom_mse: 0.0866 - val_loss: 0.0886 - learning_rate: 0.0010
# Epoch 47/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1788 - custom_mse: 0.0844 - loss: 0.0865
# Epoch 47: val_loss improved from 0.08856 to 0.08836, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1788 - custom_mse: 0.0844 - loss: 0.0864 - val_custom_accuracy_without_padding: 0.1670 - val_custom_mse: 0.0865 - val_loss: 0.0884 - learning_rate: 0.0010
# Epoch 48/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1765 - custom_mse: 0.0837 - loss: 0.0858
# Epoch 48: val_loss improved from 0.08836 to 0.08808, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy_without_padding: 0.1768 - custom_mse: 0.0838 - loss: 0.0858 - val_custom_accuracy_without_padding: 0.1726 - val_custom_mse: 0.0862 - val_loss: 0.0881 - learning_rate: 0.0010
# Epoch 49/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1829 - custom_mse: 0.0836 - loss: 0.0857
# Epoch 49: val_loss improved from 0.08808 to 0.08774, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1827 - custom_mse: 0.0836 - loss: 0.0857 - val_custom_accuracy_without_padding: 0.1726 - val_custom_mse: 0.0858 - val_loss: 0.0877 - learning_rate: 0.0010
# Epoch 50/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1808 - custom_mse: 0.0826 - loss: 0.0846
# Epoch 50: val_loss improved from 0.08774 to 0.08765, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy_without_padding: 0.1806 - custom_mse: 0.0827 - loss: 0.0847 - val_custom_accuracy_without_padding: 0.1705 - val_custom_mse: 0.0858 - val_loss: 0.0877 - learning_rate: 0.0010
# Epoch 51/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1768 - custom_mse: 0.0843 - loss: 0.0863
# Epoch 51: val_loss improved from 0.08765 to 0.08727, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1770 - custom_mse: 0.0842 - loss: 0.0862 - val_custom_accuracy_without_padding: 0.1710 - val_custom_mse: 0.0854 - val_loss: 0.0873 - learning_rate: 0.0010
# Epoch 52/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1789 - custom_mse: 0.0840 - loss: 0.0860
# Epoch 52: val_loss improved from 0.08727 to 0.08684, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1790 - custom_mse: 0.0839 - loss: 0.0859 - val_custom_accuracy_without_padding: 0.1754 - val_custom_mse: 0.0850 - val_loss: 0.0868 - learning_rate: 0.0010
# Epoch 53/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1779 - custom_mse: 0.0834 - loss: 0.0853
# Epoch 53: val_loss improved from 0.08684 to 0.08664, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.1782 - custom_mse: 0.0833 - loss: 0.0852 - val_custom_accuracy_without_padding: 0.1774 - val_custom_mse: 0.0848 - val_loss: 0.0866 - learning_rate: 0.0010
# Epoch 54/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.1862 - custom_mse: 0.0822 - loss: 0.0842
# Epoch 54: val_loss improved from 0.08664 to 0.08624, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - custom_accuracy_without_padding: 0.1858 - custom_mse: 0.0823 - loss: 0.0842 - val_custom_accuracy_without_padding: 0.1776 - val_custom_mse: 0.0844 - val_loss: 0.0862 - learning_rate: 0.0010
# Epoch 55/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.1780 - custom_mse: 0.0827 - loss: 0.0847
# Epoch 55: val_loss improved from 0.08624 to 0.08613, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - custom_accuracy_without_padding: 0.1789 - custom_mse: 0.0826 - loss: 0.0845 - val_custom_accuracy_without_padding: 0.1772 - val_custom_mse: 0.0843 - val_loss: 0.0861 - learning_rate: 0.0010
# Epoch 56/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.1846 - custom_mse: 0.0817 - loss: 0.0836
# Epoch 56: val_loss improved from 0.08613 to 0.08588, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - custom_accuracy_without_padding: 0.1846 - custom_mse: 0.0817 - loss: 0.0836 - val_custom_accuracy_without_padding: 0.1777 - val_custom_mse: 0.0841 - val_loss: 0.0859 - learning_rate: 0.0010
# Epoch 57/500
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.1845 - custom_mse: 0.0820 - loss: 0.0839
# Epoch 57: val_loss improved from 0.08588 to 0.08576, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.1846 - custom_mse: 0.0820 - loss: 0.0839 - val_custom_accuracy_without_padding: 0.1764 - val_custom_mse: 0.0840 - val_loss: 0.0858 - learning_rate: 0.0010
# Epoch 58/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1850 - custom_mse: 0.0808 - loss: 0.0827
# Epoch 58: val_loss improved from 0.08576 to 0.08545, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1850 - custom_mse: 0.0809 - loss: 0.0828 - val_custom_accuracy_without_padding: 0.1764 - val_custom_mse: 0.0838 - val_loss: 0.0854 - learning_rate: 0.0010
# Epoch 59/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1892 - custom_mse: 0.0806 - loss: 0.0825
# Epoch 59: val_loss improved from 0.08545 to 0.08526, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1886 - custom_mse: 0.0807 - loss: 0.0826 - val_custom_accuracy_without_padding: 0.1786 - val_custom_mse: 0.0836 - val_loss: 0.0853 - learning_rate: 0.0010
# Epoch 60/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1846 - custom_mse: 0.0821 - loss: 0.0839
# Epoch 60: val_loss improved from 0.08526 to 0.08477, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1849 - custom_mse: 0.0820 - loss: 0.0838 - val_custom_accuracy_without_padding: 0.1807 - val_custom_mse: 0.0830 - val_loss: 0.0848 - learning_rate: 0.0010
# Epoch 61/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.1815 - custom_mse: 0.0809 - loss: 0.0827
# Epoch 61: val_loss improved from 0.08477 to 0.08460, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.1827 - custom_mse: 0.0808 - loss: 0.0826 - val_custom_accuracy_without_padding: 0.1779 - val_custom_mse: 0.0829 - val_loss: 0.0846 - learning_rate: 0.0010
# Epoch 62/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1811 - custom_mse: 0.0803 - loss: 0.0821
# Epoch 62: val_loss improved from 0.08460 to 0.08426, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1825 - custom_mse: 0.0804 - loss: 0.0822 - val_custom_accuracy_without_padding: 0.1827 - val_custom_mse: 0.0826 - val_loss: 0.0843 - learning_rate: 0.0010
# Epoch 63/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1909 - custom_mse: 0.0797 - loss: 0.0815
# Epoch 63: val_loss improved from 0.08426 to 0.08384, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1908 - custom_mse: 0.0798 - loss: 0.0816 - val_custom_accuracy_without_padding: 0.1812 - val_custom_mse: 0.0822 - val_loss: 0.0838 - learning_rate: 0.0010
# Epoch 64/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1938 - custom_mse: 0.0803 - loss: 0.0820
# Epoch 64: val_loss improved from 0.08384 to 0.08379, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1935 - custom_mse: 0.0802 - loss: 0.0820 - val_custom_accuracy_without_padding: 0.1799 - val_custom_mse: 0.0822 - val_loss: 0.0838 - learning_rate: 0.0010
# Epoch 65/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1867 - custom_mse: 0.0789 - loss: 0.0807
# Epoch 65: val_loss improved from 0.08379 to 0.08321, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1873 - custom_mse: 0.0790 - loss: 0.0808 - val_custom_accuracy_without_padding: 0.1867 - val_custom_mse: 0.0816 - val_loss: 0.0832 - learning_rate: 0.0010
# Epoch 66/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1929 - custom_mse: 0.0790 - loss: 0.0807
# Epoch 66: val_loss improved from 0.08321 to 0.08312, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy_without_padding: 0.1932 - custom_mse: 0.0790 - loss: 0.0808 - val_custom_accuracy_without_padding: 0.1845 - val_custom_mse: 0.0815 - val_loss: 0.0831 - learning_rate: 0.0010
# Epoch 67/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1907 - custom_mse: 0.0802 - loss: 0.0819
# Epoch 67: val_loss improved from 0.08312 to 0.08269, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1916 - custom_mse: 0.0800 - loss: 0.0817 - val_custom_accuracy_without_padding: 0.1837 - val_custom_mse: 0.0811 - val_loss: 0.0827 - learning_rate: 0.0010
# Epoch 68/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1947 - custom_mse: 0.0792 - loss: 0.0809
# Epoch 68: val_loss improved from 0.08269 to 0.08229, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1948 - custom_mse: 0.0791 - loss: 0.0809 - val_custom_accuracy_without_padding: 0.1862 - val_custom_mse: 0.0808 - val_loss: 0.0823 - learning_rate: 0.0010
# Epoch 69/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1995 - custom_mse: 0.0773 - loss: 0.0790
# Epoch 69: val_loss improved from 0.08229 to 0.08184, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1990 - custom_mse: 0.0774 - loss: 0.0791 - val_custom_accuracy_without_padding: 0.1882 - val_custom_mse: 0.0803 - val_loss: 0.0818 - learning_rate: 0.0010
# Epoch 70/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1992 - custom_mse: 0.0779 - loss: 0.0796
# Epoch 70: val_loss improved from 0.08184 to 0.08143, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.1992 - custom_mse: 0.0779 - loss: 0.0796 - val_custom_accuracy_without_padding: 0.1916 - val_custom_mse: 0.0799 - val_loss: 0.0814 - learning_rate: 0.0010
# Epoch 71/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2013 - custom_mse: 0.0768 - loss: 0.0785
# Epoch 71: val_loss improved from 0.08143 to 0.08103, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy_without_padding: 0.2012 - custom_mse: 0.0769 - loss: 0.0786 - val_custom_accuracy_without_padding: 0.1971 - val_custom_mse: 0.0795 - val_loss: 0.0810 - learning_rate: 0.0010
# Epoch 72/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2049 - custom_mse: 0.0779 - loss: 0.0795
# Epoch 72: val_loss improved from 0.08103 to 0.08054, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.2046 - custom_mse: 0.0778 - loss: 0.0794 - val_custom_accuracy_without_padding: 0.1958 - val_custom_mse: 0.0791 - val_loss: 0.0805 - learning_rate: 0.0010
# Epoch 73/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2060 - custom_mse: 0.0772 - loss: 0.0788
# Epoch 73: val_loss improved from 0.08054 to 0.08024, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.2057 - custom_mse: 0.0772 - loss: 0.0788 - val_custom_accuracy_without_padding: 0.1969 - val_custom_mse: 0.0788 - val_loss: 0.0802 - learning_rate: 0.0010
# Epoch 74/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2026 - custom_mse: 0.0761 - loss: 0.0777
# Epoch 74: val_loss improved from 0.08024 to 0.07970, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.2029 - custom_mse: 0.0762 - loss: 0.0778 - val_custom_accuracy_without_padding: 0.2019 - val_custom_mse: 0.0783 - val_loss: 0.0797 - learning_rate: 0.0010
# Epoch 75/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2100 - custom_mse: 0.0762 - loss: 0.0778
# Epoch 75: val_loss improved from 0.07970 to 0.07940, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.2098 - custom_mse: 0.0762 - loss: 0.0778 - val_custom_accuracy_without_padding: 0.2029 - val_custom_mse: 0.0780 - val_loss: 0.0794 - learning_rate: 0.0010
# Epoch 76/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.2143 - custom_mse: 0.0757 - loss: 0.0773
# Epoch 76: val_loss improved from 0.07940 to 0.07884, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - custom_accuracy_without_padding: 0.2140 - custom_mse: 0.0757 - loss: 0.0773 - val_custom_accuracy_without_padding: 0.2082 - val_custom_mse: 0.0774 - val_loss: 0.0788 - learning_rate: 0.0010
# Epoch 77/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.2168 - custom_mse: 0.0755 - loss: 0.0771
# Epoch 77: val_loss improved from 0.07884 to 0.07855, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - custom_accuracy_without_padding: 0.2165 - custom_mse: 0.0755 - loss: 0.0770 - val_custom_accuracy_without_padding: 0.2108 - val_custom_mse: 0.0772 - val_loss: 0.0785 - learning_rate: 0.0010
# Epoch 78/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.2132 - custom_mse: 0.0751 - loss: 0.0766
# Epoch 78: val_loss improved from 0.07855 to 0.07790, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - custom_accuracy_without_padding: 0.2134 - custom_mse: 0.0750 - loss: 0.0766 - val_custom_accuracy_without_padding: 0.2146 - val_custom_mse: 0.0765 - val_loss: 0.0779 - learning_rate: 0.0010
# Epoch 79/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.2143 - custom_mse: 0.0746 - loss: 0.0762
# Epoch 79: val_loss improved from 0.07790 to 0.07754, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - custom_accuracy_without_padding: 0.2146 - custom_mse: 0.0746 - loss: 0.0761 - val_custom_accuracy_without_padding: 0.2151 - val_custom_mse: 0.0762 - val_loss: 0.0775 - learning_rate: 0.0010
# Epoch 80/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2192 - custom_mse: 0.0744 - loss: 0.0759
# Epoch 80: val_loss improved from 0.07754 to 0.07724, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy_without_padding: 0.2195 - custom_mse: 0.0743 - loss: 0.0758 - val_custom_accuracy_without_padding: 0.2181 - val_custom_mse: 0.0759 - val_loss: 0.0772 - learning_rate: 0.0010
# Epoch 81/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2239 - custom_mse: 0.0738 - loss: 0.0753
# Epoch 81: val_loss improved from 0.07724 to 0.07668, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.2240 - custom_mse: 0.0738 - loss: 0.0753 - val_custom_accuracy_without_padding: 0.2188 - val_custom_mse: 0.0753 - val_loss: 0.0767 - learning_rate: 0.0010
# Epoch 82/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2258 - custom_mse: 0.0731 - loss: 0.0746
# Epoch 82: val_loss improved from 0.07668 to 0.07647, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.2258 - custom_mse: 0.0732 - loss: 0.0747 - val_custom_accuracy_without_padding: 0.2245 - val_custom_mse: 0.0751 - val_loss: 0.0765 - learning_rate: 0.0010
# Epoch 83/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2299 - custom_mse: 0.0738 - loss: 0.0753
# Epoch 83: val_loss improved from 0.07647 to 0.07627, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.2297 - custom_mse: 0.0738 - loss: 0.0753 - val_custom_accuracy_without_padding: 0.2254 - val_custom_mse: 0.0749 - val_loss: 0.0763 - learning_rate: 0.0010
# Epoch 84/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2338 - custom_mse: 0.0723 - loss: 0.0738
# Epoch 84: val_loss improved from 0.07627 to 0.07601, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.2334 - custom_mse: 0.0724 - loss: 0.0739 - val_custom_accuracy_without_padding: 0.2280 - val_custom_mse: 0.0747 - val_loss: 0.0760 - learning_rate: 0.0010
# Epoch 85/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2348 - custom_mse: 0.0724 - loss: 0.0738
# Epoch 85: val_loss improved from 0.07601 to 0.07560, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.2346 - custom_mse: 0.0724 - loss: 0.0739 - val_custom_accuracy_without_padding: 0.2295 - val_custom_mse: 0.0743 - val_loss: 0.0756 - learning_rate: 0.0010
# Epoch 86/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2333 - custom_mse: 0.0724 - loss: 0.0738
# Epoch 86: val_loss improved from 0.07560 to 0.07537, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.2334 - custom_mse: 0.0724 - loss: 0.0738 - val_custom_accuracy_without_padding: 0.2343 - val_custom_mse: 0.0741 - val_loss: 0.0754 - learning_rate: 0.0010
# Epoch 87/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2340 - custom_mse: 0.0727 - loss: 0.0742
# Epoch 87: val_loss improved from 0.07537 to 0.07525, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.2341 - custom_mse: 0.0727 - loss: 0.0741 - val_custom_accuracy_without_padding: 0.2325 - val_custom_mse: 0.0739 - val_loss: 0.0752 - learning_rate: 0.0010
# Epoch 88/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2341 - custom_mse: 0.0728 - loss: 0.0742
# ...
# Epoch 228/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3247 - custom_mse: 0.0641 - loss: 0.0647
# Epoch 228: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3248 - custom_mse: 0.0639 - loss: 0.0645 - val_custom_accuracy_without_padding: 0.3228 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 3.1250e-05
# Epoch 229/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3252 - custom_mse: 0.0635 - loss: 0.0641
# Epoch 229: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3250 - custom_mse: 0.0634 - loss: 0.0639 - val_custom_accuracy_without_padding: 0.3223 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 3.1250e-05
# Epoch 230/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3254 - custom_mse: 0.0634 - loss: 0.0640
# Epoch 230: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3253 - custom_mse: 0.0633 - loss: 0.0639 - val_custom_accuracy_without_padding: 0.3228 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 3.1250e-05
# Epoch 231/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3301 - custom_mse: 0.0625 - loss: 0.0631
# Epoch 231: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 231: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3286 - custom_mse: 0.0627 - loss: 0.0633 - val_custom_accuracy_without_padding: 0.3223 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 3.1250e-05
# Epoch 232/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3271 - custom_mse: 0.0622 - loss: 0.0628
# Epoch 232: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3266 - custom_mse: 0.0624 - loss: 0.0630 - val_custom_accuracy_without_padding: 0.3223 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 1.5625e-05
# Epoch 233/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3260 - custom_mse: 0.0630 - loss: 0.0636
# Epoch 233: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3257 - custom_mse: 0.0630 - loss: 0.0636 - val_custom_accuracy_without_padding: 0.3228 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 1.5625e-05
# Epoch 234/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3243 - custom_mse: 0.0633 - loss: 0.0639
# Epoch 234: val_loss improved from 0.06411 to 0.06411, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.3245 - custom_mse: 0.0633 - loss: 0.0639 - val_custom_accuracy_without_padding: 0.3232 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 1.5625e-05
# Epoch 235/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3283 - custom_mse: 0.0630 - loss: 0.0636
# Epoch 235: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.3274 - custom_mse: 0.0630 - loss: 0.0636 - val_custom_accuracy_without_padding: 0.3224 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 1.5625e-05
# Epoch 236/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3214 - custom_mse: 0.0637 - loss: 0.0643
# Epoch 236: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 236: val_loss improved from 0.06411 to 0.06411, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy_without_padding: 0.3220 - custom_mse: 0.0636 - loss: 0.0642 - val_custom_accuracy_without_padding: 0.3229 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 1.5625e-05
# Epoch 237/500
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3234 - custom_mse: 0.0634 - loss: 0.0640
# Epoch 237: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.3236 - custom_mse: 0.0633 - loss: 0.0639 - val_custom_accuracy_without_padding: 0.3231 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 7.8125e-06
# Epoch 238/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3249 - custom_mse: 0.0634 - loss: 0.0640
# Epoch 238: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.3248 - custom_mse: 0.0633 - loss: 0.0639 - val_custom_accuracy_without_padding: 0.3219 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 7.8125e-06
# Epoch 239/500
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3240 - custom_mse: 0.0630 - loss: 0.0636
# Epoch 239: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.3244 - custom_mse: 0.0630 - loss: 0.0636 - val_custom_accuracy_without_padding: 0.3228 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 7.8125e-06
# Epoch 240/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3257 - custom_mse: 0.0629 - loss: 0.0635
# Epoch 240: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3254 - custom_mse: 0.0630 - loss: 0.0636 - val_custom_accuracy_without_padding: 0.3229 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 7.8125e-06
# Epoch 241/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3301 - custom_mse: 0.0621 - loss: 0.0627
# Epoch 241: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 241: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.3292 - custom_mse: 0.0623 - loss: 0.0628 - val_custom_accuracy_without_padding: 0.3223 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 7.8125e-06
# Epoch 242/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.3239 - custom_mse: 0.0627 - loss: 0.0633
# Epoch 242: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3240 - custom_mse: 0.0627 - loss: 0.0633 - val_custom_accuracy_without_padding: 0.3228 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 3.9063e-06
# Epoch 243/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3297 - custom_mse: 0.0631 - loss: 0.0637
# Epoch 243: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3291 - custom_mse: 0.0631 - loss: 0.0637 - val_custom_accuracy_without_padding: 0.3224 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 3.9063e-06
# Epoch 244/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3243 - custom_mse: 0.0632 - loss: 0.0638
# Epoch 244: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.3244 - custom_mse: 0.0631 - loss: 0.0637 - val_custom_accuracy_without_padding: 0.3223 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 3.9063e-06
# Epoch 245/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.3278 - custom_mse: 0.0622 - loss: 0.0628
# Epoch 245: val_loss improved from 0.06411 to 0.06411, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - custom_accuracy_without_padding: 0.3276 - custom_mse: 0.0622 - loss: 0.0628 - val_custom_accuracy_without_padding: 0.3224 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 3.9063e-06
# Epoch 246/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.3285 - custom_mse: 0.0624 - loss: 0.0630
# Epoch 246: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 246: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - custom_accuracy_without_padding: 0.3283 - custom_mse: 0.0625 - loss: 0.0631 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 3.9063e-06
# Epoch 247/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3261 - custom_mse: 0.0630 - loss: 0.0635
# Epoch 247: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3260 - custom_mse: 0.0629 - loss: 0.0635 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 1.9531e-06
# Epoch 248/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3236 - custom_mse: 0.0631 - loss: 0.0637
# Epoch 248: val_loss improved from 0.06411 to 0.06411, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.3239 - custom_mse: 0.0631 - loss: 0.0637 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 1.9531e-06
# Epoch 249/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3312 - custom_mse: 0.0622 - loss: 0.0628
# Epoch 249: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3299 - custom_mse: 0.0624 - loss: 0.0630 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 1.9531e-06
# Epoch 250/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3281 - custom_mse: 0.0627 - loss: 0.0633
# Epoch 250: val_loss did not improve from 0.06411
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3278 - custom_mse: 0.0627 - loss: 0.0633 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 1.9531e-06
# Epoch 251/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3292 - custom_mse: 0.0630 - loss: 0.0636
# Epoch 251: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 251: val_loss improved from 0.06411 to 0.06410, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.3283 - custom_mse: 0.0630 - loss: 0.0636 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 1.9531e-06
# Epoch 252/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3191 - custom_mse: 0.0637 - loss: 0.0643
# Epoch 252: val_loss improved from 0.06410 to 0.06410, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_updated_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_accuracy_without_padding: 0.3207 - custom_mse: 0.0635 - loss: 0.0641 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 9.7656e-07
# Epoch 253/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3266 - custom_mse: 0.0628 - loss: 0.0634
# Epoch 253: val_loss did not improve from 0.06410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3264 - custom_mse: 0.0629 - loss: 0.0634 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 9.7656e-07
# Epoch 254/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3212 - custom_mse: 0.0640 - loss: 0.0646
# Epoch 254: val_loss did not improve from 0.06410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.3218 - custom_mse: 0.0638 - loss: 0.0644 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 9.7656e-07
# Epoch 255/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3206 - custom_mse: 0.0631 - loss: 0.0637
# Epoch 255: val_loss did not improve from 0.06410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.3216 - custom_mse: 0.0630 - loss: 0.0636 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 9.7656e-07
# Epoch 256/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3242 - custom_mse: 0.0634 - loss: 0.0640
# Epoch 256: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 256: val_loss did not improve from 0.06410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3245 - custom_mse: 0.0633 - loss: 0.0639 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 9.7656e-07
# Epoch 257/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3249 - custom_mse: 0.0625 - loss: 0.0631
# Epoch 257: val_loss did not improve from 0.06410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.3250 - custom_mse: 0.0626 - loss: 0.0632 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 4.8828e-07
# Epoch 258/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3299 - custom_mse: 0.0625 - loss: 0.0631
# Epoch 258: val_loss did not improve from 0.06410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3291 - custom_mse: 0.0626 - loss: 0.0632 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 4.8828e-07
# Epoch 259/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3250 - custom_mse: 0.0627 - loss: 0.0633
# Epoch 259: val_loss did not improve from 0.06410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3250 - custom_mse: 0.0627 - loss: 0.0633 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 4.8828e-07
# Epoch 260/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3248 - custom_mse: 0.0627 - loss: 0.0633
# Epoch 260: val_loss did not improve from 0.06410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3248 - custom_mse: 0.0628 - loss: 0.0634 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 4.8828e-07
# Epoch 261/500
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3240 - custom_mse: 0.0632 - loss: 0.0637
# Epoch 261: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 261: val_loss did not improve from 0.06410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.3244 - custom_mse: 0.0631 - loss: 0.0637 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 4.8828e-07
# Epoch 262/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3291 - custom_mse: 0.0630 - loss: 0.0636
# Epoch 262: val_loss did not improve from 0.06410
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.3281 - custom_mse: 0.0629 - loss: 0.0635 - val_custom_accuracy_without_padding: 0.3226 - val_custom_mse: 0.0638 - val_loss: 0.0641 - learning_rate: 2.4414e-07

# %%
# Evaluate the model on the test set
eval_results = model.evaluate(X_test, y_test)
print(f"Test results - Loss: {eval_results[0]}, MSE: {eval_results[1]}, Accuracy: {eval_results[2]}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3224 - custom_mse: 0.0625 - loss: 0.0630
# Test results - Loss: 0.06410443037748337, MSE: 0.0637669712305069, Accuracy: 0.3225859999656677

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['custom_accuracy_without_padding'], label='Training Accuracy')
plt.plot(history.history['val_custom_accuracy_without_padding'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.show()

# %%
y_pred = model.predict(X_test)
y_test_rescaled = y_test * (q - 1)
y_pred_rescaled = y_pred * (q - 1)

print("Comparison of predictions and ground truth:")
for i in range(3):
    print(f"Sample {i+1}:")
    print(f"  Predicted:    {np.round(y_pred_rescaled[i]).astype(int)}")
    print(f"  Ground Truth: {np.round(y_test_rescaled[i]).astype(int)}")
    print("-" * 40)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step
# Comparison of predictions and ground truth:
# Sample 1:
#   Predicted:    [3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 5 3 3 3 3 4 6 4 2 3 1 0 0 0 0 0]
#   Ground Truth: [5 6 5 1 3 4 1 1 6 2 3 1 4 0 3 2 5 1 4 3 4 4 6 5 2 3 1 0 0 0 0 0]
# ----------------------------------------
# Sample 2:
#   Predicted:    [3 3 3 3 2 3 3 3 3 3 3 3 3 3 3 3 1 3 2 2 1 5 1 2 4 0 4 0 0 0 0 0]
#   Ground Truth: [1 4 1 3 3 3 0 5 5 2 4 3 3 1 3 1 1 2 0 1 1 5 2 1 4 0 4 0 0 0 0 0]
# ----------------------------------------
# Sample 3:
#   Predicted:    [3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 6 3 3 6 0 5 4 2 3 4 4 0 0 0 0 0]
#   Ground Truth: [2 6 0 2 2 1 3 4 2 6 4 1 0 5 2 3 5 1 4 6 0 4 3 2 3 4 4 0 0 0 0 0]
# ----------------------------------------

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)

print(f"R² Score: {r2:.4f}")
# Out:
# R² Score: 0.4264

# %%
# ---------------------- Inference time on Test Set ----------------------------

import time

_ = model.predict(X_test, verbose=0)  # warm up

times = []
for _ in range(100):
    start = time.perf_counter()
    _ = model.predict(X_test, verbose=0)
    end = time.perf_counter()
    times.append(end - start)

average_inference_time = np.mean(times)
print(f"Average batch inference time over 100 runs: {average_inference_time:.6f} seconds")

average_per_sample = average_inference_time / X_test.shape[0]
print(f"Average inference time per sample (from batch): {average_per_sample:.6f} seconds")
# Out:
# Average batch inference time over 100 runs: 0.093473 seconds
# Average inference time per sample (from batch): 0.000467 seconds

# %% [markdown]
# Test on unseen samples

# %%
# --------------------- Predictions on unseen samples (no noise) -------------------------

np.random.seed(42)

x_unseen_original = np.random.randint(0, q, size=(num_unseen_samples, n))
x_unseen_original_padded = np.pad(x_unseen_original, ((0, 0), (0, padding)), mode='constant', constant_values=0)

# encode
encoded_dataset_unseen = np.array([np.dot(M_tilde, x) for x in x_unseen_original_padded])
encoded_dataset_unseen[np.abs(encoded_dataset_unseen) < 1e-10] = 0
encoded_dataset_unseen = np.round(encoded_dataset_unseen, decimals=10)

# pre-process
N = encoded_dataset_unseen.shape[1]
k = np.arange(N)
shift = np.exp(-1j * np.pi * k / (2 * N))
alpha_k = np.where(k == 0, np.sqrt(1/N), np.sqrt(2/N))

x_unseen_dct2 = np.array([np.real(alpha_k * shift * y) for y in encoded_dataset_unseen])
x_unseen_dct2[np.abs(x_unseen_dct2) < 1e-10] = 0
x_unseen_dct2 = np.round(x_unseen_dct2, decimals=10)

# Normalize
x_unseen_dct2_normalized = (x_unseen_dct2 - x_unseen_dct2.mean()) / x_unseen_dct2.std()

# Predict
nn_pred = model.predict(x_unseen_dct2_normalized)

# Rescale prediction
y_pred_final = np.mod(np.round(nn_pred * (q - 1)), q)

# Evaluate
x_unseen_original_padded_normalized = x_unseen_original_padded.astype(np.float32) / (q - 1)

mse_nn = custom_mse(x_unseen_original_padded_normalized, nn_pred)
acc_nn = custom_accuracy_without_padding(x_unseen_original_padded_normalized, nn_pred)

print(f"MSE on unseen data (no noise): {mse_nn}")
print(f"Accuracy on unseen data (no noise): {acc_nn}")

num_display_samples = 3
for i in range(num_display_samples):
    print(f"\nSample {i+1}:")
    print(f"Original : {x_unseen_original_padded[i]}")
    print(f"NN Pred  : {y_pred_final[i].astype(int)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# MSE on unseen data (no noise): 0.0641651377081871
# Accuracy on unseen data (no noise): 0.3333333432674408
#
# Sample 1:
# Original : [6 3 4 6 2 4 4 6 1 2 6 2 2 4 3 2 5 4 1 3 5 5 1 3 4 0 3 0 0 0 0 0]
# NN Pred  : [3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 5 3 1 3 4 5 2 2 4 0 2 0 0 0 0 0]
#
# Sample 2:
# Original : [1 5 4 3 0 0 2 2 6 1 3 3 6 5 5 6 5 2 3 6 3 0 2 4 2 6 4 0 0 0 0 0]
# NN Pred  : [3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 5 3 2 5 3 1 3 3 2 6 4 0 0 0 0 0]
#
# Sample 3:
# Original : [0 6 1 3 0 3 5 1 1 0 1 4 1 3 3 6 3 6 3 4 6 2 5 0 3 1 3 0 0 0 0 0]
# NN Pred  : [3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 2 3 3 2 6 1 5 0 3 1 3 0 0 0 0 0]

# %% [markdown]
# Visualize and Analyse model training

# %%
import matplotlib.pyplot as plt

# exclude zero pads
y_pred_first_n = y_pred[:, :n]
y_pred_first_n_rescaled = y_pred_first_n * (q - 1)

plt.hist(y_pred_first_n_rescaled.flatten(), bins=50)
plt.xlabel('Prediction Value')
plt.ylabel('Frequency')
plt.show()

# %%
for layer in model.layers:
    if layer.trainable_variables:  # Check if the layer has trainable variables
        for i, var in enumerate(layer.trainable_variables):
            print(f"{layer.name} - Variable {i} ({var.name}): values: {var.numpy()}")
    else:
        print(layer.name, "has no trainable variables.")
# Out:
# first_layer - Variable 0 (B_1): values: [ 0.77454036  0.605411    0.7131832   0.4619775   0.54673743  1.2994276
#   0.67065895  0.934275    0.5973594   1.416458    1.3807186   0.96225417
#   0.6935174  -0.14926387  0.3291482   0.7750176 ]
# first_layer - Variable 1 (B_2): values: [1.2754327  1.3604503  0.90235674 1.0080899  0.29705796 1.2687954
#  0.37250435 0.92490816 0.8461345  1.1510408  1.0539097  1.2004379
#  1.5523005  1.2185653  1.1692692 ]
# first_layer - Variable 2 (bias): values: [ 0.18024388  0.32359412  0.08892936  0.17767513  0.05636853  0.05999377
#   0.04727347  0.11950211  0.031196    0.02177278 -0.03521726 -0.00788606
#   0.01044779  0.00836261  0.00972972 -0.04951271 -0.00378375 -0.12078355
#  -0.18874444 -0.03764051  0.06068206 -0.02263899  0.00159902 -0.03297764
#   0.02922901  0.03058226  0.05167815  0.10366561  0.00093891  0.10469338
#  -0.18313456  0.10826061]
# second_layer - Variable 0 (B_1): values: [1.3463775  0.7637555  1.0857157  0.84109485 1.0244706  0.8453218
#  1.0417162  0.8033612  0.7535869  0.8596028  0.5710294  0.9188732
#  1.4006728  0.9523474  0.84372973 0.6964165 ]
# second_layer - Variable 1 (B_2): values: [0.9973984  0.88294595 1.1629527  0.97055364 0.71082646 1.1275948
#  1.0328331  0.7275267  1.0984071  0.9025999  1.2266837  0.5216449
#  0.98162663 1.1261318  1.3490226 ]
# second_layer - Variable 2 (W_c): values: [ 0.19289817 -0.317739   -0.06303462 -0.20367523  0.4454677   0.35476536
#   0.7110694  -0.15117662  0.35261956  0.7906177  -0.26132923  0.9520112
#   1.776058    1.4500045   3.23435    10.941639  ]
# second_layer - Variable 3 (bias): values: [ 0.21508971  0.39629155  0.15764888  0.23973468  0.08091156  0.3249681
#   0.09891052  0.7429088   0.08900891  0.48791412  0.1480027   0.25734153
#   0.0207177   0.16959289  0.02342841 -0.21312225  0.001141   -0.32686514
#   0.0487474  -0.29211217  0.19280748 -0.30757147  0.1050266  -0.42107782
#   0.06163762 -0.12005456  0.10394128 -0.66815627  0.22437349 -0.3856254
#   0.02967364 -0.1444004 ]
# second_layer - Variable 4 (B_1): values: [1.048447   0.75452876 1.0449313  1.1013826  0.6043729  1.1931627
#  0.93480724 0.46822575]
# second_layer - Variable 5 (B_2): values: [0.8004717  0.9341893  0.86320204 0.9098239  1.3884513  1.1423259
#  1.498386  ]
# second_layer - Variable 6 (W_c): values: [ 0.1016795   0.02713619 -0.05296229  0.27011117  0.9737141   1.4062246
#   1.3161205   5.1834726 ]
# second_layer - Variable 7 (bias): values: [ 0.14092915  0.08388495 -0.01799603  0.2442419  -0.00851824  0.15761822
#   0.072871    0.16248083  0.07386647  0.22779717  0.11649073  0.12854835
#  -0.02873971  0.1015692  -0.04447597 -0.0500293 ]
# second_layer - Variable 8 (B_1): values: [1.4335515  0.28463596 0.7390225  0.9947518 ]
# second_layer - Variable 9 (B_2): values: [1.0147568 0.4682675 1.0409504]
# second_layer - Variable 10 (W_c): values: [0.5060593  0.11916226 0.02828367 2.3074007 ]
# second_layer - Variable 11 (bias): values: [0.10763545 0.0722612  0.0088187  0.1816616  0.02469751 0.15426648
#  0.16819616 0.11642597]
# second_layer - Variable 12 (B_1): values: [1.2588725  0.23152414]
# second_layer - Variable 13 (B_2): values: [0.95421886]
# second_layer - Variable 14 (W_c): values: [0.27399504 0.6406158 ]
# second_layer - Variable 15 (bias): values: [0.13615848 0.16666886 0.08408317 0.12020116]
# second_layer - Variable 16 (C_2): values: [[ 0.72852623  0.20130894]
#  [ 0.29717442 -0.28962064]]
# second_layer - Variable 17 (C_2): values: [[ 0.4263405   0.49056137]
#  [ 0.6390409  -0.4622784 ]]
# second_layer - Variable 18 (B_1): values: [1.061244  0.9304363]
# second_layer - Variable 19 (B_2): values: [1.0028673]
# second_layer - Variable 20 (W_c): values: [0.35257536 1.0147368 ]
# second_layer - Variable 21 (bias): values: [ 0.02289425 -0.11891207  0.00717881  0.03750179]
# second_layer - Variable 22 (C_2): values: [[ 0.8229489   0.20198657]
#  [ 0.3394199  -0.03896003]]
# second_layer - Variable 23 (C_2): values: [[ 0.45397    0.59003  ]
#  [ 0.4639984 -0.7570079]]
# second_layer - Variable 24 (B_1): values: [1.4395388 1.1586554 1.0683442 0.9960536]
# second_layer - Variable 25 (B_2): values: [0.4706748 1.0403014 1.2952174]
# second_layer - Variable 26 (W_c): values: [0.563019   0.40603587 0.9501827  2.0733645 ]
# second_layer - Variable 27 (bias): values: [ 0.06181461  0.05657725  0.08601718  0.2690476  -0.04712064  0.21645504
#  -0.11566106  0.06832521]
# second_layer - Variable 28 (B_1): values: [1.3017612 1.0988301]
# second_layer - Variable 29 (B_2): values: [1.1383369]
# second_layer - Variable 30 (W_c): values: [0.4443971 1.6297572]
# second_layer - Variable 31 (bias): values: [ 0.08722944 -0.1298027   0.12466936  0.11254426]
# second_layer - Variable 32 (C_2): values: [[ 0.4486927   0.7352397 ]
#  [ 0.43808833 -0.20890519]]
# second_layer - Variable 33 (C_2): values: [[ 0.6348158   0.6435114 ]
#  [ 0.57015514 -0.9792455 ]]
# second_layer - Variable 34 (B_1): values: [1.1780012 1.1471807]
# second_layer - Variable 35 (B_2): values: [1.0794176]
# second_layer - Variable 36 (W_c): values: [0.5102523 1.1706293]
# second_layer - Variable 37 (bias): values: [-0.03897827  0.11045795 -0.07778263  0.2013552 ]
# second_layer - Variable 38 (C_2): values: [[ 0.685659    0.7529656 ]
#  [ 0.7232487  -0.77852905]]
# second_layer - Variable 39 (C_2): values: [[ 0.52967495  0.7739302 ]
#  [ 0.532171   -0.80988485]]
# second_layer - Variable 40 (B_1): values: [1.3200344  0.9808136  0.81852126 0.9822213  1.1259652  1.1513782
#  0.9019332  1.0126292 ]
# second_layer - Variable 41 (B_2): values: [0.99250156 1.0410519  0.8727341  0.988969   0.7287592  1.1914968
#  1.0228195 ]
# second_layer - Variable 42 (W_c): values: [0.55584955 0.8635189  0.280005   0.7383152  0.5312447  1.2066466
#  0.49526277 4.9214478 ]
# second_layer - Variable 43 (bias): values: [ 0.21512374  0.2602119   0.11459003  0.09858606  0.15840831 -0.02187367
#   0.11414699  0.06028377  0.10883673  0.04704725  0.10212009 -0.10445556
#   0.07107757 -0.0381294   0.09808423 -0.05439866]
# second_layer - Variable 44 (B_1): values: [1.5136578 1.0456783 0.5353654 0.8910005]
# second_layer - Variable 45 (B_2): values: [0.86879337 1.2205839  1.0775796 ]
# second_layer - Variable 46 (W_c): values: [0.51111966 0.6478001  0.50180054 2.6141045 ]
# second_layer - Variable 47 (bias): values: [-0.0361513   0.27722278  0.06021598  0.18048535  0.14995922  0.22671741
#   0.24927439  0.3444909 ]
# second_layer - Variable 48 (B_1): values: [1.2993705 0.8465554]
# second_layer - Variable 49 (B_2): values: [1.1133174]
# second_layer - Variable 50 (W_c): values: [0.5421334  0.92957985]
# second_layer - Variable 51 (bias): values: [-0.02160302  0.2924014   0.12966013  0.23279649]
# second_layer - Variable 52 (C_2): values: [[ 0.6884156   0.44877607]
#  [ 0.36492607 -0.6360672 ]]
# second_layer - Variable 53 (C_2): values: [[ 0.6991748   0.7106788 ]
#  [ 0.47699195 -0.7652757 ]]
# second_layer - Variable 54 (B_1): values: [1.2881904 1.0263888]
# second_layer - Variable 55 (B_2): values: [1.0247532]
# second_layer - Variable 56 (W_c): values: [0.5244211 1.1485788]
# second_layer - Variable 57 (bias): values: [-0.05279386  0.07330886 -0.02328454 -0.00313568]
# second_layer - Variable 58 (C_2): values: [[ 0.86406183  0.51629186]
#  [ 0.5576283  -0.62338513]]
# second_layer - Variable 59 (C_2): values: [[ 0.6358504   0.72849536]
#  [ 0.5675072  -0.733165  ]]
# second_layer - Variable 60 (B_1): values: [1.5088388 1.0932224 1.2393138 1.0254884]
# second_layer - Variable 61 (B_2): values: [0.8699232  0.5640954  0.52820075]
# second_layer - Variable 62 (W_c): values: [0.54242694 0.4470587  0.6906742  2.1302235 ]
# second_layer - Variable 63 (bias): values: [ 0.07167218  0.04451958  0.094483   -0.00806642  0.1369098  -0.07544996
#   0.04970099 -0.03830474]
# second_layer - Variable 64 (B_1): values: [1.2021203 1.0209392]
# second_layer - Variable 65 (B_2): values: [1.0582967]
# second_layer - Variable 66 (W_c): values: [0.5755563 0.6784333]
# second_layer - Variable 67 (bias): values: [0.00302202 0.08568747 0.01885011 0.09378356]
# second_layer - Variable 68 (C_2): values: [[ 0.5707866   0.7634145 ]
#  [ 0.817824   -0.60473806]]
# second_layer - Variable 69 (C_2): values: [[ 0.6307237   0.8133813 ]
#  [ 0.4197656  -0.61939037]]
# second_layer - Variable 70 (B_1): values: [1.1679575  0.84598505]
# second_layer - Variable 71 (B_2): values: [1.1838685]
# second_layer - Variable 72 (W_c): values: [0.49307957 1.2414981 ]
# second_layer - Variable 73 (bias): values: [ 0.07371522 -0.02709476  0.10459787 -0.08467509]
# second_layer - Variable 74 (C_2): values: [[ 0.8563681   0.47053817]
#  [ 0.58902043 -0.5034077 ]]
# second_layer - Variable 75 (C_2): values: [[ 0.6557072   0.6631997 ]
#  [ 0.322765   -0.90860754]]
# third_layer - Variable 0 (W_c): values: [ 1.1510981  -0.08289871 -0.15443538  0.55447954  0.06016821 -0.89928734
#   0.98622316 -0.13276485  0.5903563  -0.6086618   0.7967136   0.25677028
#   1.5013134   1.6675282   2.3529272   9.864125  ]
# third_layer - Variable 1 (bias): values: [ 1.4841561e-01 -3.1013045e-01  2.5526664e-01 -2.7481341e-01
#   2.8511199e-01 -9.5094973e-03  1.1298056e-01 -4.7465673e-01
#   7.7559732e-02  1.1912263e-04  1.4876984e-01 -1.8854630e-01
#   1.5876283e-01  2.0578656e-02  4.2750321e-02 -1.8231122e-01
#  -6.5620072e-02  4.0735272e-01  3.0524063e-01  3.6906710e-01
#   6.4854270e-01  5.1407778e-01  4.8798510e-01  2.9234821e-01
#   7.4378014e-01  2.2833182e-01  3.2515022e-01  6.6069074e-02
#   2.3983645e-01  1.4988506e-01  3.9660820e-01  5.0541294e-01]
# leaky_re_lu has no trainable variables.
# scaling_layer - Variable 0 (log_scale): values: 0.050329431891441345
# scaling_layer - Variable 1 (diag): values: [ 1.8379675e-01  4.7374043e-01  3.8567647e-01  4.4163927e-01
#   4.4493926e-01  3.3591664e-01  1.2106785e-01  1.5583462e-01
#   5.8684070e-02  1.5335426e-01  1.7440047e-02  4.5693405e-02
#  -3.9363224e-03  1.9711483e-01  8.6850025e-02  9.6339509e-02
#   1.0528256e+00  4.6132800e-01  1.3235664e+00  8.7100333e-01
#   4.5878616e-01  5.2800888e-01  5.9057754e-01  2.1070138e-01
#   5.0243486e-02  3.9374566e-01  2.2679371e-01  1.7677723e-38
#  -9.7104378e-41  1.5368164e-29 -2.1292750e-31 -2.7075912e-34]
# scaling_layer - Variable 2 (bias): values: [ 2.23925576e-01  2.70272523e-01  3.00953060e-01  1.08162105e-01
#   6.70881197e-02  1.62880227e-01  1.94705442e-01  8.74250084e-02
#   5.28316081e-01  2.46905178e-01  4.62789118e-01  3.83486480e-01
#   5.10465741e-01  1.70508549e-01  2.32460558e-01  3.09576690e-01
#   1.46077657e-02  8.34567323e-02  5.73839359e-02  5.09165935e-02
#   2.28871983e-02  3.25882435e-02  3.52533907e-02  3.13810408e-02
#  -1.50147686e-02  1.14786839e-02  7.29890587e-03 -1.47992050e-37
#  -7.89068363e-40 -1.22887367e-28 -6.68116371e-32  7.54352951e-35]
# leaky_re_lu_1 has no trainable variables.

# %%
from tensorflow.keras import backend as K
K.clear_session()
