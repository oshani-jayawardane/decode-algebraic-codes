# %% [markdown]
# ### 3-layer DCT-III StNN - Generator matrix encoded data

# %% [markdown]
# This code uses this technique:
# ![what it does.jpg](data:image/jpeg;base64,...)

# %%
# %reset -f
import gc
gc.collect()
# Out:
# 0

# %%
global w0
global z0

w0 = 4
z0 = 3

n = 27
q = 7
num_samples = 1000

num_unseen_samples = 20

# %%
import numpy as np
import tensorflow as tf
import math

np.random.seed(42)

# %%
def next_power_of_two(x):
    return 2 ** math.ceil(math.log2(x))

n_padded = next_power_of_two(n)

x_original = np.random.randint(0, q, size=(num_samples, n))

padding = n_padded - n
dataset = np.pad(x_original, ((0, 0), (0, padding)), mode='constant', constant_values=0)

print(f"Original n: {n}, Padded to: {n_padded}")
# Out:
# Original n: 27, Padded to: 32

# %%
x_original.shape
# Out:
# (1000, 27)

# %%
dataset.shape
# Out:
# (1000, 32)

# %% [markdown]
# Encode using generator matrix
# $$
# \tilde{M}_{kj} = \left[ \left( \frac{w_0}{z_0} \right)^j \zeta^{kj} \right]_{k,j=0}^{n-1}
# $$

# %%
def padded_generator_matrix(N, w0, z0):
    n = np.arange(N)
    k = n.reshape((N, 1))
    zeta = np.exp(-2j * np.pi / N)
    M_tilde = ((w0 / z0) ** n) * (zeta ** (k * n))
    return M_tilde

# %%
M_tilde = padded_generator_matrix(n_padded, w0, z0)
print(M_tilde.shape)
# Out:
# (32, 32)

# %%
encoded_dataset = np.array([np.dot(M_tilde, x) for x in dataset])
encoded_dataset[np.abs(encoded_dataset) < 1e-10] = 0
encoded_dataset = np.round(encoded_dataset, decimals=10)
encoded_dataset.shape
# Out:
# (1000, 32)

# %%
print(f"x_original[0]:", x_original[0])
print(f"\nAfter encoding:\n", encoded_dataset[0])
# Out:
# x_original[0]: [6 3 4 6 2 4 4 6 1 2 6 2 2 4 3 2 5 4 1 3 5 5 1 3 4 0 3]
#
# After encoding:
#  [18563.60052945    +0.j         -3175.07412411+14542.65392496j
#  -9480.13851167 -1549.89213738j  -850.18419129 -5788.51248279j
#   2813.63372348 -2457.36436449j  3312.0476391   +337.88077825j
#   1059.2907911  +3489.68169028j -2366.82367016  +909.74502726j
#   -210.29906943  +357.85181443j -3878.07651347  +373.95548592j
#    -49.25036994 -6370.32567308j  6901.71964373 -1088.5938127j
#   2896.76301761 +7252.43377368j -6714.83312544 +4427.90575271j
#  -5496.28870703 -5330.43278044j  2828.24226801 -6162.17891893j
#   6446.94186958    -0.j          2828.24226801 +6162.17891893j
#  -5496.28870703 +5330.43278044j -6714.83312544 -4427.90575271j
#   2896.76301761 -7252.43377368j  6901.71964373 +1088.5938127j
#    -49.25036994 +6370.32567308j -3878.07651347  -373.95548592j
#   -210.29906943  -357.85181443j -2366.82367016  -909.74502726j
#   1059.2907911  -3489.68169028j  3312.0476391   -337.88077825j
#   2813.63372348 +2457.36436449j  -850.18419129 +5788.51248279j
#  -9480.13851167 +1549.89213738j -3175.07412411-14542.65392496j]

# %% [markdown]
# Pre-processing

# %%
N = encoded_dataset.shape[1]

k = np.arange(N)
shift = np.exp(-1j * np.pi * k / (2 * N))
alpha_k = np.where(k == 0, np.sqrt(1/N), np.sqrt(2/N))

dct2_dataset = np.array([np.real(alpha_k * shift * y) for y in encoded_dataset])
dct2_dataset[np.abs(dct2_dataset) < 1e-10] = 0
dct2_dataset = np.round(dct2_dataset, decimals=10) # Round for numerical stability

# %%
"""
The part below is for testing purposes only
"""

from scipy.fftpack import dct

dct3_dataset = np.array([dct(x, type=3, norm='ortho') for x in dct2_dataset])

X_perm = np.hstack((dct3_dataset[:, ::2], dct3_dataset[:, 1::2][:, ::-1]))

D_hat_n = np.array([(z0 / w0) ** k for k in range(N)])
decoded_dataset = X_perm * D_hat_n

# Print verification (for one sample)
sample_idx = 78
print("Original x:", dataset[sample_idx])
print("\nEncoded y:", encoded_dataset[sample_idx])
print("\nDCT Coefficients:", np.round(dct2_dataset[sample_idx], 4))
print("\nReconstructed Signal:", np.round(dct3_dataset[sample_idx], 4))
print("\nAfter Permutation:", np.round(X_perm[sample_idx], 4))
print("\nAfter Scaling:", np.round(decoded_dataset[sample_idx], 4))
# Out:
# Original x: [4 3 6 4 2 0 5 6 6 2 2 1 6 1 1 5 1 4 3 0 2 4 0 6 6 6 4 0 0 0 0 0]
#
# Encoded y: [ 29916.11588021    +0.j            328.95686704+26422.4846445j
#  -21936.20111033 +3988.95593508j  -7301.38988823-17810.36382931j
#   13577.84642585 -8953.74117052j   9354.9421295  +8727.48732799j
#   -4221.49645678 +8798.15590637j  -7861.90722461  -861.73832776j
#    -779.76795929 -5322.56486315j   2168.22506293 -1740.90057156j
#    1615.33333537 -1441.8771791j    5127.91361716 +2018.69510167j
#   -2943.81135295 +6208.60576073j  -5262.87924206 -2070.18847016j
#     798.8487054  -4460.7613612j    2679.94226354  +633.97975698j
#    -477.22622529    -0.j           2679.94226354  -633.97975698j
#     798.8487054  +4460.7613612j   -5262.87924206 +2070.18847016j
#   -2943.81135295 -6208.60576073j   5127.91361716 -2018.69510167j
#    1615.33333537 +1441.8771791j    2168.22506293 +1740.90057156j
#    -779.76795929 +5322.56486315j  -7861.90722461  +861.73832776j
#   -4221.49645678 -8798.15590637j   9354.9421295  -8727.48732799j
#   13577.84642585 +8953.74117052j  -7301.38988823+17810.36382931j
#  -21936.20111033 -3988.95593508j    328.95686704-26422.4846445j ]
#
# DCT Coefficients: [ 5288.4721   406.2626 -5359.8966 -2458.9216  2892.5409  2798.7982
#   -371.4376 -1923.1607  -689.3173   303.9303   186.2252  1359.0437
#    250.4067 -1365.0985  -553.0897   602.8653   -84.3625   332.4978
#    988.7499  -368.0756 -1699.4402   226.1955   508.2713   625.1978
#   1154.7511  -459.308  -2411.1865 -1548.2175  2857.651   4136.5643
#  -1529.9679 -6593.6291]
#
# Reconstructed Signal: [ 4.0000000e+00  0.0000000e+00  4.0000000e+00  0.0000000e+00
#   1.0666700e+01 -0.0000000e+00  9.4815000e+00  0.0000000e+00
#   6.3210000e+00  0.0000000e+00  0.0000000e+00  7.0870769e+03
#   2.8093300e+01  7.9729615e+03  4.4949200e+01  5.9797211e+03
#   5.9932300e+01  4.4847908e+03  2.6636600e+01 -0.0000000e+00
#   3.5515500e+01  1.6817966e+03  2.3677000e+01  6.3067370e+02
#   1.8941580e+02  0.0000000e+00  4.2092400e+01  5.3213090e+02
#   5.6123200e+01  5.3213090e+02  3.7415460e+02  9.9774600e+01]
#
# After Permutation: [ 4.0000000e+00  4.0000000e+00  1.0666700e+01  9.4815000e+00
#   6.3210000e+00  0.0000000e+00  2.8093300e+01  4.4949200e+01
#   5.9932300e+01  2.6636600e+01  3.5515500e+01  2.3677000e+01
#   1.8941580e+02  4.2092400e+01  5.6123200e+01  3.7415460e+02
#   9.9774600e+01  5.3213090e+02  5.3213090e+02  0.0000000e+00
#   6.3067370e+02  1.6817966e+03 -0.0000000e+00  4.4847908e+03
#   5.9797211e+03  7.9729615e+03  7.0870769e+03  0.0000000e+00
#   0.0000000e+00 -0.0000000e+00  0.0000000e+00  0.0000000e+00]
#
# After Scaling: [ 4.  3.  6.  4.  2.  0.  5.  6.  6.  2.  2.  1.  6.  1.  1.  5.  1.  4.
#   3.  0.  2.  4. -0.  6.  6.  6.  4.  0.  0. -0.  0.  0.]

# %%
y = dataset.astype(np.float32)
y_normalized = y / (q - 1)  # Scale to [0, 1]

# labels = y
labels = y_normalized

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    dct2_dataset, labels, test_size=0.2, random_state=42
)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (800, 32) (800, 32)
# (200, 32) (200, 32)

# %%
X_train = (X_train - X_train.mean()) / X_train.std()
X_test = (X_test - X_test.mean()) / X_test.std()

# %% [markdown]
# DCT-3 imposed StNN

# %%
class FirstLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, **kwargs):
        super(FirstLayer, self).__init__(**kwargs)
        self.n = units
        self.n1 = units // 2
        self.trainable = trainable

        init_diag = tf.ones(self.n1, dtype=tf.float32)
        init_diag = tf.tensor_scatter_nd_update(init_diag, [[0]], [tf.sqrt(2.0)])

        self.B_1 = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_diag),
                trainable=self.trainable,
                name='B_1'
            )
        self.B_2 = self.add_weight(
                shape=(self.n1 - 1,), # size of B_2 is (n1 - 1)
                initializer='ones',
                trainable=self.trainable,
                name='B_2'
            )
        self.bias = self.add_weight(
            shape=(self.n,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

    def call(self, x):
        even = x[:, ::2]
        odd = x[:, 1::2]

        d1 = tf.multiply(odd, self.B_1) # diagonal ex: [x1, x3, x5, x7] and multiply by B_1
        temp = tf.multiply(odd[:, :(self.n1 - 1)], self.B_2) # ex: get [x1, x3, x5] and multiply by B_2
        d2 = tf.concat([tf.zeros_like(temp[:, :1]), temp], axis=1) # rearrange it to [0, x1.B2_1, x3.B2_2, x5..B2_3]
        B_n = tf.add(d1, d2)

        u = tf.concat([even, B_n], axis=1)

        return u + self.bias

# %%
class DCTIII(tf.keras.layers.Layer):
    def __init__(self, n, trainable=True, **kwargs):
        super(DCTIII, self).__init__(**kwargs)
        self.n = n
        self.n1 = n // 2 if n > 2 else 1
        self.trainable = trainable

        if n == 2:
            # Base case: trainable 2x2 matrix
            self.C_2 = self.add_weight(
                shape=(2, 2),
                initializer=tf.keras.initializers.Constant((1 / np.sqrt(2)) * np.array([[1., 1.], [1., -1.]])),
                trainable=self.trainable,
                name='C_2'
            )
        else:
            init_diag = tf.ones(self.n1, dtype=tf.float32)
            init_diag = tf.tensor_scatter_nd_update(init_diag, [[0]], [tf.sqrt(2.0)])

            # Weights for B^T_{n/2}
            self.B_1 = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_diag),
                trainable=self.trainable,
                name='B_1'
            )
            self.B_2 = self.add_weight(
                shape=(self.n1 - 1,), # again length of B_2 should be n1-1 in each recursion - this will be adapted dynamically since DCT111 will be called each time for different n
                initializer='ones',
                trainable=self.trainable,
                name='B_2'
            )

            k = tf.cast(tf.range(1, self.n1 + 1), tf.float32)
            pi = tf.constant(np.pi, dtype=tf.float32)
            init_W_c = 1 / (2 * tf.cos((2 * k - 1) * (pi / (2 * self.n))))

            # Weight for W_c
            self.w_c = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_W_c),
                trainable=self.trainable,
                name='W_c'
            )

            # Recursive DCTIII for n/2
            self.dctiii_layer1 = DCTIII(self.n1,trainable=self.trainable)
            self.dctiii_layer2 = DCTIII(self.n1,trainable=self.trainable)

    def call(self, x):
        if self.n == 2:
            y = tf.matmul(self.C_2, x, transpose_b=True)
            return tf.transpose(y)
        else:
            # Permutation
            even = x[:, ::2]
            odd = x[:, 1::2]

            # B^T - same as in the FirstLayeer
            d1 = tf.multiply(odd, self.B_1)
            temp = tf.multiply(odd[:, :(self.n1 - 1)], self.B_2)
            d2 = tf.concat([tf.zeros_like(temp[:, :1]), temp], axis=1)
            B_n = tf.add(d1, d2)
            u = tf.concat([even, B_n], axis=1)

            # Recursive DCTIII
            z1 = self.dctiii_layer1(u[:, :self.n1])
            z2 = self.dctiii_layer2(u[:, self.n1:])
            recurs_out = tf.concat([z1, z2], axis=1)

            # W_c - same as in the ThirdLayer
            W_n = tf.multiply(recurs_out[:, self.n1:], self.w_c)
            v = tf.concat([recurs_out[:, :self.n1], W_n], axis=1)

            # H_n
            out1 = v[:, :self.n1]
            out2 = v[:, self.n1:]
            y = (1 / tf.sqrt(tf.constant(2.0, dtype=tf.float32))) * tf.concat(
                [(out1 + out2), tf.reverse((out1 - out2), axis=[1])],
                axis=1
            )

            return y

# %%
class SecondLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, **kwargs):
        super(SecondLayer, self).__init__(**kwargs)
        self.n = units
        self.n1 = units // 2
        self.trainable = trainable

        self.bias = self.add_weight(
            shape=(self.n,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

        # Recursive DCTIII for n/2
        self.dctiii1 = DCTIII(self.n1, trainable=self.trainable)
        self.dctiii2 = DCTIII(self.n1,trainable=self.trainable)

    def call(self, x):
        z1 = self.dctiii1(x[:, :self.n1])
        z2 = self.dctiii2(x[:, self.n1:])
        out = tf.concat([z1, z2], axis=1)
        return out + self.bias

# %%
class ThirdLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, **kwargs):
        super(ThirdLayer, self).__init__(**kwargs)
        self.n = units
        self.n1 = units // 2
        self.trainable = trainable

        k = tf.cast(tf.range(1, self.n1 + 1), tf.float32)
        pi = tf.constant(np.pi, dtype=tf.float32)
        init_W_c = 1 / (2 * tf.cos((2 * k - 1) * (pi / (2 * self.n))))

        self.w_c = self.add_weight(
                shape=(self.n1,),
                initializer=tf.keras.initializers.Constant(init_W_c),
                trainable=self.trainable,
                name='W_c'
            )

        self.bias = self.add_weight(
            shape=(self.n,),
            initializer='zeros',
            trainable=True,
            name='bias'
        )

    def call(self, x):
        input1 = x[:, :self.n1]
        input2 = x[:, self.n1:]

        # W_{N/2}
        W_n = tf.multiply(input2, self.w_c)
        v = tf.concat([input1, W_n], axis=1)

        # H_n^T
        out1 = v[:, :self.n1]
        out2 = v[:, self.n1:]

        y = (1 / tf.sqrt(tf.constant(2.0, dtype=tf.float32))) * tf.concat([(out1 + out2), tf.reverse((out1 - out2), axis=[1])], axis=1)

        return y + self.bias

# %%
class DiagonalLayer(tf.keras.layers.Layer):
    def __init__(self, units, trainable=True, kernel_initializer='he_normal', bias_initializer='zeros', **kwargs):
        super(DiagonalLayer, self).__init__(**kwargs)
        self.units = units
        self.kernel_initializer = kernel_initializer
        self.bias_initializer = bias_initializer
        self.trainable = trainable

    def build(self, input_shape):
        self.diag = self.add_weight(
            shape=(self.units,),
            initializer=tf.keras.initializers.get(self.kernel_initializer),
            trainable=self.trainable,
            name='diag'
        )
        self.bias = self.add_weight(
            shape=(self.units,),
            initializer=tf.keras.initializers.get(self.bias_initializer),
            trainable=self.trainable,
            name='bias'
        )

    def call(self, inputs):
        scaled = tf.multiply(inputs, self.diag)
        return scaled + self.bias

# %%
class ScalingLayer(tf.keras.layers.Layer):
    def __init__(self, units, initial_scale=1.0, trainable=True, kernel_initializer='he_normal', bias_initializer='zeros', **kwargs):
        super(ScalingLayer, self).__init__(**kwargs)
        self.units = units
        self.initial_scale = initial_scale
        self.kernel_initializer = kernel_initializer
        self.bias_initializer = bias_initializer

    def build(self, input_shape):

      self.log_scale = self.add_weight(
          shape=(),
          initializer=tf.keras.initializers.Constant(self.initial_scale),
          trainable=True,
          name="log_scale",
      )
      self.diag = self.add_weight(
          shape=(self.units,),
          initializer=tf.keras.initializers.get(self.kernel_initializer),
          regularizer=tf.keras.regularizers.l2(1e-4),
          trainable=True,
          name='diag'
      )
      self.bias = self.add_weight(
          shape=(self.units,),
          initializer=tf.keras.initializers.get(self.bias_initializer),
          trainable=True,
          name='bias'
        )

      super().build(input_shape)

    def call(self, inputs):
      perm = tf.concat([inputs[:, ::2], inputs[:, 1::2][:, ::-1]], axis=-1)

      dim = tf.shape(perm)[1]

      D_hat_n = tf.exp(self.log_scale * tf.cast(tf.range(dim), tf.float32))

      scaled = perm * D_hat_n * self.diag

      return scaled + self.bias

# %% [markdown]
# Model

# %%
def custom_accuracy(y_true, y_pred):
    y_true_int = tf.cast(y_true*(q-1), tf.int32)
    y_pred_int = tf.cast(tf.round(y_pred*(q-1)), tf.int32)
    correct = tf.cast(tf.equal(y_true_int, y_pred_int), tf.float32)
    return tf.reduce_mean(correct)

def custom_accuracy_without_padding(y_true, y_pred):
    y_true_int = tf.cast(y_true * (q - 1), tf.int32)
    y_pred_int = tf.cast(tf.round(y_pred * (q - 1)), tf.int32)
    mask = tf.concat(
        [tf.ones((tf.shape(y_true)[0], n), dtype=tf.float32),
         tf.zeros((tf.shape(y_true)[0], n_padded - n), dtype=tf.float32)],
        axis=1
    )
    correct = tf.cast(tf.equal(y_true_int, y_pred_int), tf.float32) * mask
    return tf.reduce_sum(correct) / tf.reduce_sum(mask)

def custom_mse(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    loss = tf.reduce_mean(tf.square(tf.cast(y_true - y_pred, tf.float32)))
    return loss

# %%
from tensorflow.keras.layers import InputLayer, LeakyReLU, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

initial_log_scale = np.log(z0 / w0)
initial_scale = (z0 / w0)

input_shape = (n_padded,)
model = Sequential([
    InputLayer(shape=input_shape),
    FirstLayer(units=n_padded, trainable=True, name="first_layer"),
    # LeakyReLU(negative_slope=0.1),
    SecondLayer(units=n_padded, trainable=True, name="second_layer"),
    # LeakyReLU(negative_slope=0.1),
    ThirdLayer(units=n_padded, trainable=True, name="third_layer"),
    LeakyReLU(negative_slope=0.1),
    ScalingLayer(units=n_padded, initial_scale=initial_log_scale, trainable=True, kernel_initializer='ones', bias_initializer='zeros', name="scaling_layer"),
    LeakyReLU(negative_slope=0.1)
    # DiagonalLayer(units=n_padded, trainable=False, kernel_initializer='ones', bias_initializer='zeros', name="output_layer"),
    # Activation('linear')
])

# notes:
# 1. adding the diagonal layers in the middle worsens results
# 2. residual connections does not work
# 3. removing bias in hidden layers worsens performance
# 4. removing "LeakyReLU" activation in between layers improved performance


model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=custom_mse,
    metrics=[custom_mse, custom_accuracy_without_padding]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ first_layer (FirstLayer)        │ (None, 32)             │            63 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ second_layer (SecondLayer)      │ (None, 32)             │           226 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ third_layer (ThirdLayer)        │ (None, 32)             │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ scaling_layer (ScalingLayer)    │ (None, 32)             │            65 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 32)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 402 (1.57 KB)
#  Trainable params: 402 (1.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ------------- FLOP counts ---------------

# Create concrete function
input_shape = (1, n_padded)  # batch size 1
concrete_func = tf.function(model).get_concrete_function(tf.TensorSpec(input_shape, tf.float32))

from tensorflow.python.profiler import model_analyzer
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

profile_opts = ProfileOptionBuilder.float_operation()
flops = model_analyzer.profile(concrete_func.graph, options=profile_opts)

print('FLOPs:', flops.total_float_ops)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/profiler/internal/flops_registry.py:140: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# FLOPs: 864

# %% [markdown]
# Training

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

checkpoint_path = f"/content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_{n}.keras"

model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

adjust_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

history = model.fit(
    X_train, y_train,
    epochs=500,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[adjust_lr, early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/500
# 15/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.1427 - custom_mse: 0.2886 - loss: 0.2918
# Epoch 1: val_loss improved from inf to 0.24388, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 133ms/step - custom_accuracy_without_padding: 0.1421 - custom_mse: 0.2843 - loss: 0.2875 - val_custom_accuracy_without_padding: 0.1478 - val_custom_mse: 0.2398 - val_loss: 0.2439 - learning_rate: 0.0010
# Epoch 2/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.1481 - custom_mse: 0.2450 - loss: 0.2481
# Epoch 2: val_loss improved from 0.24388 to 0.21080, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.1454 - custom_mse: 0.2399 - loss: 0.2430 - val_custom_accuracy_without_padding: 0.1490 - val_custom_mse: 0.2066 - val_loss: 0.2108 - learning_rate: 0.0010
# Epoch 3/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.1425 - custom_mse: 0.2095 - loss: 0.2127
# Epoch 3: val_loss improved from 0.21080 to 0.18639, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1425 - custom_mse: 0.2079 - loss: 0.2111 - val_custom_accuracy_without_padding: 0.1551 - val_custom_mse: 0.1822 - val_loss: 0.1864 - learning_rate: 0.0010
# Epoch 4/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1485 - custom_mse: 0.1855 - loss: 0.1887
# Epoch 4: val_loss improved from 0.18639 to 0.16468, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1483 - custom_mse: 0.1848 - loss: 0.1880 - val_custom_accuracy_without_padding: 0.1491 - val_custom_mse: 0.1606 - val_loss: 0.1647 - learning_rate: 0.0010
# Epoch 5/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1446 - custom_mse: 0.1618 - loss: 0.1651
# Epoch 5: val_loss improved from 0.16468 to 0.13653, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.1444 - custom_mse: 0.1606 - loss: 0.1640 - val_custom_accuracy_without_padding: 0.1501 - val_custom_mse: 0.1328 - val_loss: 0.1365 - learning_rate: 0.0010
# Epoch 6/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.1481 - custom_mse: 0.1286 - loss: 0.1321
# Epoch 6: val_loss improved from 0.13653 to 0.09013, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.1485 - custom_mse: 0.1276 - loss: 0.1311 - val_custom_accuracy_without_padding: 0.1966 - val_custom_mse: 0.0867 - val_loss: 0.0901 - learning_rate: 0.0010
# Epoch 7/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.1808 - custom_mse: 0.0838 - loss: 0.0874
# Epoch 7: val_loss improved from 0.09013 to 0.07298, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.1844 - custom_mse: 0.0806 - loss: 0.0842 - val_custom_accuracy_without_padding: 0.1939 - val_custom_mse: 0.0693 - val_loss: 0.0730 - learning_rate: 0.0010
# Epoch 8/500
# 14/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.2082 - custom_mse: 0.0693 - loss: 0.0729
# Epoch 8: val_loss improved from 0.07298 to 0.06984, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.2073 - custom_mse: 0.0687 - loss: 0.0724 - val_custom_accuracy_without_padding: 0.1926 - val_custom_mse: 0.0662 - val_loss: 0.0698 - learning_rate: 0.0010
# Epoch 9/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.2187 - custom_mse: 0.0654 - loss: 0.0691
# Epoch 9: val_loss improved from 0.06984 to 0.06803, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.2188 - custom_mse: 0.0654 - loss: 0.0691 - val_custom_accuracy_without_padding: 0.2128 - val_custom_mse: 0.0645 - val_loss: 0.0680 - learning_rate: 0.0010
# Epoch 10/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2288 - custom_mse: 0.0645 - loss: 0.0682
# Epoch 10: val_loss improved from 0.06803 to 0.06691, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.2296 - custom_mse: 0.0644 - loss: 0.0681 - val_custom_accuracy_without_padding: 0.2325 - val_custom_mse: 0.0634 - val_loss: 0.0669 - learning_rate: 0.0010
# Epoch 11/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2501 - custom_mse: 0.0624 - loss: 0.0661
# Epoch 11: val_loss improved from 0.06691 to 0.06608, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.2503 - custom_mse: 0.0625 - loss: 0.0661 - val_custom_accuracy_without_padding: 0.2465 - val_custom_mse: 0.0625 - val_loss: 0.0661 - learning_rate: 0.0010
# Epoch 12/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.2550 - custom_mse: 0.0621 - loss: 0.0658
# Epoch 12: val_loss improved from 0.06608 to 0.06523, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.2558 - custom_mse: 0.0621 - loss: 0.0657 - val_custom_accuracy_without_padding: 0.2566 - val_custom_mse: 0.0617 - val_loss: 0.0652 - learning_rate: 0.0010
# Epoch 13/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.2686 - custom_mse: 0.0606 - loss: 0.0643
# Epoch 13: val_loss improved from 0.06523 to 0.06437, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.2689 - custom_mse: 0.0606 - loss: 0.0643 - val_custom_accuracy_without_padding: 0.2733 - val_custom_mse: 0.0609 - val_loss: 0.0644 - learning_rate: 0.0010
# Epoch 14/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.2839 - custom_mse: 0.0603 - loss: 0.0640
# Epoch 14: val_loss improved from 0.06437 to 0.06370, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.2833 - custom_mse: 0.0602 - loss: 0.0639 - val_custom_accuracy_without_padding: 0.2801 - val_custom_mse: 0.0602 - val_loss: 0.0637 - learning_rate: 0.0010
# Epoch 15/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.2861 - custom_mse: 0.0592 - loss: 0.0628
# Epoch 15: val_loss improved from 0.06370 to 0.06300, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - custom_accuracy_without_padding: 0.2862 - custom_mse: 0.0592 - loss: 0.0629 - val_custom_accuracy_without_padding: 0.2892 - val_custom_mse: 0.0595 - val_loss: 0.0630 - learning_rate: 0.0010
# Epoch 16/500
# 17/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.2931 - custom_mse: 0.0591 - loss: 0.0627
# Epoch 16: val_loss improved from 0.06300 to 0.06222, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - custom_accuracy_without_padding: 0.2937 - custom_mse: 0.0591 - loss: 0.0627 - val_custom_accuracy_without_padding: 0.2966 - val_custom_mse: 0.0587 - val_loss: 0.0622 - learning_rate: 0.0010
# Epoch 17/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.2999 - custom_mse: 0.0580 - loss: 0.0616
# Epoch 17: val_loss improved from 0.06222 to 0.06199, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - custom_accuracy_without_padding: 0.3000 - custom_mse: 0.0580 - loss: 0.0616 - val_custom_accuracy_without_padding: 0.2923 - val_custom_mse: 0.0585 - val_loss: 0.0620 - learning_rate: 0.0010
# Epoch 18/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.3032 - custom_mse: 0.0577 - loss: 0.0613
# Epoch 18: val_loss improved from 0.06199 to 0.06126, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.3037 - custom_mse: 0.0577 - loss: 0.0613 - val_custom_accuracy_without_padding: 0.3057 - val_custom_mse: 0.0577 - val_loss: 0.0613 - learning_rate: 0.0010
# Epoch 19/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3052 - custom_mse: 0.0576 - loss: 0.0612
# Epoch 19: val_loss improved from 0.06126 to 0.06036, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.3058 - custom_mse: 0.0575 - loss: 0.0612 - val_custom_accuracy_without_padding: 0.3127 - val_custom_mse: 0.0569 - val_loss: 0.0604 - learning_rate: 0.0010
# Epoch 20/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3163 - custom_mse: 0.0556 - loss: 0.0592
# Epoch 20: val_loss improved from 0.06036 to 0.05994, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.3163 - custom_mse: 0.0557 - loss: 0.0593 - val_custom_accuracy_without_padding: 0.3158 - val_custom_mse: 0.0565 - val_loss: 0.0599 - learning_rate: 0.0010
# Epoch 21/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3198 - custom_mse: 0.0558 - loss: 0.0594
# Epoch 21: val_loss improved from 0.05994 to 0.05929, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.3198 - custom_mse: 0.0558 - loss: 0.0594 - val_custom_accuracy_without_padding: 0.3191 - val_custom_mse: 0.0559 - val_loss: 0.0593 - learning_rate: 0.0010
# Epoch 22/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3279 - custom_mse: 0.0554 - loss: 0.0591
# Epoch 22: val_loss improved from 0.05929 to 0.05886, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.3279 - custom_mse: 0.0554 - loss: 0.0590 - val_custom_accuracy_without_padding: 0.3247 - val_custom_mse: 0.0554 - val_loss: 0.0589 - learning_rate: 0.0010
# Epoch 23/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3287 - custom_mse: 0.0548 - loss: 0.0584
# Epoch 23: val_loss improved from 0.05886 to 0.05830, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.3288 - custom_mse: 0.0548 - loss: 0.0584 - val_custom_accuracy_without_padding: 0.3234 - val_custom_mse: 0.0549 - val_loss: 0.0583 - learning_rate: 0.0010
# Epoch 24/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3326 - custom_mse: 0.0541 - loss: 0.0578
# Epoch 24: val_loss improved from 0.05830 to 0.05775, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.3329 - custom_mse: 0.0541 - loss: 0.0577 - val_custom_accuracy_without_padding: 0.3348 - val_custom_mse: 0.0543 - val_loss: 0.0578 - learning_rate: 0.0010
# Epoch 25/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.3392 - custom_mse: 0.0541 - loss: 0.0577
# Epoch 25: val_loss improved from 0.05775 to 0.05728, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_accuracy_without_padding: 0.3398 - custom_mse: 0.0540 - loss: 0.0576 - val_custom_accuracy_without_padding: 0.3328 - val_custom_mse: 0.0539 - val_loss: 0.0573 - learning_rate: 0.0010
# Epoch 26/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3417 - custom_mse: 0.0529 - loss: 0.0565
# Epoch 26: val_loss improved from 0.05728 to 0.05663, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.3421 - custom_mse: 0.0529 - loss: 0.0565 - val_custom_accuracy_without_padding: 0.3461 - val_custom_mse: 0.0533 - val_loss: 0.0566 - learning_rate: 0.0010
# Epoch 27/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3570 - custom_mse: 0.0525 - loss: 0.0561
# Epoch 27: val_loss improved from 0.05663 to 0.05619, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.3568 - custom_mse: 0.0525 - loss: 0.0561 - val_custom_accuracy_without_padding: 0.3520 - val_custom_mse: 0.0528 - val_loss: 0.0562 - learning_rate: 0.0010
# Epoch 28/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3630 - custom_mse: 0.0521 - loss: 0.0557
# Epoch 28: val_loss improved from 0.05619 to 0.05565, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_accuracy_without_padding: 0.3624 - custom_mse: 0.0520 - loss: 0.0556 - val_custom_accuracy_without_padding: 0.3600 - val_custom_mse: 0.0523 - val_loss: 0.0556 - learning_rate: 0.0010
# Epoch 29/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3675 - custom_mse: 0.0515 - loss: 0.0551
# Epoch 29: val_loss improved from 0.05565 to 0.05536, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.3685 - custom_mse: 0.0515 - loss: 0.0551 - val_custom_accuracy_without_padding: 0.3647 - val_custom_mse: 0.0520 - val_loss: 0.0554 - learning_rate: 0.0010
# Epoch 30/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3764 - custom_mse: 0.0508 - loss: 0.0544
# Epoch 30: val_loss improved from 0.05536 to 0.05466, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.3767 - custom_mse: 0.0508 - loss: 0.0544 - val_custom_accuracy_without_padding: 0.3758 - val_custom_mse: 0.0513 - val_loss: 0.0547 - learning_rate: 0.0010
# Epoch 31/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3857 - custom_mse: 0.0500 - loss: 0.0536
# Epoch 31: val_loss improved from 0.05466 to 0.05413, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.3858 - custom_mse: 0.0500 - loss: 0.0536 - val_custom_accuracy_without_padding: 0.3821 - val_custom_mse: 0.0508 - val_loss: 0.0541 - learning_rate: 0.0010
# Epoch 32/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.3927 - custom_mse: 0.0504 - loss: 0.0540
# Epoch 32: val_loss improved from 0.05413 to 0.05387, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.3927 - custom_mse: 0.0504 - loss: 0.0540 - val_custom_accuracy_without_padding: 0.3841 - val_custom_mse: 0.0506 - val_loss: 0.0539 - learning_rate: 0.0010
# Epoch 33/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.3979 - custom_mse: 0.0496 - loss: 0.0531
# Epoch 33: val_loss improved from 0.05387 to 0.05354, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_accuracy_without_padding: 0.3978 - custom_mse: 0.0496 - loss: 0.0532 - val_custom_accuracy_without_padding: 0.3934 - val_custom_mse: 0.0502 - val_loss: 0.0535 - learning_rate: 0.0010
# Epoch 34/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.4067 - custom_mse: 0.0494 - loss: 0.0530
# Epoch 34: val_loss improved from 0.05354 to 0.05344, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy_without_padding: 0.4060 - custom_mse: 0.0494 - loss: 0.0530 - val_custom_accuracy_without_padding: 0.3970 - val_custom_mse: 0.0502 - val_loss: 0.0534 - learning_rate: 0.0010
# Epoch 35/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.4085 - custom_mse: 0.0490 - loss: 0.0526
# Epoch 35: val_loss improved from 0.05344 to 0.05271, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.4092 - custom_mse: 0.0490 - loss: 0.0526 - val_custom_accuracy_without_padding: 0.4062 - val_custom_mse: 0.0495 - val_loss: 0.0527 - learning_rate: 0.0010
# Epoch 36/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.4171 - custom_mse: 0.0483 - loss: 0.0519
# Epoch 36: val_loss improved from 0.05271 to 0.05220, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.4175 - custom_mse: 0.0484 - loss: 0.0519 - val_custom_accuracy_without_padding: 0.4089 - val_custom_mse: 0.0489 - val_loss: 0.0522 - learning_rate: 0.0010
# Epoch 37/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.4272 - custom_mse: 0.0480 - loss: 0.0515
# Epoch 37: val_loss improved from 0.05220 to 0.05184, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy_without_padding: 0.4280 - custom_mse: 0.0480 - loss: 0.0515 - val_custom_accuracy_without_padding: 0.4274 - val_custom_mse: 0.0486 - val_loss: 0.0518 - learning_rate: 0.0010
# Epoch 38/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.4395 - custom_mse: 0.0479 - loss: 0.0515
# Epoch 38: val_loss improved from 0.05184 to 0.05129, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.4403 - custom_mse: 0.0480 - loss: 0.0515 - val_custom_accuracy_without_padding: 0.4358 - val_custom_mse: 0.0481 - val_loss: 0.0513 - learning_rate: 0.0010
# Epoch 39/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.4495 - custom_mse: 0.0471 - loss: 0.0506
# Epoch 39: val_loss improved from 0.05129 to 0.05112, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - custom_accuracy_without_padding: 0.4496 - custom_mse: 0.0471 - loss: 0.0506 - val_custom_accuracy_without_padding: 0.4430 - val_custom_mse: 0.0480 - val_loss: 0.0511 - learning_rate: 0.0010
# Epoch 40/500
# 18/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.4537 - custom_mse: 0.0468 - loss: 0.0503
# Epoch 40: val_loss improved from 0.05112 to 0.05068, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - custom_accuracy_without_padding: 0.4545 - custom_mse: 0.0469 - loss: 0.0504 - val_custom_accuracy_without_padding: 0.4530 - val_custom_mse: 0.0475 - val_loss: 0.0507 - learning_rate: 0.0010
# Epoch 41/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.4645 - custom_mse: 0.0466 - loss: 0.0500
# Epoch 41: val_loss improved from 0.05068 to 0.05033, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - custom_accuracy_without_padding: 0.4648 - custom_mse: 0.0466 - loss: 0.0500 - val_custom_accuracy_without_padding: 0.4559 - val_custom_mse: 0.0472 - val_loss: 0.0503 - learning_rate: 0.0010
# Epoch 42/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.4738 - custom_mse: 0.0464 - loss: 0.0498
# Epoch 42: val_loss improved from 0.05033 to 0.04984, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.4739 - custom_mse: 0.0464 - loss: 0.0498 - val_custom_accuracy_without_padding: 0.4640 - val_custom_mse: 0.0467 - val_loss: 0.0498 - learning_rate: 0.0010
# Epoch 43/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.4775 - custom_mse: 0.0458 - loss: 0.0492
# Epoch 43: val_loss improved from 0.04984 to 0.04957, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.4777 - custom_mse: 0.0458 - loss: 0.0493 - val_custom_accuracy_without_padding: 0.4691 - val_custom_mse: 0.0465 - val_loss: 0.0496 - learning_rate: 0.0010
# Epoch 44/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.4852 - custom_mse: 0.0460 - loss: 0.0494
# Epoch 44: val_loss improved from 0.04957 to 0.04943, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.4853 - custom_mse: 0.0460 - loss: 0.0494 - val_custom_accuracy_without_padding: 0.4732 - val_custom_mse: 0.0464 - val_loss: 0.0494 - learning_rate: 0.0010
# Epoch 45/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.4938 - custom_mse: 0.0450 - loss: 0.0484
# Epoch 45: val_loss improved from 0.04943 to 0.04935, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.4941 - custom_mse: 0.0451 - loss: 0.0485 - val_custom_accuracy_without_padding: 0.4886 - val_custom_mse: 0.0462 - val_loss: 0.0494 - learning_rate: 0.0010
# Epoch 46/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5048 - custom_mse: 0.0452 - loss: 0.0485
# Epoch 46: val_loss improved from 0.04935 to 0.04853, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.5048 - custom_mse: 0.0452 - loss: 0.0486 - val_custom_accuracy_without_padding: 0.4955 - val_custom_mse: 0.0454 - val_loss: 0.0485 - learning_rate: 0.0010
# Epoch 47/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.5055 - custom_mse: 0.0450 - loss: 0.0483
# Epoch 47: val_loss did not improve from 0.04853
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.5062 - custom_mse: 0.0450 - loss: 0.0483 - val_custom_accuracy_without_padding: 0.4974 - val_custom_mse: 0.0455 - val_loss: 0.0485 - learning_rate: 0.0010
# Epoch 48/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5160 - custom_mse: 0.0448 - loss: 0.0481
# Epoch 48: val_loss improved from 0.04853 to 0.04813, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.5158 - custom_mse: 0.0447 - loss: 0.0481 - val_custom_accuracy_without_padding: 0.4965 - val_custom_mse: 0.0452 - val_loss: 0.0481 - learning_rate: 0.0010
# Epoch 49/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5189 - custom_mse: 0.0446 - loss: 0.0480
# Epoch 49: val_loss improved from 0.04813 to 0.04784, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.5189 - custom_mse: 0.0446 - loss: 0.0479 - val_custom_accuracy_without_padding: 0.5162 - val_custom_mse: 0.0449 - val_loss: 0.0478 - learning_rate: 0.0010
# Epoch 50/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5221 - custom_mse: 0.0445 - loss: 0.0478
# Epoch 50: val_loss improved from 0.04784 to 0.04724, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.5221 - custom_mse: 0.0445 - loss: 0.0478 - val_custom_accuracy_without_padding: 0.5150 - val_custom_mse: 0.0443 - val_loss: 0.0472 - learning_rate: 0.0010
# Epoch 51/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5268 - custom_mse: 0.0438 - loss: 0.0471
# Epoch 51: val_loss improved from 0.04724 to 0.04699, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.5270 - custom_mse: 0.0438 - loss: 0.0471 - val_custom_accuracy_without_padding: 0.5179 - val_custom_mse: 0.0440 - val_loss: 0.0470 - learning_rate: 0.0010
# Epoch 52/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5324 - custom_mse: 0.0434 - loss: 0.0466
# Epoch 52: val_loss improved from 0.04699 to 0.04675, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.5324 - custom_mse: 0.0435 - loss: 0.0467 - val_custom_accuracy_without_padding: 0.5192 - val_custom_mse: 0.0438 - val_loss: 0.0467 - learning_rate: 0.0010
# Epoch 53/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5408 - custom_mse: 0.0434 - loss: 0.0466
# Epoch 53: val_loss improved from 0.04675 to 0.04652, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.5396 - custom_mse: 0.0434 - loss: 0.0466 - val_custom_accuracy_without_padding: 0.5228 - val_custom_mse: 0.0436 - val_loss: 0.0465 - learning_rate: 0.0010
# Epoch 54/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.5364 - custom_mse: 0.0429 - loss: 0.0461
# Epoch 54: val_loss improved from 0.04652 to 0.04617, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - custom_accuracy_without_padding: 0.5367 - custom_mse: 0.0429 - loss: 0.0461 - val_custom_accuracy_without_padding: 0.5256 - val_custom_mse: 0.0432 - val_loss: 0.0462 - learning_rate: 0.0010
# Epoch 55/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.5400 - custom_mse: 0.0427 - loss: 0.0458
# Epoch 55: val_loss improved from 0.04617 to 0.04590, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - custom_accuracy_without_padding: 0.5404 - custom_mse: 0.0427 - loss: 0.0459 - val_custom_accuracy_without_padding: 0.5351 - val_custom_mse: 0.0431 - val_loss: 0.0459 - learning_rate: 0.0010
# Epoch 56/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_accuracy_without_padding: 0.5437 - custom_mse: 0.0433 - loss: 0.0464
# Epoch 56: val_loss improved from 0.04590 to 0.04559, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - custom_accuracy_without_padding: 0.5440 - custom_mse: 0.0432 - loss: 0.0463 - val_custom_accuracy_without_padding: 0.5410 - val_custom_mse: 0.0428 - val_loss: 0.0456 - learning_rate: 0.0010
# Epoch 57/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5472 - custom_mse: 0.0427 - loss: 0.0458
# Epoch 57: val_loss improved from 0.04559 to 0.04543, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.5474 - custom_mse: 0.0427 - loss: 0.0458 - val_custom_accuracy_without_padding: 0.5466 - val_custom_mse: 0.0426 - val_loss: 0.0454 - learning_rate: 0.0010
# Epoch 58/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5528 - custom_mse: 0.0418 - loss: 0.0449
# Epoch 58: val_loss improved from 0.04543 to 0.04525, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.5528 - custom_mse: 0.0418 - loss: 0.0449 - val_custom_accuracy_without_padding: 0.5428 - val_custom_mse: 0.0424 - val_loss: 0.0452 - learning_rate: 0.0010
# Epoch 59/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5611 - custom_mse: 0.0421 - loss: 0.0451
# Epoch 59: val_loss improved from 0.04525 to 0.04485, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_accuracy_without_padding: 0.5610 - custom_mse: 0.0421 - loss: 0.0451 - val_custom_accuracy_without_padding: 0.5488 - val_custom_mse: 0.0420 - val_loss: 0.0448 - learning_rate: 0.0010
# Epoch 60/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.5568 - custom_mse: 0.0418 - loss: 0.0448
# Epoch 60: val_loss improved from 0.04485 to 0.04478, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - custom_accuracy_without_padding: 0.5573 - custom_mse: 0.0418 - loss: 0.0448 - val_custom_accuracy_without_padding: 0.5536 - val_custom_mse: 0.0420 - val_loss: 0.0448 - learning_rate: 0.0010
# Epoch 61/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.5646 - custom_mse: 0.0411 - loss: 0.0441
# Epoch 61: val_loss improved from 0.04478 to 0.04458, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - custom_accuracy_without_padding: 0.5644 - custom_mse: 0.0411 - loss: 0.0441 - val_custom_accuracy_without_padding: 0.5577 - val_custom_mse: 0.0419 - val_loss: 0.0446 - learning_rate: 0.0010
# Epoch 62/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.5639 - custom_mse: 0.0416 - loss: 0.0446
# Epoch 62: val_loss improved from 0.04458 to 0.04405, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - custom_accuracy_without_padding: 0.5643 - custom_mse: 0.0416 - loss: 0.0446 - val_custom_accuracy_without_padding: 0.5618 - val_custom_mse: 0.0413 - val_loss: 0.0440 - learning_rate: 0.0010
# Epoch 63/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5679 - custom_mse: 0.0412 - loss: 0.0442
# Epoch 63: val_loss improved from 0.04405 to 0.04403, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.5672 - custom_mse: 0.0412 - loss: 0.0442 - val_custom_accuracy_without_padding: 0.5622 - val_custom_mse: 0.0413 - val_loss: 0.0440 - learning_rate: 0.0010
# Epoch 64/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5731 - custom_mse: 0.0403 - loss: 0.0432
# Epoch 64: val_loss improved from 0.04403 to 0.04395, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.5723 - custom_mse: 0.0406 - loss: 0.0436 - val_custom_accuracy_without_padding: 0.5643 - val_custom_mse: 0.0412 - val_loss: 0.0440 - learning_rate: 0.0010
# Epoch 65/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5754 - custom_mse: 0.0412 - loss: 0.0441
# Epoch 65: val_loss improved from 0.04395 to 0.04382, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.5756 - custom_mse: 0.0411 - loss: 0.0440 - val_custom_accuracy_without_padding: 0.5772 - val_custom_mse: 0.0412 - val_loss: 0.0438 - learning_rate: 0.0010
# Epoch 66/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5825 - custom_mse: 0.0408 - loss: 0.0436
# Epoch 66: val_loss improved from 0.04382 to 0.04372, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.5823 - custom_mse: 0.0408 - loss: 0.0436 - val_custom_accuracy_without_padding: 0.5756 - val_custom_mse: 0.0411 - val_loss: 0.0437 - learning_rate: 0.0010
# Epoch 67/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5785 - custom_mse: 0.0413 - loss: 0.0441
# Epoch 67: val_loss improved from 0.04372 to 0.04325, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.5790 - custom_mse: 0.0411 - loss: 0.0440 - val_custom_accuracy_without_padding: 0.5775 - val_custom_mse: 0.0406 - val_loss: 0.0432 - learning_rate: 0.0010
# Epoch 68/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5810 - custom_mse: 0.0404 - loss: 0.0432
# Epoch 68: val_loss improved from 0.04325 to 0.04317, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.5813 - custom_mse: 0.0404 - loss: 0.0432 - val_custom_accuracy_without_padding: 0.5832 - val_custom_mse: 0.0405 - val_loss: 0.0432 - learning_rate: 0.0010
# Epoch 69/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5844 - custom_mse: 0.0402 - loss: 0.0430
# Epoch 69: val_loss did not improve from 0.04317
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.5845 - custom_mse: 0.0402 - loss: 0.0430 - val_custom_accuracy_without_padding: 0.5840 - val_custom_mse: 0.0408 - val_loss: 0.0434 - learning_rate: 0.0010
# Epoch 70/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.5845 - custom_mse: 0.0410 - loss: 0.0437
# Epoch 70: val_loss improved from 0.04317 to 0.04284, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.5851 - custom_mse: 0.0407 - loss: 0.0435 - val_custom_accuracy_without_padding: 0.5880 - val_custom_mse: 0.0403 - val_loss: 0.0428 - learning_rate: 0.0010
# Epoch 71/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5930 - custom_mse: 0.0392 - loss: 0.0420
# Epoch 71: val_loss improved from 0.04284 to 0.04261, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.5930 - custom_mse: 0.0393 - loss: 0.0420 - val_custom_accuracy_without_padding: 0.5876 - val_custom_mse: 0.0401 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 72/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5949 - custom_mse: 0.0396 - loss: 0.0423
# Epoch 72: val_loss improved from 0.04261 to 0.04261, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - custom_accuracy_without_padding: 0.5947 - custom_mse: 0.0396 - loss: 0.0424 - val_custom_accuracy_without_padding: 0.5911 - val_custom_mse: 0.0400 - val_loss: 0.0426 - learning_rate: 0.0010
# Epoch 73/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5930 - custom_mse: 0.0393 - loss: 0.0419
# Epoch 73: val_loss improved from 0.04261 to 0.04247, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.5930 - custom_mse: 0.0393 - loss: 0.0420 - val_custom_accuracy_without_padding: 0.5906 - val_custom_mse: 0.0399 - val_loss: 0.0425 - learning_rate: 0.0010
# Epoch 74/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5955 - custom_mse: 0.0396 - loss: 0.0423
# Epoch 74: val_loss improved from 0.04247 to 0.04213, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.5952 - custom_mse: 0.0396 - loss: 0.0423 - val_custom_accuracy_without_padding: 0.5904 - val_custom_mse: 0.0396 - val_loss: 0.0421 - learning_rate: 0.0010
# Epoch 75/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5938 - custom_mse: 0.0398 - loss: 0.0425
# Epoch 75: val_loss improved from 0.04213 to 0.04199, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.5938 - custom_mse: 0.0398 - loss: 0.0424 - val_custom_accuracy_without_padding: 0.5939 - val_custom_mse: 0.0395 - val_loss: 0.0420 - learning_rate: 0.0010
# Epoch 76/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5971 - custom_mse: 0.0396 - loss: 0.0422
# Epoch 76: val_loss improved from 0.04199 to 0.04178, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.5970 - custom_mse: 0.0395 - loss: 0.0421 - val_custom_accuracy_without_padding: 0.5928 - val_custom_mse: 0.0393 - val_loss: 0.0418 - learning_rate: 0.0010
# Epoch 77/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5983 - custom_mse: 0.0385 - loss: 0.0411
# Epoch 77: val_loss improved from 0.04178 to 0.04167, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.5978 - custom_mse: 0.0388 - loss: 0.0414 - val_custom_accuracy_without_padding: 0.5916 - val_custom_mse: 0.0393 - val_loss: 0.0417 - learning_rate: 0.0010
# Epoch 78/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5965 - custom_mse: 0.0383 - loss: 0.0409
# Epoch 78: val_loss improved from 0.04167 to 0.04152, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.5965 - custom_mse: 0.0383 - loss: 0.0409 - val_custom_accuracy_without_padding: 0.5947 - val_custom_mse: 0.0391 - val_loss: 0.0415 - learning_rate: 0.0010
# Epoch 79/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5998 - custom_mse: 0.0383 - loss: 0.0409
# Epoch 79: val_loss improved from 0.04152 to 0.04127, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy_without_padding: 0.5996 - custom_mse: 0.0384 - loss: 0.0409 - val_custom_accuracy_without_padding: 0.5933 - val_custom_mse: 0.0389 - val_loss: 0.0413 - learning_rate: 0.0010
# Epoch 80/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5947 - custom_mse: 0.0392 - loss: 0.0417
# Epoch 80: val_loss improved from 0.04127 to 0.04127, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.5948 - custom_mse: 0.0392 - loss: 0.0417 - val_custom_accuracy_without_padding: 0.5994 - val_custom_mse: 0.0390 - val_loss: 0.0413 - learning_rate: 0.0010
# Epoch 81/500
# 13/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.5964 - custom_mse: 0.0382 - loss: 0.0406
# Epoch 81: val_loss improved from 0.04127 to 0.04124, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy_without_padding: 0.5974 - custom_mse: 0.0383 - loss: 0.0408 - val_custom_accuracy_without_padding: 0.6000 - val_custom_mse: 0.0389 - val_loss: 0.0412 - learning_rate: 0.0010
# Epoch 82/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.5992 - custom_mse: 0.0385 - loss: 0.0410
# Epoch 82: val_loss improved from 0.04124 to 0.04104, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.5990 - custom_mse: 0.0385 - loss: 0.0410 - val_custom_accuracy_without_padding: 0.5997 - val_custom_mse: 0.0388 - val_loss: 0.0410 - learning_rate: 0.0010
# Epoch 83/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.5968 - custom_mse: 0.0384 - loss: 0.0409
# Epoch 83: val_loss improved from 0.04104 to 0.04070, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - custom_accuracy_without_padding: 0.5971 - custom_mse: 0.0384 - loss: 0.0408 - val_custom_accuracy_without_padding: 0.5982 - val_custom_mse: 0.0385 - val_loss: 0.0407 - learning_rate: 0.0010
# Epoch 84/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.6036 - custom_mse: 0.0370 - loss: 0.0394
# Epoch 84: val_loss improved from 0.04070 to 0.04067, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - custom_accuracy_without_padding: 0.6029 - custom_mse: 0.0372 - loss: 0.0396 - val_custom_accuracy_without_padding: 0.6015 - val_custom_mse: 0.0385 - val_loss: 0.0407 - learning_rate: 0.0010
# Epoch 85/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.6010 - custom_mse: 0.0384 - loss: 0.0408
# Epoch 85: val_loss improved from 0.04067 to 0.04053, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - custom_accuracy_without_padding: 0.6011 - custom_mse: 0.0383 - loss: 0.0407 - val_custom_accuracy_without_padding: 0.6022 - val_custom_mse: 0.0384 - val_loss: 0.0405 - learning_rate: 0.0010
# Epoch 86/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.6025 - custom_mse: 0.0385 - loss: 0.0408
# Epoch 86: val_loss improved from 0.04053 to 0.04021, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_accuracy_without_padding: 0.6025 - custom_mse: 0.0384 - loss: 0.0408 - val_custom_accuracy_without_padding: 0.6045 - val_custom_mse: 0.0380 - val_loss: 0.0402 - learning_rate: 0.0010
# Epoch 87/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6030 - custom_mse: 0.0377 - loss: 0.0400
# Epoch 87: val_loss improved from 0.04021 to 0.03989, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - custom_accuracy_without_padding: 0.6030 - custom_mse: 0.0377 - loss: 0.0400 - val_custom_accuracy_without_padding: 0.6047 - val_custom_mse: 0.0378 - val_loss: 0.0399 - learning_rate: 0.0010
# Epoch 88/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - custom_accuracy_without_padding: 0.6067 - custom_mse: 0.0380 - loss: 0.0404
# Epoch 88: val_loss improved from 0.03989 to 0.03987, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.6067 - custom_mse: 0.0380 - loss: 0.0403 - val_custom_accuracy_without_padding: 0.6086 - val_custom_mse: 0.0377 - val_loss: 0.0399 - learning_rate: 0.0010
# Epoch 89/500
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.6082 - custom_mse: 0.0381 - loss: 0.0404
# Epoch 89: val_loss did not improve from 0.03987
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.6083 - custom_mse: 0.0380 - loss: 0.0403 - val_custom_accuracy_without_padding: 0.6093 - val_custom_mse: 0.0379 - val_loss: 0.0401 - learning_rate: 0.0010
# Epoch 90/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.6098 - custom_mse: 0.0370 - loss: 0.0393
# ...
# Epoch 227/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7101 - custom_mse: 0.0270 - loss: 0.0283
# Epoch 227: val_loss did not improve from 0.02796
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7101 - custom_mse: 0.0270 - loss: 0.0283 - val_custom_accuracy_without_padding: 0.7049 - val_custom_mse: 0.0266 - val_loss: 0.0280 - learning_rate: 1.5625e-05
# Epoch 228/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7088 - custom_mse: 0.0272 - loss: 0.0285
# Epoch 228: val_loss did not improve from 0.02796
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.7090 - custom_mse: 0.0271 - loss: 0.0285 - val_custom_accuracy_without_padding: 0.7054 - val_custom_mse: 0.0266 - val_loss: 0.0280 - learning_rate: 1.5625e-05
# Epoch 229/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7085 - custom_mse: 0.0267 - loss: 0.0280
# Epoch 229: val_loss did not improve from 0.02796
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7085 - custom_mse: 0.0267 - loss: 0.0280 - val_custom_accuracy_without_padding: 0.7049 - val_custom_mse: 0.0266 - val_loss: 0.0280 - learning_rate: 1.5625e-05
# Epoch 230/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7080 - custom_mse: 0.0266 - loss: 0.0279
# Epoch 230: val_loss did not improve from 0.02796
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.7083 - custom_mse: 0.0266 - loss: 0.0279 - val_custom_accuracy_without_padding: 0.7050 - val_custom_mse: 0.0266 - val_loss: 0.0280 - learning_rate: 1.5625e-05
# Epoch 231/500
# 17/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.7108 - custom_mse: 0.0266 - loss: 0.0280
# Epoch 231: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 231: val_loss improved from 0.02796 to 0.02795, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.7103 - custom_mse: 0.0267 - loss: 0.0280 - val_custom_accuracy_without_padding: 0.7047 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 1.5625e-05
# Epoch 232/500
# 23/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7114 - custom_mse: 0.0270 - loss: 0.0283
# Epoch 232: val_loss did not improve from 0.02795
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7112 - custom_mse: 0.0269 - loss: 0.0283 - val_custom_accuracy_without_padding: 0.7047 - val_custom_mse: 0.0266 - val_loss: 0.0280 - learning_rate: 7.8125e-06
# Epoch 233/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7073 - custom_mse: 0.0277 - loss: 0.0290
# Epoch 233: val_loss did not improve from 0.02795
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7078 - custom_mse: 0.0276 - loss: 0.0289 - val_custom_accuracy_without_padding: 0.7042 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 7.8125e-06
# Epoch 234/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7077 - custom_mse: 0.0273 - loss: 0.0286
# Epoch 234: val_loss did not improve from 0.02795
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.7081 - custom_mse: 0.0271 - loss: 0.0285 - val_custom_accuracy_without_padding: 0.7045 - val_custom_mse: 0.0266 - val_loss: 0.0280 - learning_rate: 7.8125e-06
# Epoch 235/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7109 - custom_mse: 0.0269 - loss: 0.0282
# Epoch 235: val_loss did not improve from 0.02795
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7106 - custom_mse: 0.0269 - loss: 0.0282 - val_custom_accuracy_without_padding: 0.7049 - val_custom_mse: 0.0266 - val_loss: 0.0280 - learning_rate: 7.8125e-06
# Epoch 236/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7091 - custom_mse: 0.0266 - loss: 0.0279
# Epoch 236: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 236: val_loss did not improve from 0.02795
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7092 - custom_mse: 0.0266 - loss: 0.0279 - val_custom_accuracy_without_padding: 0.7044 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 7.8125e-06
# Epoch 237/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7062 - custom_mse: 0.0271 - loss: 0.0284
# Epoch 237: val_loss improved from 0.02795 to 0.02795, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.7067 - custom_mse: 0.0271 - loss: 0.0284 - val_custom_accuracy_without_padding: 0.7044 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 3.9063e-06
# Epoch 238/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7098 - custom_mse: 0.0267 - loss: 0.0280
# Epoch 238: val_loss did not improve from 0.02795
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7097 - custom_mse: 0.0267 - loss: 0.0280 - val_custom_accuracy_without_padding: 0.7044 - val_custom_mse: 0.0266 - val_loss: 0.0280 - learning_rate: 3.9063e-06
# Epoch 239/500
# 19/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7091 - custom_mse: 0.0271 - loss: 0.0284
# Epoch 239: val_loss improved from 0.02795 to 0.02794, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.7092 - custom_mse: 0.0270 - loss: 0.0283 - val_custom_accuracy_without_padding: 0.7047 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 3.9063e-06
# Epoch 240/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7092 - custom_mse: 0.0263 - loss: 0.0276
# Epoch 240: val_loss improved from 0.02794 to 0.02794, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy_without_padding: 0.7092 - custom_mse: 0.0263 - loss: 0.0277 - val_custom_accuracy_without_padding: 0.7042 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 3.9063e-06
# Epoch 241/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7111 - custom_mse: 0.0266 - loss: 0.0279
# Epoch 241: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 241: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.7109 - custom_mse: 0.0266 - loss: 0.0279 - val_custom_accuracy_without_padding: 0.7042 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 3.9063e-06
# Epoch 242/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7071 - custom_mse: 0.0268 - loss: 0.0281
# Epoch 242: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.7075 - custom_mse: 0.0268 - loss: 0.0281 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 1.9531e-06
# Epoch 243/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7073 - custom_mse: 0.0268 - loss: 0.0281
# Epoch 243: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.7078 - custom_mse: 0.0268 - loss: 0.0281 - val_custom_accuracy_without_padding: 0.7042 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 1.9531e-06
# Epoch 244/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7113 - custom_mse: 0.0265 - loss: 0.0278
# Epoch 244: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7110 - custom_mse: 0.0265 - loss: 0.0278 - val_custom_accuracy_without_padding: 0.7044 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 1.9531e-06
# Epoch 245/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7089 - custom_mse: 0.0267 - loss: 0.0280
# Epoch 245: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7090 - custom_mse: 0.0267 - loss: 0.0280 - val_custom_accuracy_without_padding: 0.7042 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 1.9531e-06
# Epoch 246/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7083 - custom_mse: 0.0271 - loss: 0.0284
# Epoch 246: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 246: val_loss improved from 0.02794 to 0.02794, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - custom_accuracy_without_padding: 0.7085 - custom_mse: 0.0270 - loss: 0.0283 - val_custom_accuracy_without_padding: 0.7039 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 1.9531e-06
# Epoch 247/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7102 - custom_mse: 0.0272 - loss: 0.0285
# Epoch 247: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7101 - custom_mse: 0.0271 - loss: 0.0284 - val_custom_accuracy_without_padding: 0.7039 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 9.7656e-07
# Epoch 248/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7097 - custom_mse: 0.0267 - loss: 0.0280
# Epoch 248: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7096 - custom_mse: 0.0267 - loss: 0.0280 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 9.7656e-07
# Epoch 249/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7104 - custom_mse: 0.0267 - loss: 0.0280
# Epoch 249: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7103 - custom_mse: 0.0267 - loss: 0.0280 - val_custom_accuracy_without_padding: 0.7042 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 9.7656e-07
# Epoch 250/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7076 - custom_mse: 0.0272 - loss: 0.0285
# Epoch 250: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7078 - custom_mse: 0.0271 - loss: 0.0284 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 9.7656e-07
# Epoch 251/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7118 - custom_mse: 0.0263 - loss: 0.0276
# Epoch 251: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 251: val_loss improved from 0.02794 to 0.02794, saving model to /content/drive/MyDrive/10 Masters/Research/error-correcting-codes/ThisIsTheCleanest/weights/DCT_model_27.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy_without_padding: 0.7114 - custom_mse: 0.0264 - loss: 0.0277 - val_custom_accuracy_without_padding: 0.7039 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 9.7656e-07
# Epoch 252/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7123 - custom_mse: 0.0260 - loss: 0.0273
# Epoch 252: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_accuracy_without_padding: 0.7118 - custom_mse: 0.0262 - loss: 0.0275 - val_custom_accuracy_without_padding: 0.7039 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 4.8828e-07
# Epoch 253/500
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_accuracy_without_padding: 0.7085 - custom_mse: 0.0271 - loss: 0.0284
# Epoch 253: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - custom_accuracy_without_padding: 0.7085 - custom_mse: 0.0271 - loss: 0.0284 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 4.8828e-07
# Epoch 254/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7114 - custom_mse: 0.0270 - loss: 0.0283
# Epoch 254: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_accuracy_without_padding: 0.7110 - custom_mse: 0.0270 - loss: 0.0283 - val_custom_accuracy_without_padding: 0.7039 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 4.8828e-07
# Epoch 255/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7100 - custom_mse: 0.0267 - loss: 0.0280
# Epoch 255: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_accuracy_without_padding: 0.7098 - custom_mse: 0.0267 - loss: 0.0280 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 4.8828e-07
# Epoch 256/500
# 20/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7107 - custom_mse: 0.0264 - loss: 0.0277
# Epoch 256: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 256: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - custom_accuracy_without_padding: 0.7103 - custom_mse: 0.0265 - loss: 0.0278 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 4.8828e-07
# Epoch 257/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7084 - custom_mse: 0.0268 - loss: 0.0281
# Epoch 257: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7086 - custom_mse: 0.0268 - loss: 0.0281 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 2.4414e-07
# Epoch 258/500
# 22/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7067 - custom_mse: 0.0271 - loss: 0.0284
# Epoch 258: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7071 - custom_mse: 0.0270 - loss: 0.0284 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 2.4414e-07
# Epoch 259/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7102 - custom_mse: 0.0268 - loss: 0.0282
# Epoch 259: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_accuracy_without_padding: 0.7100 - custom_mse: 0.0268 - loss: 0.0281 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 2.4414e-07
# Epoch 260/500
# 17/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - custom_accuracy_without_padding: 0.7092 - custom_mse: 0.0269 - loss: 0.0282
# Epoch 260: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.7092 - custom_mse: 0.0268 - loss: 0.0282 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 2.4414e-07
# Epoch 261/500
# 21/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - custom_accuracy_without_padding: 0.7093 - custom_mse: 0.0268 - loss: 0.0281
# Epoch 261: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
#
# Epoch 261: val_loss did not improve from 0.02794
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_accuracy_without_padding: 0.7092 - custom_mse: 0.0268 - loss: 0.0281 - val_custom_accuracy_without_padding: 0.7040 - val_custom_mse: 0.0266 - val_loss: 0.0279 - learning_rate: 2.4414e-07

# %%
# Evaluate the model on the test set
eval_results = model.evaluate(X_test, y_test)
print(f"Test results - Loss: {eval_results[0]}, MSE: {eval_results[1]}, Accuracy: {eval_results[2]}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - custom_accuracy_without_padding: 0.7055 - custom_mse: 0.0261 - loss: 0.0274
# Test results - Loss: 0.027939030900597572, MSE: 0.026560476049780846, Accuracy: 0.7038690447807312

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['custom_accuracy_without_padding'], label='Training Accuracy')
plt.plot(history.history['val_custom_accuracy_without_padding'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.show()

# %%
y_pred = model.predict(X_test)
y_test_rescaled = y_test * (q - 1)
y_pred_rescaled = y_pred * (q - 1)

print("Comparison of predictions and ground truth:")
for i in range(3):
    print(f"Sample {i+1}:")
    print(f"  Predicted:    {np.round(y_pred_rescaled[i]).astype(int)}")
    print(f"  Ground Truth: {np.round(y_test_rescaled[i]).astype(int)}")
    print("-" * 40)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step
# Comparison of predictions and ground truth:
# Sample 1:
#   Predicted:    [3 3 3 3 3 3 3 3 4 2 3 1 4 0 3 2 5 1 4 3 4 4 6 5 2 3 1 0 0 0 0 0]
#   Ground Truth: [5 6 5 1 3 4 1 1 6 2 3 1 4 0 3 2 5 1 4 3 4 4 6 5 2 3 1 0 0 0 0 0]
# ----------------------------------------
# Sample 2:
#   Predicted:    [3 3 3 3 3 3 3 3 3 2 4 3 3 1 3 1 1 2 0 1 1 5 2 1 4 0 4 0 0 0 0 0]
#   Ground Truth: [1 4 1 3 3 3 0 5 5 2 4 3 3 1 3 1 1 2 0 1 1 5 2 1 4 0 4 0 0 0 0 0]
# ----------------------------------------
# Sample 3:
#   Predicted:    [3 3 3 3 3 3 3 3 3 6 4 1 0 5 2 3 5 1 4 6 0 4 3 2 3 4 4 0 0 0 0 0]
#   Ground Truth: [2 6 0 2 2 1 3 4 2 6 4 1 0 5 2 3 5 1 4 6 0 4 3 2 3 4 4 0 0 0 0 0]
# ----------------------------------------

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)

print(f"R² Score: {r2:.4f}")
# Out:
# R² Score: 0.6049

# %%
# ---------------------- Inference time on Test Set ----------------------------

import time

_ = model.predict(X_test, verbose=0)  # warm up

times = []
for _ in range(100):
    start = time.perf_counter()
    _ = model.predict(X_test, verbose=0)
    end = time.perf_counter()
    times.append(end - start)

average_inference_time = np.mean(times)
print(f"Average batch inference time over 100 runs: {average_inference_time:.6f} seconds")

average_per_sample = average_inference_time / X_test.shape[0]
print(f"Average inference time per sample (from batch): {average_per_sample:.6f} seconds")
# Out:
# Average batch inference time over 100 runs: 0.099736 seconds
# Average inference time per sample (from batch): 0.000499 seconds

# %% [markdown]
# Test on unseen samples

# %%
# --------------------- Predictions on unseen samples (no noise) -------------------------

np.random.seed(42)

x_unseen_original = np.random.randint(0, q, size=(num_unseen_samples, n))
x_unseen_original_padded = np.pad(x_unseen_original, ((0, 0), (0, padding)), mode='constant', constant_values=0)

# encode
encoded_dataset_unseen = np.array([np.dot(M_tilde, x) for x in x_unseen_original_padded])
encoded_dataset_unseen[np.abs(encoded_dataset_unseen) < 1e-10] = 0
encoded_dataset_unseen = np.round(encoded_dataset_unseen, decimals=10)

# pre-process
N = encoded_dataset_unseen.shape[1]
k = np.arange(N)
shift = np.exp(-1j * np.pi * k / (2 * N))
alpha_k = np.where(k == 0, np.sqrt(1/N), np.sqrt(2/N))

x_unseen_dct2 = np.array([np.real(alpha_k * shift * y) for y in encoded_dataset_unseen])
x_unseen_dct2[np.abs(x_unseen_dct2) < 1e-10] = 0
x_unseen_dct2 = np.round(x_unseen_dct2, decimals=10)

# Normalize
x_unseen_dct2_normalized = (x_unseen_dct2 - x_unseen_dct2.mean()) / x_unseen_dct2.std()

# Predict
nn_pred = model.predict(x_unseen_dct2_normalized)

# Rescale prediction
y_pred_final = np.mod(np.round(nn_pred * (q - 1)), q)

# Evaluate
x_unseen_original_padded_normalized = x_unseen_original_padded.astype(np.float32) / (q - 1)

mse_nn = custom_mse(x_unseen_original_padded_normalized, nn_pred)
acc_nn = custom_accuracy_without_padding(x_unseen_original_padded_normalized, nn_pred)

print(f"MSE on unseen data (no noise): {mse_nn}")
print(f"Accuracy on unseen data (no noise): {acc_nn}")

num_display_samples = 3
for i in range(num_display_samples):
    print(f"\nSample {i+1}:")
    print(f"Original : {x_unseen_original_padded[i]}")
    print(f"NN Pred  : {y_pred_final[i].astype(int)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 794ms/step
# MSE on unseen data (no noise): 0.027460360899567604
# Accuracy on unseen data (no noise): 0.7222222089767456
#
# Sample 1:
# Original : [6 3 4 6 2 4 4 6 1 2 6 2 2 4 3 2 5 4 1 3 5 5 1 3 4 0 3 0 0 0 0 0]
# NN Pred  : [3 3 3 3 3 3 3 4 2 2 6 2 2 4 3 2 5 4 1 3 5 5 1 3 4 0 3 0 0 0 0 0]
#
# Sample 2:
# Original : [1 5 4 3 0 0 2 2 6 1 3 3 6 5 5 6 5 2 3 6 3 0 2 4 2 6 4 0 0 0 0 0]
# NN Pred  : [3 3 3 3 3 3 3 3 4 1 3 3 6 5 5 6 5 2 3 6 3 0 2 4 2 6 4 0 0 0 0 0]
#
# Sample 3:
# Original : [0 6 1 3 0 3 5 1 1 0 1 4 1 3 3 6 3 6 3 4 6 2 5 0 3 1 3 0 0 0 0 0]
# NN Pred  : [3 3 3 3 3 3 3 3 2 0 1 4 1 3 3 6 3 6 3 4 6 2 5 0 3 1 3 0 0 0 0 0]

# %% [markdown]
# Visualize and Analyse model training

# %%
import matplotlib.pyplot as plt

# exclude zero pads
y_pred_first_n = y_pred[:, :n]
y_pred_first_n_rescaled = y_pred_first_n * (q - 1)

plt.hist(y_pred_first_n_rescaled.flatten(), bins=50)
plt.xlabel('Prediction Value')
plt.ylabel('Frequency')
plt.show()

# %%
for layer in model.layers:
    if layer.trainable_variables:  # Check if the layer has trainable variables
        for i, var in enumerate(layer.trainable_variables):
            print(f"{layer.name} - Variable {i} ({var.name}): values: {var.numpy()}")
    else:
        print(layer.name, "has no trainable variables.")
# Out:
# first_layer - Variable 0 (B_1): values: [1.5630417  1.0380825  1.0186867  1.0364052  1.069584   1.0306617
#  1.0282315  1.0537454  1.1172426  1.0426903  1.0499136  1.0408541
#  1.0409977  1.0128112  1.0212052  0.98611534]
# first_layer - Variable 1 (B_2): values: [1.02089   1.0197275 1.0117259 1.0589387 1.0264717 1.0268568 1.0377098
#  1.116462  1.0311216 1.046009  1.049157  1.0279696 1.0163378 1.0617847
#  1.0248344]
# first_layer - Variable 2 (bias): values: [-0.09535801  0.14941026  0.05274789 -0.04192781  0.06097946 -0.03914553
#   0.04565322  0.01159718  0.02811953  0.03572422  0.08297968  0.04421414
#   0.07394889  0.10740344  0.04499364  0.20274913  0.1620489   0.07313675
#  -0.03224356 -0.00867278  0.01001195 -0.00384605 -0.00020295  0.0115473
#  -0.00076179  0.00666852  0.04015227 -0.01624002  0.0065004   0.01727629
#  -0.0176557  -0.00881951]
# second_layer - Variable 0 (bias): values: [ 0.06964935  0.07800669  0.07213023  0.05622036  0.07943217  0.05999783
#   0.04723457  0.05355839  0.05113814  0.05738382  0.02145384 -0.1040321
#   0.00899917 -0.02308541  0.04936013  0.03815963  0.20861168 -0.02821688
#   0.22827187 -0.01026229  0.22261733 -0.03597819  0.14616574 -0.03985069
#   0.11432211 -0.05011993  0.06013805 -0.18079686  0.04188929 -0.10135546
#   0.00928345 -0.01049518]
# second_layer - Variable 1 (B_1): values: [1.4937562 1.0453645 1.0372089 1.0357248 1.1044813 1.0571994 1.0459718
#  1.0775971]
# second_layer - Variable 2 (B_2): values: [0.99619305 1.0252037  1.0098408  1.0638227  1.0622392  1.011322
#  0.99693966]
# second_layer - Variable 3 (W_c): values: [0.5662321  0.63417476 0.6886974  0.72335714 0.85438585 1.2792437
#  2.0611436  5.347196  ]
# second_layer - Variable 4 (B_1): values: [1.5090785 1.0779611 1.0723584 1.0347422]
# second_layer - Variable 5 (B_2): values: [1.0049889 1.0692898 1.0233984]
# second_layer - Variable 6 (W_c): values: [0.57941204 0.7124902  1.0659122  2.6801863 ]
# second_layer - Variable 7 (B_1): values: [1.5242718 1.1911627]
# second_layer - Variable 8 (B_2): values: [0.98508686]
# second_layer - Variable 9 (W_c): values: [0.60943896 1.5176259 ]
# second_layer - Variable 10 (C_2): values: [[ 0.83838254  0.9214199 ]
#  [ 0.96653205 -1.0894985 ]]
# second_layer - Variable 11 (C_2): values: [[ 0.8265613   0.69864744]
#  [ 0.7706495  -0.7920261 ]]
# second_layer - Variable 12 (B_1): values: [1.439618  1.0693723]
# second_layer - Variable 13 (B_2): values: [0.9983788]
# second_layer - Variable 14 (W_c): values: [0.57151157 1.4755746 ]
# second_layer - Variable 15 (C_2): values: [[ 0.7545428  0.7890599]
#  [ 0.8516786 -0.8738109]]
# second_layer - Variable 16 (C_2): values: [[ 0.751336    0.7231251 ]
#  [ 0.7378183  -0.74115944]]
# second_layer - Variable 17 (B_1): values: [1.4668893 1.0408562 1.0480876 1.021118 ]
# second_layer - Variable 18 (B_2): values: [1.0001209 1.0456955 1.0027936]
# second_layer - Variable 19 (W_c): values: [0.5301582 0.6507648 0.9853466 2.5678275]
# second_layer - Variable 20 (B_1): values: [1.4697443 1.0780656]
# second_layer - Variable 21 (B_2): values: [1.0004375]
# second_layer - Variable 22 (W_c): values: [0.5705078 1.4129407]
# second_layer - Variable 23 (C_2): values: [[ 0.74131966  0.7827101 ]
#  [ 0.81231534 -0.8379951 ]]
# second_layer - Variable 24 (C_2): values: [[ 0.74398655  0.7242237 ]
#  [ 0.74358416 -0.74967575]]
# second_layer - Variable 25 (B_1): values: [1.4513355 1.0452559]
# second_layer - Variable 26 (B_2): values: [1.0046712]
# second_layer - Variable 27 (W_c): values: [0.5558781 1.3624728]
# second_layer - Variable 28 (C_2): values: [[ 0.7272655   0.74466926]
#  [ 0.7708219  -0.75301063]]
# second_layer - Variable 29 (C_2): values: [[ 0.72314185  0.7173883 ]
#  [ 0.71623904 -0.7170365 ]]
# second_layer - Variable 30 (B_1): values: [1.5128467  1.0216494  1.0448416  1.0126071  1.0853447  1.0552634
#  1.0284795  0.99381745]
# second_layer - Variable 31 (B_2): values: [0.99509084 1.0247294  1.0214579  1.0614338  1.0590355  1.0068377
#  1.0829628 ]
# second_layer - Variable 32 (W_c): values: [0.5537552  0.6304409  0.6863962  0.6874162  0.85751826 1.2932541
#  2.0829778  5.508581  ]
# second_layer - Variable 33 (B_1): values: [1.532297  1.0516863 1.0581882 1.020897 ]
# second_layer - Variable 34 (B_2): values: [1.0207567 1.0496439 1.0328922]
# second_layer - Variable 35 (W_c): values: [0.550216  0.7162126 1.0600533 2.652825 ]
# second_layer - Variable 36 (B_1): values: [1.5096612 1.137502 ]
# second_layer - Variable 37 (B_2): values: [0.99733984]
# second_layer - Variable 38 (W_c): values: [0.59652096 1.5918165 ]
# second_layer - Variable 39 (C_2): values: [[ 0.8140636  0.8456282]
#  [ 1.0071493 -1.0194848]]
# second_layer - Variable 40 (C_2): values: [[ 0.7902361   0.71995807]
#  [ 0.7666405  -0.7925039 ]]
# second_layer - Variable 41 (B_1): values: [1.4858315 1.0655645]
# second_layer - Variable 42 (B_2): values: [1.0125989]
# second_layer - Variable 43 (W_c): values: [0.5697698 1.4618887]
# second_layer - Variable 44 (C_2): values: [[ 0.7652165   0.79388946]
#  [ 0.8635977  -0.88071036]]
# second_layer - Variable 45 (C_2): values: [[ 0.7550362   0.71829534]
#  [ 0.7407116  -0.74952555]]
# second_layer - Variable 46 (B_1): values: [1.4829931 1.0364871 1.0278904 1.0262684]
# second_layer - Variable 47 (B_2): values: [1.009264  1.0530659 0.9955052]
# second_layer - Variable 48 (W_c): values: [0.5236023  0.6662625  0.96278775 2.6155765 ]
# second_layer - Variable 49 (B_1): values: [1.4720368 1.1026251]
# second_layer - Variable 50 (B_2): values: [1.0130507]
# second_layer - Variable 51 (W_c): values: [0.566923  1.4372773]
# second_layer - Variable 52 (C_2): values: [[ 0.74504983  0.76129717]
#  [ 0.8535371  -0.843465  ]]
# second_layer - Variable 53 (C_2): values: [[ 0.7490293   0.7081131 ]
#  [ 0.74387234 -0.7405352 ]]
# second_layer - Variable 54 (B_1): values: [1.4696262 1.0346304]
# second_layer - Variable 55 (B_2): values: [0.99504536]
# second_layer - Variable 56 (W_c): values: [0.55460167 1.3465266 ]
# second_layer - Variable 57 (C_2): values: [[ 0.7423608  0.7399716]
#  [ 0.7931778 -0.7749577]]
# second_layer - Variable 58 (C_2): values: [[ 0.7308103   0.7216837 ]
#  [ 0.72077566 -0.7323903 ]]
# third_layer - Variable 0 (W_c): values: [0.55103785 1.1275109  0.48994786 1.3099349  0.51511645 1.3078463
#  0.58812875 1.4604027  0.7363377  1.4697452  0.92532575 1.139521
#  1.4884802  1.985252   3.2471747  9.927972  ]
# third_layer - Variable 1 (bias): values: [ 0.12755881  0.03342209  0.13381271 -0.11393079  0.13608216 -0.00218331
#   0.08852324  0.05431411  0.08091167  0.04184424  0.03933704  0.1959354
#   0.02595424  0.30617386  0.0284433   0.15990995  0.02486229  0.239469
#   0.03360403  0.19665128  0.04515328  0.17743215  0.05740147  0.09566396
#   0.05359366  0.06848471  0.06003185  0.00946878  0.05630175 -0.04711078
#   0.07783917 -0.03151986]
# leaky_re_lu has no trainable variables.
# scaling_layer - Variable 0 (log_scale): values: 0.23333963751792908
# scaling_layer - Variable 1 (diag): values: [ 6.4969468e-01  6.9817603e-01  6.4634407e-01  7.5620109e-01
#   7.8861374e-01  9.1591132e-01  1.0518848e+00  1.3089757e+00
#   1.1359704e+00  1.7550634e+00  1.5088164e+00  4.7526550e-01
#   2.7626786e-01  1.2910852e-01  8.7674484e-02  4.5324136e-02
#   5.0398845e-02  2.6825635e-02  1.9659167e-02  9.4936583e-03
#   6.6264099e-03  3.3243278e-03  2.3568487e-03  1.1756398e-03
#   8.1651803e-04  4.1546591e-04  3.0353610e-04 -2.0702437e-08
#  -6.2259664e-10 -1.5493626e-07 -1.5622337e-09 -1.4243263e-06]
# scaling_layer - Variable 2 (bias): values: [ 1.36247635e-01  1.22715734e-01  1.12754226e-01  6.86964169e-02
#   4.81391922e-02  3.77131887e-02  3.44530232e-02  4.40648794e-02
#   3.44080180e-02  3.49842384e-02  2.23966651e-02  6.69450015e-02
#   6.04310911e-03  1.42281572e-03  1.36162387e-03  8.49320728e-04
#   1.69313059e-03  2.62243138e-03  2.65380880e-03  2.94918055e-03
#   4.31031547e-03  3.09899542e-03  3.90585396e-03 -1.29718315e-02
#  -1.66075844e-02  1.03678629e-02  2.23588739e-02 -3.48843741e-07
#  -8.12403034e-09 -4.38490088e-06 -4.84109393e-08 -8.77303683e-05]
# leaky_re_lu_1 has no trainable variables.

# %%
from tensorflow.keras import backend as K
K.clear_session()
